# %%
import networkx as nx
import ModelConfig as mc
# import IndependentCascadesModelP001 as icm
# import IndependentCascadesModelP010 as icm
# import WeightedCascadeModel as icm
import ThresholdModel as tm
import operator
import random 
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
def GreedySelect(g, activated_nodes, model, config, greedy_i):
    ''' 
    Select node with max average marginal gain
    Variable 'mg' refers to 'marginal gain'
    Number of iterations to find average marginal gain defaulted to 100
    '''
    mg_dict = {}
    for candidate in g.nodes():
        if candidate in activated_nodes:
            continue
        mg = 0
        for i in range(greedy_i):
            newly_activated_nodes = GreedySim(model, config, candidate)
            mg += len(newly_activated_nodes)
        avg_mg = mg/greedy_i
        mg_dict[candidate] = avg_mg
    influencer = max(mg_dict.items(), key=operator.itemgetter(1))[0]
    print(f"Selected Influencer: Node {influencer}")
    
    return influencer

def GreedySim(model, config, candidate):
    config.add_model_initial_configuration("Infected", [candidate])
    model.set_initial_status(config)
    active_set_size, newly_activated_nodes = model.iteration_bunch()
    newly_activated_nodes.append(candidate)
    model.mg_reset(newly_activated_nodes)
    
    return newly_activated_nodes

# %%
def InitModel(g):
    model = tm.ThresholdModel(g) 
    config = mc.Configuration()
    
    edge_dict = {}
    for (v, w) in list(g.edges()):
        counter = list(g.edges()).count((v, w))
        if (w, v) in list(g.edges()): 
            counter += list(g.edges()).count((w, v))
        edge_dict[(v, w)] = counter / len(list(g.neighbors(w)))

    threshold_dict = {}
    for node in g.nodes():
        threshold_dict[node] = np.random.random_sample()
    
    config.add_node_set_configuration('threshold', threshold_dict)
    config.add_edge_set_configuration('weight', edge_dict)
    return model, config


def InfluenceSpread(model, config, influencer):
    config.add_model_initial_configuration("Infected", [influencer])
    model.set_initial_status(config)
    active_set_size, newly_activated_nodes = model.iteration_bunch()
    return active_set_size, newly_activated_nodes

def get_combination(g, target_set_size, greedy_i=100):
    '''
    Assuming continuous process (previously activated nodes cannot reattempt)
    As compared to one-time influence spread, all influencer same start point
    Default strategy set as greedy 
    '''
    # prepare graph for respective strategies
    g = remove_isolated_nodes(g)
        
    # initialize diffusion model
    model, config = InitModel(g)
    
    all_activated_nodes = []
    influencers = []
    active_ss_list = []
    for i in range(1, target_set_size+1):
        print(f"Selecting Influencer {i}")
        print("------------------------------------")
        
        influencer = GreedySelect(g, all_activated_nodes, model, config, greedy_i)
        influencers.append(influencer)

        active_set_size, newly_activated_nodes = InfluenceSpread(model, config, influencer)
        print(f"Newly Activated Nodes: {newly_activated_nodes}")
        newly_activated_nodes.append(influencer)
        all_activated_nodes.extend(newly_activated_nodes)
        print(f"All Activated Nodes: {all_activated_nodes}")
        print(f"Active Set Size: {active_set_size}")
        
        active_set_size, all_activated_nodes = model.random_deactivation(all_activated_nodes)
        print(f"Final Activated Nodes: {all_activated_nodes}")
        print(f"Final Active Set Size: {active_set_size}")
        print("")

        model.is_reset()
        active_ss_list.append(active_set_size)

    return influencers, active_ss_list[-1]

# %%
def remove_isolated_nodes(g):
    isolated_nodes = []
    for pair in g.degree:
        node = pair[0]
        degree = pair[1]
        if degree == 0:
            isolated_nodes.append(node)

    for node in isolated_nodes:
        g.remove_node(node)
        
    return g

# %%
# Simulation: Build Long Term Reward Reference

# %%
g = nx.erdos_renyi_graph(150, 0.1) #number of nodes, probability to form edges
g = remove_isolated_nodes(g)
target_set_size = 5
greedy_i = 10
LT_ref = []
num_i = 10
for i in range(1, num_i+1):
    print(f"Combination {i}")
    print("------------------------------------")
        
    combination = get_combination(g, target_set_size, greedy_i)
    LT_ref.append(combination)

LT_ref.sort(key=lambda x:x[1], reverse=True)
sorted_influencers = []
for influencers, LT_reward in LT_ref:
    if influencers in sorted_influencers: #better if can compare LT_reward and use the one with higher value
        continue  
    sorted_influencers.append(influencers)
# Out:
# Combination 1
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 137
# Newly Activated Nodes: [21, 90, 100, 128, 2, 27, 34, 77]
# All Activated Nodes: [21, 90, 100, 128, 2, 27, 34, 77, 137]
# Active Set Size: 9
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [21, 90, 100, 128, 2, 27, 34, 77, 137]
# Final Active Set Size: 9
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 119
# Newly Activated Nodes: [69, 79, 101, 30, 56, 6]
# All Activated Nodes: [21, 90, 100, 128, 2, 27, 34, 77, 137, 69, 79, 101, 30, 56, 6, 119]
# Active Set Size: 16
# Number of deactivations: 1
# Deactivated Nodes: [77]
# Final Activated Nodes: [21, 90, 100, 128, 2, 27, 34, 137, 69, 79, 101, 30, 56, 6, 119]
# Final Active Set Size: 15
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 44
# Newly Activated Nodes: [10, 24, 77]
# All Activated Nodes: [21, 90, 100, 128, 2, 27, 34, 137, 69, 79, 101, 30, 56, 6, 119, 10, 24, 77, 44]
# Active Set Size: 19
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [21, 90, 100, 128, 2, 27, 34, 137, 69, 79, 101, 30, 56, 6, 119, 10, 24, 77, 44]
# Final Active Set Size: 19
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 17
# Newly Activated Nodes: [14]
# All Activated Nodes: [21, 90, 100, 128, 2, 27, 34, 137, 69, 79, 101, 30, 56, 6, 119, 10, 24, 77, 44, 14, 17]
# Active Set Size: 21
# Number of deactivations: 1
# Deactivated Nodes: [2]
# Final Activated Nodes: [21, 90, 100, 128, 27, 34, 137, 69, 79, 101, 30, 56, 6, 119, 10, 24, 77, 44, 14, 17]
# Final Active Set Size: 20
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 80
# Newly Activated Nodes: [2, 70]
# All Activated Nodes: [21, 90, 100, 128, 27, 34, 137, 69, 79, 101, 30, 56, 6, 119, 10, 24, 77, 44, 14, 17, 2, 70, 80]
# Active Set Size: 23
# Number of deactivations: 1
# Deactivated Nodes: [70]
# Final Activated Nodes: [21, 90, 100, 128, 27, 34, 137, 69, 79, 101, 30, 56, 6, 119, 10, 24, 77, 44, 14, 17, 2, 80]
# Final Active Set Size: 22
#
# Combination 2
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 132
# Newly Activated Nodes: [82, 91, 37, 47, 60, 18]
# All Activated Nodes: [82, 91, 37, 47, 60, 18, 132]
# Active Set Size: 7
# Number of deactivations: 1
# Deactivated Nodes: [82]
# Final Activated Nodes: [91, 37, 47, 60, 18, 132]
# Final Active Set Size: 6
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 92
# Newly Activated Nodes: [33, 82, 24]
# All Activated Nodes: [91, 37, 47, 60, 18, 132, 33, 82, 24, 92]
# Active Set Size: 10
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [91, 37, 47, 60, 18, 132, 33, 82, 24, 92]
# Final Active Set Size: 10
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 30
# Newly Activated Nodes: [14]
# All Activated Nodes: [91, 37, 47, 60, 18, 132, 33, 82, 24, 92, 14, 30]
# Active Set Size: 12
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [91, 37, 47, 60, 18, 132, 33, 82, 24, 92, 14, 30]
# Final Active Set Size: 12
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 42
# Newly Activated Nodes: [28]
# All Activated Nodes: [91, 37, 47, 60, 18, 132, 33, 82, 24, 92, 14, 30, 28, 42]
# Active Set Size: 14
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [91, 37, 47, 60, 18, 132, 33, 82, 24, 92, 14, 30, 28, 42]
# Final Active Set Size: 14
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 78
# Newly Activated Nodes: [66, 38]
# All Activated Nodes: [91, 37, 47, 60, 18, 132, 33, 82, 24, 92, 14, 30, 28, 42, 66, 38, 78]
# Active Set Size: 17
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [91, 37, 47, 60, 18, 132, 33, 82, 24, 92, 14, 30, 28, 42, 66, 38, 78]
# Final Active Set Size: 17
#
# Combination 3
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 132
# Newly Activated Nodes: [22, 82, 119, 27, 39, 101, 2, 19]
# All Activated Nodes: [22, 82, 119, 27, 39, 101, 2, 19, 132]
# Active Set Size: 9
# Number of deactivations: 1
# Deactivated Nodes: [101]
# Final Activated Nodes: [22, 82, 119, 27, 39, 2, 19, 132]
# Final Active Set Size: 8
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 131
# Newly Activated Nodes: [15, 41, 65, 101, 102]
# All Activated Nodes: [22, 82, 119, 27, 39, 2, 19, 132, 15, 41, 65, 101, 102, 131]
# Active Set Size: 14
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [22, 82, 119, 27, 39, 2, 19, 132, 15, 41, 65, 101, 102, 131]
# Final Active Set Size: 14
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 117
# Newly Activated Nodes: [52, 66]
# All Activated Nodes: [22, 82, 119, 27, 39, 2, 19, 132, 15, 41, 65, 101, 102, 131, 52, 66, 117]
# Active Set Size: 17
# Number of deactivations: 1
# Deactivated Nodes: [19]
# Final Activated Nodes: [22, 82, 119, 27, 39, 2, 132, 15, 41, 65, 101, 102, 131, 52, 66, 117]
# Final Active Set Size: 16
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 98
# Newly Activated Nodes: [0, 8, 19, 95]
# All Activated Nodes: [22, 82, 119, 27, 39, 2, 132, 15, 41, 65, 101, 102, 131, 52, 66, 117, 0, 8, 19, 95, 98]
# Active Set Size: 21
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [22, 82, 119, 27, 39, 2, 132, 15, 41, 65, 101, 102, 131, 52, 66, 117, 0, 8, 19, 95, 98]
# Final Active Set Size: 21
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 125
# Newly Activated Nodes: [71, 112, 69]
# All Activated Nodes: [22, 82, 119, 27, 39, 2, 132, 15, 41, 65, 101, 102, 131, 52, 66, 117, 0, 8, 19, 95, 98, 71, 112, 69, 125]
# Active Set Size: 25
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [22, 82, 119, 27, 39, 2, 132, 15, 41, 65, 101, 102, 131, 52, 66, 117, 0, 8, 19, 95, 98, 71, 112, 69, 125]
# Final Active Set Size: 25
#
# Combination 4
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 125
# Newly Activated Nodes: [52, 114, 0, 97, 28, 19]
# All Activated Nodes: [52, 114, 0, 97, 28, 19, 125]
# Active Set Size: 7
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [52, 114, 0, 97, 28, 19, 125]
# Final Active Set Size: 7
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 104
# Newly Activated Nodes: [15, 77, 92, 7, 51, 61]
# All Activated Nodes: [52, 114, 0, 97, 28, 19, 125, 15, 77, 92, 7, 51, 61, 104]
# Active Set Size: 14
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [52, 114, 0, 97, 28, 19, 125, 15, 77, 92, 7, 51, 61, 104]
# Final Active Set Size: 14
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 146
# Newly Activated Nodes: [33, 142, 41, 43]
# All Activated Nodes: [52, 114, 0, 97, 28, 19, 125, 15, 77, 92, 7, 51, 61, 104, 33, 142, 41, 43, 146]
# Active Set Size: 19
# Number of deactivations: 1
# Deactivated Nodes: [97]
# Final Activated Nodes: [52, 114, 0, 28, 19, 125, 15, 77, 92, 7, 51, 61, 104, 33, 142, 41, 43, 146]
# Final Active Set Size: 18
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 138
# Newly Activated Nodes: [18, 73, 97, 59]
# All Activated Nodes: [52, 114, 0, 28, 19, 125, 15, 77, 92, 7, 51, 61, 104, 33, 142, 41, 43, 146, 18, 73, 97, 59, 138]
# Active Set Size: 23
# Number of deactivations: 1
# Deactivated Nodes: [19]
# Final Activated Nodes: [52, 114, 0, 28, 125, 15, 77, 92, 7, 51, 61, 104, 33, 142, 41, 43, 146, 18, 73, 97, 59, 138]
# Final Active Set Size: 22
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 148
# Newly Activated Nodes: [19, 31, 130, 35]
# All Activated Nodes: [52, 114, 0, 28, 125, 15, 77, 92, 7, 51, 61, 104, 33, 142, 41, 43, 146, 18, 73, 97, 59, 138, 19, 31, 130, 35, 148]
# Active Set Size: 27
# Number of deactivations: 1
# Deactivated Nodes: [148]
# Final Activated Nodes: [52, 114, 0, 28, 125, 15, 77, 92, 7, 51, 61, 104, 33, 142, 41, 43, 146, 18, 73, 97, 59, 138, 19, 31, 130, 35]
# Final Active Set Size: 26
#
# Combination 5
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 141
# Newly Activated Nodes: [40, 137, 21, 41, 1]
# All Activated Nodes: [40, 137, 21, 41, 1, 141]
# Active Set Size: 6
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [40, 137, 21, 41, 1, 141]
# Final Active Set Size: 6
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 98
# Newly Activated Nodes: [49, 61, 5, 27]
# All Activated Nodes: [40, 137, 21, 41, 1, 141, 49, 61, 5, 27, 98]
# Active Set Size: 11
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [40, 137, 21, 41, 1, 141, 49, 61, 5, 27, 98]
# Final Active Set Size: 11
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 94
# Newly Activated Nodes: [8, 46, 85, 12, 32, 38]
# All Activated Nodes: [40, 137, 21, 41, 1, 141, 49, 61, 5, 27, 98, 8, 46, 85, 12, 32, 38, 94]
# Active Set Size: 18
# Number of deactivations: 1
# Deactivated Nodes: [8]
# Final Activated Nodes: [40, 137, 21, 41, 1, 141, 49, 61, 5, 27, 98, 46, 85, 12, 32, 38, 94]
# Final Active Set Size: 17
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 13
# Newly Activated Nodes: [8, 10]
# All Activated Nodes: [40, 137, 21, 41, 1, 141, 49, 61, 5, 27, 98, 46, 85, 12, 32, 38, 94, 8, 10, 13]
# Active Set Size: 20
# Number of deactivations: 1
# Deactivated Nodes: [38]
# Final Activated Nodes: [40, 137, 21, 41, 1, 141, 49, 61, 5, 27, 98, 46, 85, 12, 32, 94, 8, 10, 13]
# Final Active Set Size: 19
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 42
# Newly Activated Nodes: [35, 38]
# All Activated Nodes: [40, 137, 21, 41, 1, 141, 49, 61, 5, 27, 98, 46, 85, 12, 32, 94, 8, 10, 13, 35, 38, 42]
# Active Set Size: 22
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [40, 137, 21, 41, 1, 141, 49, 61, 5, 27, 98, 46, 85, 12, 32, 94, 8, 10, 13, 35, 38, 42]
# Final Active Set Size: 22
#
# Combination 6
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 113
# Newly Activated Nodes: [93, 45, 42]
# All Activated Nodes: [93, 45, 42, 113]
# Active Set Size: 4
# Number of deactivations: 1
# Deactivated Nodes: [113]
# Final Activated Nodes: [93, 45, 42]
# Final Active Set Size: 3
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 118
# Newly Activated Nodes: [68, 105]
# All Activated Nodes: [93, 45, 42, 68, 105, 118]
# Active Set Size: 6
# Number of deactivations: 1
# Deactivated Nodes: [68]
# Final Activated Nodes: [93, 45, 42, 105, 118]
# Final Active Set Size: 5
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 0
# Newly Activated Nodes: [68]
# All Activated Nodes: [93, 45, 42, 105, 118, 68, 0]
# Active Set Size: 7
# Number of deactivations: 1
# Deactivated Nodes: [45]
# Final Activated Nodes: [93, 42, 105, 118, 68, 0]
# Final Active Set Size: 6
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 1
# Newly Activated Nodes: [45]
# All Activated Nodes: [93, 42, 105, 118, 68, 0, 45, 1]
# Active Set Size: 8
# Number of deactivations: 1
# Deactivated Nodes: [0]
# Final Activated Nodes: [93, 42, 105, 118, 68, 45, 1]
# Final Active Set Size: 7
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 0
# Newly Activated Nodes: []
# All Activated Nodes: [93, 42, 105, 118, 68, 45, 1, 0]
# Active Set Size: 8
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [93, 42, 105, 118, 68, 45, 1, 0]
# Final Active Set Size: 8
#
# Combination 7
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 90
# Newly Activated Nodes: [58, 85, 38, 22]
# All Activated Nodes: [58, 85, 38, 22, 90]
# Active Set Size: 5
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [58, 85, 38, 22, 90]
# Final Active Set Size: 5
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 46
# Newly Activated Nodes: [31, 23]
# All Activated Nodes: [58, 85, 38, 22, 90, 31, 23, 46]
# Active Set Size: 8
# Number of deactivations: 1
# Deactivated Nodes: [38]
# Final Activated Nodes: [58, 85, 22, 90, 31, 23, 46]
# Final Active Set Size: 7
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 60
# Newly Activated Nodes: [38, 54, 44]
# All Activated Nodes: [58, 85, 22, 90, 31, 23, 46, 38, 54, 44, 60]
# Active Set Size: 11
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [58, 85, 22, 90, 31, 23, 46, 38, 54, 44, 60]
# Final Active Set Size: 11
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 93
# Newly Activated Nodes: [45, 86]
# All Activated Nodes: [58, 85, 22, 90, 31, 23, 46, 38, 54, 44, 60, 45, 86, 93]
# Active Set Size: 14
# Number of deactivations: 1
# Deactivated Nodes: [22]
# Final Activated Nodes: [58, 85, 90, 31, 23, 46, 38, 54, 44, 60, 45, 86, 93]
# Final Active Set Size: 13
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 128
# Newly Activated Nodes: [22, 28, 73, 76, 29]
# All Activated Nodes: [58, 85, 90, 31, 23, 46, 38, 54, 44, 60, 45, 86, 93, 22, 28, 73, 76, 29, 128]
# Active Set Size: 19
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [58, 85, 90, 31, 23, 46, 38, 54, 44, 60, 45, 86, 93, 22, 28, 73, 76, 29, 128]
# Final Active Set Size: 19
#
# Combination 8
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 112
# Newly Activated Nodes: [40, 91, 111, 25, 37, 47]
# All Activated Nodes: [40, 91, 111, 25, 37, 47, 112]
# Active Set Size: 7
# Number of deactivations: 1
# Deactivated Nodes: [25]
# Final Activated Nodes: [40, 91, 111, 37, 47, 112]
# Final Active Set Size: 6
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 131
# Newly Activated Nodes: [24, 25, 90, 127, 58]
# All Activated Nodes: [40, 91, 111, 37, 47, 112, 24, 25, 90, 127, 58, 131]
# Active Set Size: 12
# Number of deactivations: 1
# Deactivated Nodes: [127]
# Final Activated Nodes: [40, 91, 111, 37, 47, 112, 24, 25, 90, 58, 131]
# Final Active Set Size: 11
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 142
# Newly Activated Nodes: [102, 127, 139]
# All Activated Nodes: [40, 91, 111, 37, 47, 112, 24, 25, 90, 58, 131, 102, 127, 139, 142]
# Active Set Size: 15
# Number of deactivations: 1
# Deactivated Nodes: [47]
# Final Activated Nodes: [40, 91, 111, 37, 112, 24, 25, 90, 58, 131, 102, 127, 139, 142]
# Final Active Set Size: 14
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 109
# Newly Activated Nodes: [47, 95, 74]
# All Activated Nodes: [40, 91, 111, 37, 112, 24, 25, 90, 58, 131, 102, 127, 139, 142, 47, 95, 74, 109]
# Active Set Size: 18
# Number of deactivations: 1
# Deactivated Nodes: [112]
# Final Activated Nodes: [40, 91, 111, 37, 24, 25, 90, 58, 131, 102, 127, 139, 142, 47, 95, 74, 109]
# Final Active Set Size: 17
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 28
# Newly Activated Nodes: [19]
# All Activated Nodes: [40, 91, 111, 37, 24, 25, 90, 58, 131, 102, 127, 139, 142, 47, 95, 74, 109, 19, 28]
# Active Set Size: 19
# Number of deactivations: 1
# Deactivated Nodes: [131]
# Final Activated Nodes: [40, 91, 111, 37, 24, 25, 90, 58, 102, 127, 139, 142, 47, 95, 74, 109, 19, 28]
# Final Active Set Size: 18
#
# Combination 9
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 136
# Newly Activated Nodes: [110, 132, 101, 86, 23]
# All Activated Nodes: [110, 132, 101, 86, 23, 136]
# Active Set Size: 6
# Number of deactivations: 1
# Deactivated Nodes: [132]
# Final Activated Nodes: [110, 101, 86, 23, 136]
# Final Active Set Size: 5
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 139
# Newly Activated Nodes: [77, 116, 132, 4, 37, 65, 75, 18]
# All Activated Nodes: [110, 101, 86, 23, 136, 77, 116, 132, 4, 37, 65, 75, 18, 139]
# Active Set Size: 14
# Number of deactivations: 1
# Deactivated Nodes: [77]
# Final Activated Nodes: [110, 101, 86, 23, 136, 116, 132, 4, 37, 65, 75, 18, 139]
# Final Active Set Size: 13
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 68
# Newly Activated Nodes: [33, 43, 45, 77]
# All Activated Nodes: [110, 101, 86, 23, 136, 116, 132, 4, 37, 65, 75, 18, 139, 33, 43, 45, 77, 68]
# Active Set Size: 18
# Number of deactivations: 1
# Deactivated Nodes: [4]
# Final Activated Nodes: [110, 101, 86, 23, 136, 116, 132, 37, 65, 75, 18, 139, 33, 43, 45, 77, 68]
# Final Active Set Size: 17
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 103
# Newly Activated Nodes: [4, 9, 71, 7]
# All Activated Nodes: [110, 101, 86, 23, 136, 116, 132, 37, 65, 75, 18, 139, 33, 43, 45, 77, 68, 4, 9, 71, 7, 103]
# Active Set Size: 22
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [110, 101, 86, 23, 136, 116, 132, 37, 65, 75, 18, 139, 33, 43, 45, 77, 68, 4, 9, 71, 7, 103]
# Final Active Set Size: 22
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 148
# Newly Activated Nodes: [134, 121]
# All Activated Nodes: [110, 101, 86, 23, 136, 116, 132, 37, 65, 75, 18, 139, 33, 43, 45, 77, 68, 4, 9, 71, 7, 103, 134, 121, 148]
# Active Set Size: 25
# Number of deactivations: 2
# Deactivated Nodes: [110, 116]
# Final Activated Nodes: [101, 86, 23, 136, 132, 37, 65, 75, 18, 139, 33, 43, 45, 77, 68, 4, 9, 71, 7, 103, 134, 121, 148]
# Final Active Set Size: 23
#
# Combination 10
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 149
# Newly Activated Nodes: [71, 127, 64, 69, 0, 4, 33, 36, 48, 2]
# All Activated Nodes: [71, 127, 64, 69, 0, 4, 33, 36, 48, 2, 149]
# Active Set Size: 11
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [71, 127, 64, 69, 0, 4, 33, 36, 48, 2, 149]
# Final Active Set Size: 11
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 109
# Newly Activated Nodes: [9, 99, 7, 28, 19]
# All Activated Nodes: [71, 127, 64, 69, 0, 4, 33, 36, 48, 2, 149, 9, 99, 7, 28, 19, 109]
# Active Set Size: 17
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [71, 127, 64, 69, 0, 4, 33, 36, 48, 2, 149, 9, 99, 7, 28, 19, 109]
# Final Active Set Size: 17
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 122
# Newly Activated Nodes: [14, 79, 1]
# All Activated Nodes: [71, 127, 64, 69, 0, 4, 33, 36, 48, 2, 149, 9, 99, 7, 28, 19, 109, 14, 79, 1, 122]
# Active Set Size: 21
# Number of deactivations: 1
# Deactivated Nodes: [109]
# Final Activated Nodes: [71, 127, 64, 69, 0, 4, 33, 36, 48, 2, 149, 9, 99, 7, 28, 19, 14, 79, 1, 122]
# Final Active Set Size: 20
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 90
# Newly Activated Nodes: [58, 84]
# All Activated Nodes: [71, 127, 64, 69, 0, 4, 33, 36, 48, 2, 149, 9, 99, 7, 28, 19, 14, 79, 1, 122, 58, 84, 90]
# Active Set Size: 23
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [71, 127, 64, 69, 0, 4, 33, 36, 48, 2, 149, 9, 99, 7, 28, 19, 14, 79, 1, 122, 58, 84, 90]
# Final Active Set Size: 23
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 142
# Newly Activated Nodes: [43, 139]
# All Activated Nodes: [71, 127, 64, 69, 0, 4, 33, 36, 48, 2, 149, 9, 99, 7, 28, 19, 14, 79, 1, 122, 58, 84, 90, 43, 139, 142]
# Active Set Size: 26
# Number of deactivations: 1
# Deactivated Nodes: [33]
# Final Activated Nodes: [71, 127, 64, 69, 0, 4, 36, 48, 2, 149, 9, 99, 7, 28, 19, 14, 79, 1, 122, 58, 84, 90, 43, 139, 142]
# Final Active Set Size: 25

# %%
print(LT_ref)
print("")
print(sorted_influencers)
# Out:
# [([125, 104, 146, 138, 148], 26), ([132, 131, 117, 98, 125], 25), ([149, 109, 122, 90, 142], 25), ([136, 139, 68, 103, 148], 23), ([137, 119, 44, 17, 80], 22), ([141, 98, 94, 13, 42], 22), ([90, 46, 60, 93, 128], 19), ([112, 131, 142, 109, 28], 18), ([132, 92, 30, 42, 78], 17), ([113, 118, 0, 1, 0], 8)]
#
# [[125, 104, 146, 138, 148], [132, 131, 117, 98, 125], [149, 109, 122, 90, 142], [136, 139, 68, 103, 148], [137, 119, 44, 17, 80], [141, 98, 94, 13, 42], [90, 46, 60, 93, 128], [112, 131, 142, 109, 28], [132, 92, 30, 42, 78], [113, 118, 0, 1, 0]]

# %%
# Actual Influence Spread

# %%
def check_reference(sorted_influencers, all_activated_nodes, i, model, config):
    influencer = sorted_influencers[0][i]
    j = 1
    while influencer in all_activated_nodes:
        try:   
            influencer = sorted_influencers[j][i]
            j += 1
        except IndexError:
            influencer = GreedySelect(g, all_activated_nodes, model, config, greedy_i)

    # Filter sorted influencers for unmatching combinations
    print(f"Influencer: Node {influencer}")
    n = []
    for combination in sorted_influencers:
        if combination[i] == influencer:
            n.append(combination)
    print(f"New Sorted Combination List: {n}")
    sorted_influencers = n
    return influencer, sorted_influencers

def greedy_sequential(g, target_set_size, greedy_i, sorted_influencers):
    '''
    Assuming continuous process (previously activated nodes cannot reattempt)
    As compared to one-time influence spread, all influencer same start point
    Default strategy set as greedy 
    '''
    # prepare graph for respective strategies
    g = remove_isolated_nodes(g)
        
    # initialize diffusion model
    model, config = InitModel(g)
    
    all_activated_nodes = []
    influencers = []
    active_ss_list = []
    
    for i in range(target_set_size):
        print(f"Selecting Influencer {i+1}")
        print("------------------------------------")
        
        if sorted_influencers == []: # If no matching combination, simulate greedy
            influencer = GreedySelect(g, all_activated_nodes, model, config, greedy_i)
            print("Approach: Greedy Select")
        else: # Check LT Reward Reference
            influencer, sorted_influencers = check_reference(sorted_influencers, all_activated_nodes, i, model, config)
            print("Approach: LT Reward Reference")
            
        influencers.append(influencer)

        active_set_size, newly_activated_nodes = InfluenceSpread(model, config, influencer)
        print(f"Newly Activated Nodes: {newly_activated_nodes}")
        newly_activated_nodes.append(influencer)
        all_activated_nodes.extend(newly_activated_nodes)
        print(f"All Activated Nodes: {all_activated_nodes}")
        print(f"Active Set Size: {active_set_size}")
        
        active_set_size, all_activated_nodes = model.random_deactivation(all_activated_nodes)
        print(f"Final Activated Nodes: {all_activated_nodes}")
        print(f"Final Active Set Size: {active_set_size}")
        print("")

        model.is_reset()
        active_ss_list.append(active_set_size)

    return influencers, active_ss_list[-1]

# %%
exp_i = 5
greedy_i = 10
target_set_size = 5
g_total_activated_nodes = 0

for i in range(exp_i):
    influencers, active_set_size = greedy_sequential(g, target_set_size, greedy_i, sorted_influencers)
    g_total_activated_nodes += active_set_size

g_avg_activated_nodes = g_total_activated_nodes / exp_i
# Out:
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 125
# New Sorted Combination List: [[125, 104, 146, 138, 148]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [11]
# All Activated Nodes: [11, 125]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [11, 125]
# Final Active Set Size: 2
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 104
# New Sorted Combination List: [[125, 104, 146, 138, 148]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [3]
# All Activated Nodes: [11, 125, 3, 104]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [11, 125, 3, 104]
# Final Active Set Size: 4
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 146
# New Sorted Combination List: [[125, 104, 146, 138, 148]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [98, 66, 38]
# All Activated Nodes: [11, 125, 3, 104, 98, 66, 38, 146]
# Active Set Size: 8
# Number of deactivations: 1
# Deactivated Nodes: [66]
# Final Activated Nodes: [11, 125, 3, 104, 98, 38, 146]
# Final Active Set Size: 7
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 138
# New Sorted Combination List: [[125, 104, 146, 138, 148]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [66]
# All Activated Nodes: [11, 125, 3, 104, 98, 38, 146, 66, 138]
# Active Set Size: 9
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [11, 125, 3, 104, 98, 38, 146, 66, 138]
# Final Active Set Size: 9
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 148
# New Sorted Combination List: [[125, 104, 146, 138, 148]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [23]
# All Activated Nodes: [11, 125, 3, 104, 98, 38, 146, 66, 138, 23, 148]
# Active Set Size: 11
# Number of deactivations: 1
# Deactivated Nodes: [98]
# Final Activated Nodes: [11, 125, 3, 104, 38, 146, 66, 138, 23, 148]
# Final Active Set Size: 10
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 125
# New Sorted Combination List: [[125, 104, 146, 138, 148]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [70, 72, 65]
# All Activated Nodes: [70, 72, 65, 125]
# Active Set Size: 4
# Number of deactivations: 1
# Deactivated Nodes: [70]
# Final Activated Nodes: [72, 65, 125]
# Final Active Set Size: 3
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 104
# New Sorted Combination List: [[125, 104, 146, 138, 148]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [70, 76, 18]
# All Activated Nodes: [72, 65, 125, 70, 76, 18, 104]
# Active Set Size: 7
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [72, 65, 125, 70, 76, 18, 104]
# Final Active Set Size: 7
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 146
# New Sorted Combination List: [[125, 104, 146, 138, 148]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [34, 139]
# All Activated Nodes: [72, 65, 125, 70, 76, 18, 104, 34, 139, 146]
# Active Set Size: 10
# Number of deactivations: 1
# Deactivated Nodes: [72]
# Final Activated Nodes: [65, 125, 70, 76, 18, 104, 34, 139, 146]
# Final Active Set Size: 9
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 138
# New Sorted Combination List: [[125, 104, 146, 138, 148]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [63, 72, 73, 127]
# All Activated Nodes: [65, 125, 70, 76, 18, 104, 34, 139, 146, 63, 72, 73, 127, 138]
# Active Set Size: 14
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [65, 125, 70, 76, 18, 104, 34, 139, 146, 63, 72, 73, 127, 138]
# Final Active Set Size: 14
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 148
# New Sorted Combination List: [[125, 104, 146, 138, 148]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [65, 125, 70, 76, 18, 104, 34, 139, 146, 63, 72, 73, 127, 138, 148]
# Active Set Size: 15
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [65, 125, 70, 76, 18, 104, 34, 139, 146, 63, 72, 73, 127, 138, 148]
# Final Active Set Size: 15
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 125
# New Sorted Combination List: [[125, 104, 146, 138, 148]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [0, 87]
# All Activated Nodes: [0, 87, 125]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [0, 87, 125]
# Final Active Set Size: 3
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 104
# New Sorted Combination List: [[125, 104, 146, 138, 148]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [49]
# All Activated Nodes: [0, 87, 125, 49, 104]
# Active Set Size: 5
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [0, 87, 125, 49, 104]
# Final Active Set Size: 5
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 146
# New Sorted Combination List: [[125, 104, 146, 138, 148]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [22, 33]
# All Activated Nodes: [0, 87, 125, 49, 104, 22, 33, 146]
# Active Set Size: 8
# Number of deactivations: 1
# Deactivated Nodes: [0]
# Final Activated Nodes: [87, 125, 49, 104, 22, 33, 146]
# Final Active Set Size: 7
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 138
# New Sorted Combination List: [[125, 104, 146, 138, 148]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [0, 26, 113]
# All Activated Nodes: [87, 125, 49, 104, 22, 33, 146, 0, 26, 113, 138]
# Active Set Size: 11
# Number of deactivations: 1
# Deactivated Nodes: [104]
# Final Activated Nodes: [87, 125, 49, 22, 33, 146, 0, 26, 113, 138]
# Final Active Set Size: 10
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 148
# New Sorted Combination List: [[125, 104, 146, 138, 148]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [8]
# All Activated Nodes: [87, 125, 49, 22, 33, 146, 0, 26, 113, 138, 8, 148]
# Active Set Size: 12
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [87, 125, 49, 22, 33, 146, 0, 26, 113, 138, 8, 148]
# Final Active Set Size: 12
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 125
# New Sorted Combination List: [[125, 104, 146, 138, 148]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [13]
# All Activated Nodes: [13, 125]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [13]
# Final Activated Nodes: [125]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 104
# New Sorted Combination List: [[125, 104, 146, 138, 148]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [13]
# All Activated Nodes: [125, 13, 104]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [125]
# Final Activated Nodes: [13, 104]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 146
# New Sorted Combination List: [[125, 104, 146, 138, 148]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [139]
# All Activated Nodes: [13, 104, 139, 146]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [13, 104, 139, 146]
# Final Active Set Size: 4
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 138
# New Sorted Combination List: [[125, 104, 146, 138, 148]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [113]
# All Activated Nodes: [13, 104, 139, 146, 113, 138]
# Active Set Size: 6
# Number of deactivations: 1
# Deactivated Nodes: [104]
# Final Activated Nodes: [13, 139, 146, 113, 138]
# Final Active Set Size: 5
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 148
# New Sorted Combination List: [[125, 104, 146, 138, 148]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [23, 56]
# All Activated Nodes: [13, 139, 146, 113, 138, 23, 56, 148]
# Active Set Size: 8
# Number of deactivations: 1
# Deactivated Nodes: [23]
# Final Activated Nodes: [13, 139, 146, 113, 138, 56, 148]
# Final Active Set Size: 7
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 125
# New Sorted Combination List: [[125, 104, 146, 138, 148]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [13, 10]
# All Activated Nodes: [13, 10, 125]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [13, 10, 125]
# Final Active Set Size: 3
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 104
# New Sorted Combination List: [[125, 104, 146, 138, 148]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [3, 52, 76, 77]
# All Activated Nodes: [13, 10, 125, 3, 52, 76, 77, 104]
# Active Set Size: 8
# Number of deactivations: 1
# Deactivated Nodes: [76]
# Final Activated Nodes: [13, 10, 125, 3, 52, 77, 104]
# Final Active Set Size: 7
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 146
# New Sorted Combination List: [[125, 104, 146, 138, 148]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [76]
# All Activated Nodes: [13, 10, 125, 3, 52, 77, 104, 76, 146]
# Active Set Size: 9
# Number of deactivations: 1
# Deactivated Nodes: [125]
# Final Activated Nodes: [13, 10, 3, 52, 77, 104, 76, 146]
# Final Active Set Size: 8
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 138
# New Sorted Combination List: [[125, 104, 146, 138, 148]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [46, 54, 45]
# All Activated Nodes: [13, 10, 3, 52, 77, 104, 76, 146, 46, 54, 45, 138]
# Active Set Size: 12
# Number of deactivations: 1
# Deactivated Nodes: [52]
# Final Activated Nodes: [13, 10, 3, 77, 104, 76, 146, 46, 54, 45, 138]
# Final Active Set Size: 11
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 148
# New Sorted Combination List: [[125, 104, 146, 138, 148]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [52, 130, 43]
# All Activated Nodes: [13, 10, 3, 77, 104, 76, 146, 46, 54, 45, 138, 52, 130, 43, 148]
# Active Set Size: 15
# Number of deactivations: 1
# Deactivated Nodes: [43]
# Final Activated Nodes: [13, 10, 3, 77, 104, 76, 146, 46, 54, 45, 138, 52, 130, 148]
# Final Active Set Size: 14

# %%
def random_sequential(g, target_set_size):
    '''
    Assuming continuous process (previously activated nodes cannot reattempt)
    As compared to one-time influence spread, all influencer same start point
    Default strategy set as greedy 
    '''
    # prepare graph for respective strategies
    g = remove_isolated_nodes(g)
        
    # initialize diffusion model
    model, config = InitModel(g)
    
    all_activated_nodes = []
    influencers = []
    active_ss_list = []
    
    for i in range(target_set_size):
        print(f"Selecting Influencer {i+1}")
        print("------------------------------------")
        
        influencer = random.randint(0, len(g)-1)
        while influencer in all_activated_nodes:
            influencer = random.randint(0, len(g)-1)
        print(f"Influencer: Node {influencer}")
            
        influencers.append(influencer)

        active_set_size, newly_activated_nodes = InfluenceSpread(model, config, influencer)
        print(f"Newly Activated Nodes: {newly_activated_nodes}")
        newly_activated_nodes.append(influencer)
        all_activated_nodes.extend(newly_activated_nodes)
        print(f"All Activated Nodes: {all_activated_nodes}")
        print(f"Active Set Size: {active_set_size}")
        
        active_set_size, all_activated_nodes = model.random_deactivation(all_activated_nodes)
        print(f"Final Activated Nodes: {all_activated_nodes}")
        print(f"Final Active Set Size: {active_set_size}")
        print("")

        model.is_reset()
        active_ss_list.append(active_set_size)

    return influencers, active_ss_list[-1]

# %%
exp_i = 5
target_set_size = 5
r_total_activated_nodes = 0

for i in range(exp_i):
    influencers, active_set_size = random_sequential(g, target_set_size)
    r_total_activated_nodes += active_set_size

r_avg_activated_nodes = r_total_activated_nodes / exp_i
# Out:
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 95
# Newly Activated Nodes: []
# All Activated Nodes: [95]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [95]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 4
# Newly Activated Nodes: []
# All Activated Nodes: [95, 4]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [95]
# Final Activated Nodes: [4]
# Final Active Set Size: 1
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 121
# Newly Activated Nodes: []
# All Activated Nodes: [4, 121]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [4]
# Final Activated Nodes: [121]
# Final Active Set Size: 1
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 75
# Newly Activated Nodes: []
# All Activated Nodes: [121, 75]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [121, 75]
# Final Active Set Size: 2
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 64
# Newly Activated Nodes: []
# All Activated Nodes: [121, 75, 64]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [121]
# Final Activated Nodes: [75, 64]
# Final Active Set Size: 2
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 21
# Newly Activated Nodes: []
# All Activated Nodes: [21]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [21]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 87
# Newly Activated Nodes: []
# All Activated Nodes: [87]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [87]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 131
# Newly Activated Nodes: [127]
# All Activated Nodes: [127, 131]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [127, 131]
# Final Active Set Size: 2
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 39
# Newly Activated Nodes: []
# All Activated Nodes: [127, 131, 39]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [127]
# Final Activated Nodes: [131, 39]
# Final Active Set Size: 2
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 99
# Newly Activated Nodes: [127]
# All Activated Nodes: [131, 39, 127, 99]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [131, 39, 127, 99]
# Final Active Set Size: 4
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 61
# Newly Activated Nodes: [16]
# All Activated Nodes: [16, 61]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [61]
# Final Activated Nodes: [16]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 99
# Newly Activated Nodes: []
# All Activated Nodes: [16, 99]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [99]
# Final Activated Nodes: [16]
# Final Active Set Size: 1
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 42
# Newly Activated Nodes: []
# All Activated Nodes: [16, 42]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [42]
# Final Activated Nodes: [16]
# Final Active Set Size: 1
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 32
# Newly Activated Nodes: []
# All Activated Nodes: [16, 32]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [16, 32]
# Final Active Set Size: 2
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 26
# Newly Activated Nodes: []
# All Activated Nodes: [16, 32, 26]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [26]
# Final Activated Nodes: [16, 32]
# Final Active Set Size: 2
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 77
# Newly Activated Nodes: [0]
# All Activated Nodes: [0, 77]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [77]
# Final Activated Nodes: [0]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 35
# Newly Activated Nodes: []
# All Activated Nodes: [0, 35]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [0]
# Final Activated Nodes: [35]
# Final Active Set Size: 1
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 14
# Newly Activated Nodes: []
# All Activated Nodes: [35, 14]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [35]
# Final Activated Nodes: [14]
# Final Active Set Size: 1
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 47
# Newly Activated Nodes: []
# All Activated Nodes: [14, 47]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [47]
# Final Activated Nodes: [14]
# Final Active Set Size: 1
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 125
# Newly Activated Nodes: [0, 34, 87, 24]
# All Activated Nodes: [14, 0, 34, 87, 24, 125]
# Active Set Size: 6
# Number of deactivations: 1
# Deactivated Nodes: [24]
# Final Activated Nodes: [14, 0, 34, 87, 125]
# Final Active Set Size: 5
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 29
# Newly Activated Nodes: []
# All Activated Nodes: [29]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [29]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 24
# Newly Activated Nodes: []
# All Activated Nodes: [29, 24]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [24]
# Final Activated Nodes: [29]
# Final Active Set Size: 1
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 32
# Newly Activated Nodes: []
# All Activated Nodes: [29, 32]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [29, 32]
# Final Active Set Size: 2
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 147
# Newly Activated Nodes: []
# All Activated Nodes: [29, 32, 147]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [29, 32, 147]
# Final Active Set Size: 3
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 67
# Newly Activated Nodes: [52]
# All Activated Nodes: [29, 32, 147, 52, 67]
# Active Set Size: 5
# Number of deactivations: 1
# Deactivated Nodes: [32]
# Final Activated Nodes: [29, 147, 52, 67]
# Final Active Set Size: 4

# %%
print(g_avg_activated_nodes)
print(r_avg_activated_nodes)
# Out:
# 11.6
# 3.4
