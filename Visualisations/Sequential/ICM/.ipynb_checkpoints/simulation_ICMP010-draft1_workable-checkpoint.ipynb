# %%
import networkx as nx
import ModelConfig as mc
# import IndependentCascadesModelP001 as icm
import IndependentCascadesModelP010 as icm
# import WeightedCascadeModel as icm
import operator
import random 
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
def GreedySelect(g, activated_nodes, model, config, greedy_i):
    ''' 
    Select node with max average marginal gain
    Variable 'mg' refers to 'marginal gain'
    Number of iterations to find average marginal gain defaulted to 100
    '''
    mg_dict = {}
    for candidate in g.nodes():
        if candidate in activated_nodes:
            continue
        mg = 0
        for i in range(greedy_i):
            newly_activated_nodes = GreedySim(model, config, candidate)
            mg += len(newly_activated_nodes)
        avg_mg = mg/greedy_i
        mg_dict[candidate] = avg_mg
    influencer = max(mg_dict.items(), key=operator.itemgetter(1))[0]
    print(f"Selected Influencer: Node {influencer}")
    
    return influencer

def GreedySim(model, config, candidate):
    config.add_model_initial_configuration("Infected", [candidate])
    model.set_initial_status(config)
    active_set_size, newly_activated_nodes = model.iteration_bunch()
    newly_activated_nodes.append(candidate)
    model.mg_reset(newly_activated_nodes)
    
    return newly_activated_nodes

# %%
def InitModel(g):
    model = icm.IndependentCascadesModel(g)
    config = mc.Configuration()
    return model, config

def InfluenceSpread(model, config, influencer):
    config.add_model_initial_configuration("Infected", [influencer])
    model.set_initial_status(config)
    active_set_size, newly_activated_nodes = model.iteration_bunch()
    return active_set_size, newly_activated_nodes

def get_combination(g, target_set_size, greedy_i=100):
    '''
    Assuming continuous process (previously activated nodes cannot reattempt)
    As compared to one-time influence spread, all influencer same start point
    Default strategy set as greedy 
    '''
    # prepare graph for respective strategies
    g = remove_isolated_nodes(g)
        
    # initialize diffusion model
    model, config = InitModel(g)
    
    all_activated_nodes = []
    influencers = []
    active_ss_list = []
    for i in range(1, target_set_size+1):
        print(f"Selecting Influencer {i}")
        print("------------------------------------")
        
        influencer = GreedySelect(g, all_activated_nodes, model, config, greedy_i)
        influencers.append(influencer)

        active_set_size, newly_activated_nodes = InfluenceSpread(model, config, influencer)
        print(f"Newly Activated Nodes: {newly_activated_nodes}")
        newly_activated_nodes.append(influencer)
        all_activated_nodes.extend(newly_activated_nodes)
        print(f"All Activated Nodes: {all_activated_nodes}")
        print(f"Active Set Size: {active_set_size}")
        
        active_set_size, all_activated_nodes = model.random_deactivation(all_activated_nodes)
        print(f"Final Activated Nodes: {all_activated_nodes}")
        print(f"Final Active Set Size: {active_set_size}")
        print("")

        model.is_reset()
        active_ss_list.append(active_set_size)

    return influencers, active_ss_list[-1]

# %%
def remove_isolated_nodes(g):
    isolated_nodes = []
    for pair in g.degree:
        node = pair[0]
        degree = pair[1]
        if degree == 0:
            isolated_nodes.append(node)

    for node in isolated_nodes:
        g.remove_node(node)
        
    return g

# %%
# Simulation: Build Long Term Reward Reference

# %%
g = nx.erdos_renyi_graph(150, 0.1) #number of nodes, probability to form edges
g = remove_isolated_nodes(g)
target_set_size = 5
greedy_i = 10
LT_ref = []
num_i = 5
for i in range(1, num_i+1):
    print(f"Combination {i}")
    print("------------------------------------")
        
    combination = get_combination(g, target_set_size, greedy_i)
    LT_ref.append(combination)

LT_ref.sort(key=lambda x:x[1], reverse=True)
sorted_influencers = []
for influencers, LT_reward in LT_ref:
    if influencers in sorted_influencers:
        continue  
    sorted_influencers.append(influencers)
# Out:
# Combination 1
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 107
# Newly Activated Nodes: [33, 9, 16, 113, 122, 14, 37, 59, 91, 94, 98, 125, 6, 25, 36, 40, 64, 78, 111, 117, 119, 123, 134, 21, 28, 60, 66, 80, 84, 101, 104, 112, 132, 4, 10, 24, 42, 56, 88, 129, 147, 2, 102, 131, 141, 51, 69, 70, 90, 138, 71, 83, 85, 11, 29, 26, 43, 87, 97, 57, 143]
# All Activated Nodes: [33, 9, 16, 113, 122, 14, 37, 59, 91, 94, 98, 125, 6, 25, 36, 40, 64, 78, 111, 117, 119, 123, 134, 21, 28, 60, 66, 80, 84, 101, 104, 112, 132, 4, 10, 24, 42, 56, 88, 129, 147, 2, 102, 131, 141, 51, 69, 70, 90, 138, 71, 83, 85, 11, 29, 26, 43, 87, 97, 57, 143, 107]
# Active Set Size: 62
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [33, 9, 16, 113, 122, 14, 37, 59, 91, 94, 98, 125, 6, 25, 36, 40, 64, 78, 111, 117, 119, 123, 134, 21, 28, 60, 66, 80, 84, 101, 104, 112, 132, 4, 10, 24, 42, 56, 88, 129, 147, 2, 102, 131, 141, 51, 69, 70, 90, 138, 71, 83, 85, 11, 29, 26, 43, 87, 97, 57, 143, 107]
# Final Active Set Size: 62
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 100
# Newly Activated Nodes: [82, 136, 27, 127, 128, 72, 61, 106, 1, 44, 92]
# All Activated Nodes: [33, 9, 16, 113, 122, 14, 37, 59, 91, 94, 98, 125, 6, 25, 36, 40, 64, 78, 111, 117, 119, 123, 134, 21, 28, 60, 66, 80, 84, 101, 104, 112, 132, 4, 10, 24, 42, 56, 88, 129, 147, 2, 102, 131, 141, 51, 69, 70, 90, 138, 71, 83, 85, 11, 29, 26, 43, 87, 97, 57, 143, 107, 82, 136, 27, 127, 128, 72, 61, 106, 1, 44, 92, 100]
# Active Set Size: 74
# Number of deactivations: 4
# Deactivated Nodes: [136, 123, 4, 11]
# Final Activated Nodes: [33, 9, 16, 113, 122, 14, 37, 59, 91, 94, 98, 125, 6, 25, 36, 40, 64, 78, 111, 117, 119, 134, 21, 28, 60, 66, 80, 84, 101, 104, 112, 132, 10, 24, 42, 56, 88, 129, 147, 2, 102, 131, 141, 51, 69, 70, 90, 138, 71, 83, 85, 29, 26, 43, 87, 97, 57, 143, 107, 82, 27, 127, 128, 72, 61, 106, 1, 44, 92, 100]
# Final Active Set Size: 70
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 139
# Newly Activated Nodes: []
# All Activated Nodes: [33, 9, 16, 113, 122, 14, 37, 59, 91, 94, 98, 125, 6, 25, 36, 40, 64, 78, 111, 117, 119, 134, 21, 28, 60, 66, 80, 84, 101, 104, 112, 132, 10, 24, 42, 56, 88, 129, 147, 2, 102, 131, 141, 51, 69, 70, 90, 138, 71, 83, 85, 29, 26, 43, 87, 97, 57, 143, 107, 82, 27, 127, 128, 72, 61, 106, 1, 44, 92, 100, 139]
# Active Set Size: 71
# Number of deactivations: 4
# Deactivated Nodes: [139, 78, 56, 43]
# Final Activated Nodes: [33, 9, 16, 113, 122, 14, 37, 59, 91, 94, 98, 125, 6, 25, 36, 40, 64, 111, 117, 119, 134, 21, 28, 60, 66, 80, 84, 101, 104, 112, 132, 10, 24, 42, 88, 129, 147, 2, 102, 131, 141, 51, 69, 70, 90, 138, 71, 83, 85, 29, 26, 87, 97, 57, 143, 107, 82, 27, 127, 128, 72, 61, 106, 1, 44, 92, 100]
# Final Active Set Size: 67
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 34
# Newly Activated Nodes: [121, 79, 5]
# All Activated Nodes: [33, 9, 16, 113, 122, 14, 37, 59, 91, 94, 98, 125, 6, 25, 36, 40, 64, 111, 117, 119, 134, 21, 28, 60, 66, 80, 84, 101, 104, 112, 132, 10, 24, 42, 88, 129, 147, 2, 102, 131, 141, 51, 69, 70, 90, 138, 71, 83, 85, 29, 26, 87, 97, 57, 143, 107, 82, 27, 127, 128, 72, 61, 106, 1, 44, 92, 100, 121, 79, 5, 34]
# Active Set Size: 71
# Number of deactivations: 1
# Deactivated Nodes: [72]
# Final Activated Nodes: [33, 9, 16, 113, 122, 14, 37, 59, 91, 94, 98, 125, 6, 25, 36, 40, 64, 111, 117, 119, 134, 21, 28, 60, 66, 80, 84, 101, 104, 112, 132, 10, 24, 42, 88, 129, 147, 2, 102, 131, 141, 51, 69, 70, 90, 138, 71, 83, 85, 29, 26, 87, 97, 57, 143, 107, 82, 27, 127, 128, 61, 106, 1, 44, 92, 100, 121, 79, 5, 34]
# Final Active Set Size: 70
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 146
# Newly Activated Nodes: [32, 65]
# All Activated Nodes: [33, 9, 16, 113, 122, 14, 37, 59, 91, 94, 98, 125, 6, 25, 36, 40, 64, 111, 117, 119, 134, 21, 28, 60, 66, 80, 84, 101, 104, 112, 132, 10, 24, 42, 88, 129, 147, 2, 102, 131, 141, 51, 69, 70, 90, 138, 71, 83, 85, 29, 26, 87, 97, 57, 143, 107, 82, 27, 127, 128, 61, 106, 1, 44, 92, 100, 121, 79, 5, 34, 32, 65, 146]
# Active Set Size: 73
# Number of deactivations: 4
# Deactivated Nodes: [91, 143, 87, 27]
# Final Activated Nodes: [33, 9, 16, 113, 122, 14, 37, 59, 94, 98, 125, 6, 25, 36, 40, 64, 111, 117, 119, 134, 21, 28, 60, 66, 80, 84, 101, 104, 112, 132, 10, 24, 42, 88, 129, 147, 2, 102, 131, 141, 51, 69, 70, 90, 138, 71, 83, 85, 29, 26, 97, 57, 107, 82, 127, 128, 61, 106, 1, 44, 92, 100, 121, 79, 5, 34, 32, 65, 146]
# Final Active Set Size: 69
#
# Combination 2
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 39
# Newly Activated Nodes: [118, 144, 68, 72, 52, 79, 48, 96, 16, 19, 63, 104, 10, 53, 76, 47, 116, 2, 38, 41, 137, 44, 51, 70, 95, 103, 135, 50, 60, 122, 124, 133, 64, 84, 111, 55, 66, 75, 92, 100, 110, 49, 80, 109, 113, 126, 129, 136, 15, 37, 101, 140, 24, 125, 134, 12, 22, 130, 36, 61, 99, 8, 9, 107, 120, 6, 13, 33, 59, 3, 98, 149, 11, 45, 27, 40, 83]
# All Activated Nodes: [118, 144, 68, 72, 52, 79, 48, 96, 16, 19, 63, 104, 10, 53, 76, 47, 116, 2, 38, 41, 137, 44, 51, 70, 95, 103, 135, 50, 60, 122, 124, 133, 64, 84, 111, 55, 66, 75, 92, 100, 110, 49, 80, 109, 113, 126, 129, 136, 15, 37, 101, 140, 24, 125, 134, 12, 22, 130, 36, 61, 99, 8, 9, 107, 120, 6, 13, 33, 59, 3, 98, 149, 11, 45, 27, 40, 83, 39]
# Active Set Size: 78
# Number of deactivations: 2
# Deactivated Nodes: [83, 111]
# Final Activated Nodes: [118, 144, 68, 72, 52, 79, 48, 96, 16, 19, 63, 104, 10, 53, 76, 47, 116, 2, 38, 41, 137, 44, 51, 70, 95, 103, 135, 50, 60, 122, 124, 133, 64, 84, 55, 66, 75, 92, 100, 110, 49, 80, 109, 113, 126, 129, 136, 15, 37, 101, 140, 24, 125, 134, 12, 22, 130, 36, 61, 99, 8, 9, 107, 120, 6, 13, 33, 59, 3, 98, 149, 11, 45, 27, 40, 39]
# Final Active Set Size: 76
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 87
# Newly Activated Nodes: [34, 54]
# All Activated Nodes: [118, 144, 68, 72, 52, 79, 48, 96, 16, 19, 63, 104, 10, 53, 76, 47, 116, 2, 38, 41, 137, 44, 51, 70, 95, 103, 135, 50, 60, 122, 124, 133, 64, 84, 55, 66, 75, 92, 100, 110, 49, 80, 109, 113, 126, 129, 136, 15, 37, 101, 140, 24, 125, 134, 12, 22, 130, 36, 61, 99, 8, 9, 107, 120, 6, 13, 33, 59, 3, 98, 149, 11, 45, 27, 40, 39, 34, 54, 87]
# Active Set Size: 79
# Number of deactivations: 2
# Deactivated Nodes: [124, 54]
# Final Activated Nodes: [118, 144, 68, 72, 52, 79, 48, 96, 16, 19, 63, 104, 10, 53, 76, 47, 116, 2, 38, 41, 137, 44, 51, 70, 95, 103, 135, 50, 60, 122, 133, 64, 84, 55, 66, 75, 92, 100, 110, 49, 80, 109, 113, 126, 129, 136, 15, 37, 101, 140, 24, 125, 134, 12, 22, 130, 36, 61, 99, 8, 9, 107, 120, 6, 13, 33, 59, 3, 98, 149, 11, 45, 27, 40, 39, 34, 87]
# Final Active Set Size: 77
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 71
# Newly Activated Nodes: [111, 127, 23, 82, 128, 28, 17]
# All Activated Nodes: [118, 144, 68, 72, 52, 79, 48, 96, 16, 19, 63, 104, 10, 53, 76, 47, 116, 2, 38, 41, 137, 44, 51, 70, 95, 103, 135, 50, 60, 122, 133, 64, 84, 55, 66, 75, 92, 100, 110, 49, 80, 109, 113, 126, 129, 136, 15, 37, 101, 140, 24, 125, 134, 12, 22, 130, 36, 61, 99, 8, 9, 107, 120, 6, 13, 33, 59, 3, 98, 149, 11, 45, 27, 40, 39, 34, 87, 111, 127, 23, 82, 128, 28, 17, 71]
# Active Set Size: 85
# Number of deactivations: 3
# Deactivated Nodes: [99, 111, 71]
# Final Activated Nodes: [118, 144, 68, 72, 52, 79, 48, 96, 16, 19, 63, 104, 10, 53, 76, 47, 116, 2, 38, 41, 137, 44, 51, 70, 95, 103, 135, 50, 60, 122, 133, 64, 84, 55, 66, 75, 92, 100, 110, 49, 80, 109, 113, 126, 129, 136, 15, 37, 101, 140, 24, 125, 134, 12, 22, 130, 36, 61, 8, 9, 107, 120, 6, 13, 33, 59, 3, 98, 149, 11, 45, 27, 40, 39, 34, 87, 127, 23, 82, 128, 28, 17]
# Final Active Set Size: 82
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 147
# Newly Activated Nodes: [138]
# All Activated Nodes: [118, 144, 68, 72, 52, 79, 48, 96, 16, 19, 63, 104, 10, 53, 76, 47, 116, 2, 38, 41, 137, 44, 51, 70, 95, 103, 135, 50, 60, 122, 133, 64, 84, 55, 66, 75, 92, 100, 110, 49, 80, 109, 113, 126, 129, 136, 15, 37, 101, 140, 24, 125, 134, 12, 22, 130, 36, 61, 8, 9, 107, 120, 6, 13, 33, 59, 3, 98, 149, 11, 45, 27, 40, 39, 34, 87, 127, 23, 82, 128, 28, 17, 138, 147]
# Active Set Size: 84
# Number of deactivations: 3
# Deactivated Nodes: [23, 126, 6]
# Final Activated Nodes: [118, 144, 68, 72, 52, 79, 48, 96, 16, 19, 63, 104, 10, 53, 76, 47, 116, 2, 38, 41, 137, 44, 51, 70, 95, 103, 135, 50, 60, 122, 133, 64, 84, 55, 66, 75, 92, 100, 110, 49, 80, 109, 113, 129, 136, 15, 37, 101, 140, 24, 125, 134, 12, 22, 130, 36, 61, 8, 9, 107, 120, 13, 33, 59, 3, 98, 149, 11, 45, 27, 40, 39, 34, 87, 127, 82, 128, 28, 17, 138, 147]
# Final Active Set Size: 81
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 35
# Newly Activated Nodes: [26, 123]
# All Activated Nodes: [118, 144, 68, 72, 52, 79, 48, 96, 16, 19, 63, 104, 10, 53, 76, 47, 116, 2, 38, 41, 137, 44, 51, 70, 95, 103, 135, 50, 60, 122, 133, 64, 84, 55, 66, 75, 92, 100, 110, 49, 80, 109, 113, 129, 136, 15, 37, 101, 140, 24, 125, 134, 12, 22, 130, 36, 61, 8, 9, 107, 120, 13, 33, 59, 3, 98, 149, 11, 45, 27, 40, 39, 34, 87, 127, 82, 128, 28, 17, 138, 147, 26, 123, 35]
# Active Set Size: 84
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [118, 144, 68, 72, 52, 79, 48, 96, 16, 19, 63, 104, 10, 53, 76, 47, 116, 2, 38, 41, 137, 44, 51, 70, 95, 103, 135, 50, 60, 122, 133, 64, 84, 55, 66, 75, 92, 100, 110, 49, 80, 109, 113, 129, 136, 15, 37, 101, 140, 24, 125, 134, 12, 22, 130, 36, 61, 8, 9, 107, 120, 13, 33, 59, 3, 98, 149, 11, 45, 27, 40, 39, 34, 87, 127, 82, 128, 28, 17, 138, 147, 26, 123, 35]
# Final Active Set Size: 84
#
# Combination 3
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 38
# Newly Activated Nodes: [20, 28, 83, 89, 116, 9, 22, 23, 29, 41, 115, 120, 138, 2, 16, 25, 52, 57, 76, 82, 94, 104, 122, 137, 149, 17, 33, 37, 42, 53, 59, 67, 79, 96, 98, 127, 131, 135, 0, 4, 18, 21, 24, 34, 36, 43, 47, 50, 54, 62, 69, 71, 114, 124, 39, 84, 87, 88, 100, 105, 118, 128, 141, 145, 56, 126, 129, 140, 77, 92, 123, 139, 147, 1]
# All Activated Nodes: [20, 28, 83, 89, 116, 9, 22, 23, 29, 41, 115, 120, 138, 2, 16, 25, 52, 57, 76, 82, 94, 104, 122, 137, 149, 17, 33, 37, 42, 53, 59, 67, 79, 96, 98, 127, 131, 135, 0, 4, 18, 21, 24, 34, 36, 43, 47, 50, 54, 62, 69, 71, 114, 124, 39, 84, 87, 88, 100, 105, 118, 128, 141, 145, 56, 126, 129, 140, 77, 92, 123, 139, 147, 1, 38]
# Active Set Size: 75
# Number of deactivations: 2
# Deactivated Nodes: [67, 122]
# Final Activated Nodes: [20, 28, 83, 89, 116, 9, 22, 23, 29, 41, 115, 120, 138, 2, 16, 25, 52, 57, 76, 82, 94, 104, 137, 149, 17, 33, 37, 42, 53, 59, 79, 96, 98, 127, 131, 135, 0, 4, 18, 21, 24, 34, 36, 43, 47, 50, 54, 62, 69, 71, 114, 124, 39, 84, 87, 88, 100, 105, 118, 128, 141, 145, 56, 126, 129, 140, 77, 92, 123, 139, 147, 1, 38]
# Final Active Set Size: 73
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 102
# Newly Activated Nodes: []
# All Activated Nodes: [20, 28, 83, 89, 116, 9, 22, 23, 29, 41, 115, 120, 138, 2, 16, 25, 52, 57, 76, 82, 94, 104, 137, 149, 17, 33, 37, 42, 53, 59, 79, 96, 98, 127, 131, 135, 0, 4, 18, 21, 24, 34, 36, 43, 47, 50, 54, 62, 69, 71, 114, 124, 39, 84, 87, 88, 100, 105, 118, 128, 141, 145, 56, 126, 129, 140, 77, 92, 123, 139, 147, 1, 38, 102]
# Active Set Size: 74
# Number of deactivations: 2
# Deactivated Nodes: [116, 50]
# Final Activated Nodes: [20, 28, 83, 89, 9, 22, 23, 29, 41, 115, 120, 138, 2, 16, 25, 52, 57, 76, 82, 94, 104, 137, 149, 17, 33, 37, 42, 53, 59, 79, 96, 98, 127, 131, 135, 0, 4, 18, 21, 24, 34, 36, 43, 47, 54, 62, 69, 71, 114, 124, 39, 84, 87, 88, 100, 105, 118, 128, 141, 145, 56, 126, 129, 140, 77, 92, 123, 139, 147, 1, 38, 102]
# Final Active Set Size: 72
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 63
# Newly Activated Nodes: []
# All Activated Nodes: [20, 28, 83, 89, 9, 22, 23, 29, 41, 115, 120, 138, 2, 16, 25, 52, 57, 76, 82, 94, 104, 137, 149, 17, 33, 37, 42, 53, 59, 79, 96, 98, 127, 131, 135, 0, 4, 18, 21, 24, 34, 36, 43, 47, 54, 62, 69, 71, 114, 124, 39, 84, 87, 88, 100, 105, 118, 128, 141, 145, 56, 126, 129, 140, 77, 92, 123, 139, 147, 1, 38, 102, 63]
# Active Set Size: 73
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [20, 28, 83, 89, 9, 22, 23, 29, 41, 115, 120, 138, 2, 16, 25, 52, 57, 76, 82, 94, 104, 137, 149, 17, 33, 37, 42, 53, 59, 79, 96, 98, 127, 131, 135, 0, 4, 18, 21, 24, 34, 36, 43, 47, 54, 62, 69, 71, 114, 124, 39, 84, 87, 88, 100, 105, 118, 128, 141, 145, 56, 126, 129, 140, 77, 92, 123, 139, 147, 1, 38, 102, 63]
# Final Active Set Size: 73
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 50
# Newly Activated Nodes: [107, 65, 111, 73, 112]
# All Activated Nodes: [20, 28, 83, 89, 9, 22, 23, 29, 41, 115, 120, 138, 2, 16, 25, 52, 57, 76, 82, 94, 104, 137, 149, 17, 33, 37, 42, 53, 59, 79, 96, 98, 127, 131, 135, 0, 4, 18, 21, 24, 34, 36, 43, 47, 54, 62, 69, 71, 114, 124, 39, 84, 87, 88, 100, 105, 118, 128, 141, 145, 56, 126, 129, 140, 77, 92, 123, 139, 147, 1, 38, 102, 63, 107, 65, 111, 73, 112, 50]
# Active Set Size: 79
# Number of deactivations: 2
# Deactivated Nodes: [17, 76]
# Final Activated Nodes: [20, 28, 83, 89, 9, 22, 23, 29, 41, 115, 120, 138, 2, 16, 25, 52, 57, 82, 94, 104, 137, 149, 33, 37, 42, 53, 59, 79, 96, 98, 127, 131, 135, 0, 4, 18, 21, 24, 34, 36, 43, 47, 54, 62, 69, 71, 114, 124, 39, 84, 87, 88, 100, 105, 118, 128, 141, 145, 56, 126, 129, 140, 77, 92, 123, 139, 147, 1, 38, 102, 63, 107, 65, 111, 73, 112, 50]
# Final Active Set Size: 77
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 48
# Newly Activated Nodes: [74, 146]
# All Activated Nodes: [20, 28, 83, 89, 9, 22, 23, 29, 41, 115, 120, 138, 2, 16, 25, 52, 57, 82, 94, 104, 137, 149, 33, 37, 42, 53, 59, 79, 96, 98, 127, 131, 135, 0, 4, 18, 21, 24, 34, 36, 43, 47, 54, 62, 69, 71, 114, 124, 39, 84, 87, 88, 100, 105, 118, 128, 141, 145, 56, 126, 129, 140, 77, 92, 123, 139, 147, 1, 38, 102, 63, 107, 65, 111, 73, 112, 50, 74, 146, 48]
# Active Set Size: 80
# Number of deactivations: 3
# Deactivated Nodes: [118, 77, 111]
# Final Activated Nodes: [20, 28, 83, 89, 9, 22, 23, 29, 41, 115, 120, 138, 2, 16, 25, 52, 57, 82, 94, 104, 137, 149, 33, 37, 42, 53, 59, 79, 96, 98, 127, 131, 135, 0, 4, 18, 21, 24, 34, 36, 43, 47, 54, 62, 69, 71, 114, 124, 39, 84, 87, 88, 100, 105, 128, 141, 145, 56, 126, 129, 140, 92, 123, 139, 147, 1, 38, 102, 63, 107, 65, 73, 112, 50, 74, 146, 48]
# Final Active Set Size: 77
#
# Combination 4
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 19
# Newly Activated Nodes: [108, 136, 33, 114, 96, 98, 46, 107, 0, 17, 43, 48, 109, 145, 1, 3, 36, 55, 72, 87, 89, 95, 6, 27, 41, 65, 100, 111, 120, 139, 146, 18, 30, 31, 49, 71, 74, 75, 94, 99, 105, 106, 117, 126, 128, 144, 2, 26, 53, 56, 69, 77, 81, 88, 91, 92, 112, 141, 148, 8, 10, 29, 32, 47, 59, 61, 70, 83, 102, 110, 122, 127, 140, 11, 44, 64, 115, 134, 15, 42, 82, 52, 54, 80, 21, 73]
# All Activated Nodes: [108, 136, 33, 114, 96, 98, 46, 107, 0, 17, 43, 48, 109, 145, 1, 3, 36, 55, 72, 87, 89, 95, 6, 27, 41, 65, 100, 111, 120, 139, 146, 18, 30, 31, 49, 71, 74, 75, 94, 99, 105, 106, 117, 126, 128, 144, 2, 26, 53, 56, 69, 77, 81, 88, 91, 92, 112, 141, 148, 8, 10, 29, 32, 47, 59, 61, 70, 83, 102, 110, 122, 127, 140, 11, 44, 64, 115, 134, 15, 42, 82, 52, 54, 80, 21, 73, 19]
# Active Set Size: 87
# Number of deactivations: 2
# Deactivated Nodes: [95, 99]
# Final Activated Nodes: [108, 136, 33, 114, 96, 98, 46, 107, 0, 17, 43, 48, 109, 145, 1, 3, 36, 55, 72, 87, 89, 6, 27, 41, 65, 100, 111, 120, 139, 146, 18, 30, 31, 49, 71, 74, 75, 94, 105, 106, 117, 126, 128, 144, 2, 26, 53, 56, 69, 77, 81, 88, 91, 92, 112, 141, 148, 8, 10, 29, 32, 47, 59, 61, 70, 83, 102, 110, 122, 127, 140, 11, 44, 64, 115, 134, 15, 42, 82, 52, 54, 80, 21, 73, 19]
# Final Active Set Size: 85
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 50
# Newly Activated Nodes: [103, 142]
# All Activated Nodes: [108, 136, 33, 114, 96, 98, 46, 107, 0, 17, 43, 48, 109, 145, 1, 3, 36, 55, 72, 87, 89, 6, 27, 41, 65, 100, 111, 120, 139, 146, 18, 30, 31, 49, 71, 74, 75, 94, 105, 106, 117, 126, 128, 144, 2, 26, 53, 56, 69, 77, 81, 88, 91, 92, 112, 141, 148, 8, 10, 29, 32, 47, 59, 61, 70, 83, 102, 110, 122, 127, 140, 11, 44, 64, 115, 134, 15, 42, 82, 52, 54, 80, 21, 73, 19, 103, 142, 50]
# Active Set Size: 88
# Number of deactivations: 2
# Deactivated Nodes: [114, 141]
# Final Activated Nodes: [108, 136, 33, 96, 98, 46, 107, 0, 17, 43, 48, 109, 145, 1, 3, 36, 55, 72, 87, 89, 6, 27, 41, 65, 100, 111, 120, 139, 146, 18, 30, 31, 49, 71, 74, 75, 94, 105, 106, 117, 126, 128, 144, 2, 26, 53, 56, 69, 77, 81, 88, 91, 92, 112, 148, 8, 10, 29, 32, 47, 59, 61, 70, 83, 102, 110, 122, 127, 140, 11, 44, 64, 115, 134, 15, 42, 82, 52, 54, 80, 21, 73, 19, 103, 142, 50]
# Final Active Set Size: 86
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 79
# Newly Activated Nodes: [85]
# All Activated Nodes: [108, 136, 33, 96, 98, 46, 107, 0, 17, 43, 48, 109, 145, 1, 3, 36, 55, 72, 87, 89, 6, 27, 41, 65, 100, 111, 120, 139, 146, 18, 30, 31, 49, 71, 74, 75, 94, 105, 106, 117, 126, 128, 144, 2, 26, 53, 56, 69, 77, 81, 88, 91, 92, 112, 148, 8, 10, 29, 32, 47, 59, 61, 70, 83, 102, 110, 122, 127, 140, 11, 44, 64, 115, 134, 15, 42, 82, 52, 54, 80, 21, 73, 19, 103, 142, 50, 85, 79]
# Active Set Size: 88
# Number of deactivations: 4
# Deactivated Nodes: [21, 55, 105, 19]
# Final Activated Nodes: [108, 136, 33, 96, 98, 46, 107, 0, 17, 43, 48, 109, 145, 1, 3, 36, 72, 87, 89, 6, 27, 41, 65, 100, 111, 120, 139, 146, 18, 30, 31, 49, 71, 74, 75, 94, 106, 117, 126, 128, 144, 2, 26, 53, 56, 69, 77, 81, 88, 91, 92, 112, 148, 8, 10, 29, 32, 47, 59, 61, 70, 83, 102, 110, 122, 127, 140, 11, 44, 64, 115, 134, 15, 42, 82, 52, 54, 80, 73, 103, 142, 50, 85, 79]
# Final Active Set Size: 84
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 9
# Newly Activated Nodes: [97, 119, 21]
# All Activated Nodes: [108, 136, 33, 96, 98, 46, 107, 0, 17, 43, 48, 109, 145, 1, 3, 36, 72, 87, 89, 6, 27, 41, 65, 100, 111, 120, 139, 146, 18, 30, 31, 49, 71, 74, 75, 94, 106, 117, 126, 128, 144, 2, 26, 53, 56, 69, 77, 81, 88, 91, 92, 112, 148, 8, 10, 29, 32, 47, 59, 61, 70, 83, 102, 110, 122, 127, 140, 11, 44, 64, 115, 134, 15, 42, 82, 52, 54, 80, 73, 103, 142, 50, 85, 79, 97, 119, 21, 9]
# Active Set Size: 88
# Number of deactivations: 4
# Deactivated Nodes: [91, 42, 75, 17]
# Final Activated Nodes: [108, 136, 33, 96, 98, 46, 107, 0, 43, 48, 109, 145, 1, 3, 36, 72, 87, 89, 6, 27, 41, 65, 100, 111, 120, 139, 146, 18, 30, 31, 49, 71, 74, 94, 106, 117, 126, 128, 144, 2, 26, 53, 56, 69, 77, 81, 88, 92, 112, 148, 8, 10, 29, 32, 47, 59, 61, 70, 83, 102, 110, 122, 127, 140, 11, 44, 64, 115, 134, 15, 82, 52, 54, 80, 73, 103, 142, 50, 85, 79, 97, 119, 21, 9]
# Final Active Set Size: 84
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 101
# Newly Activated Nodes: [40, 58]
# All Activated Nodes: [108, 136, 33, 96, 98, 46, 107, 0, 43, 48, 109, 145, 1, 3, 36, 72, 87, 89, 6, 27, 41, 65, 100, 111, 120, 139, 146, 18, 30, 31, 49, 71, 74, 94, 106, 117, 126, 128, 144, 2, 26, 53, 56, 69, 77, 81, 88, 92, 112, 148, 8, 10, 29, 32, 47, 59, 61, 70, 83, 102, 110, 122, 127, 140, 11, 44, 64, 115, 134, 15, 82, 52, 54, 80, 73, 103, 142, 50, 85, 79, 97, 119, 21, 9, 40, 58, 101]
# Active Set Size: 87
# Number of deactivations: 3
# Deactivated Nodes: [8, 48, 9]
# Final Activated Nodes: [108, 136, 33, 96, 98, 46, 107, 0, 43, 109, 145, 1, 3, 36, 72, 87, 89, 6, 27, 41, 65, 100, 111, 120, 139, 146, 18, 30, 31, 49, 71, 74, 94, 106, 117, 126, 128, 144, 2, 26, 53, 56, 69, 77, 81, 88, 92, 112, 148, 10, 29, 32, 47, 59, 61, 70, 83, 102, 110, 122, 127, 140, 11, 44, 64, 115, 134, 15, 82, 52, 54, 80, 73, 103, 142, 50, 85, 79, 97, 119, 21, 40, 58, 101]
# Final Active Set Size: 84
#
# Combination 5
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 115
# Newly Activated Nodes: [94, 106, 67, 103, 79, 87, 110, 121, 86, 120, 143, 7, 127, 132]
# All Activated Nodes: [94, 106, 67, 103, 79, 87, 110, 121, 86, 120, 143, 7, 127, 132, 115]
# Active Set Size: 15
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [94, 106, 67, 103, 79, 87, 110, 121, 86, 120, 143, 7, 127, 132, 115]
# Final Active Set Size: 15
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 95
# Newly Activated Nodes: [89, 2, 18, 38, 43, 100]
# All Activated Nodes: [94, 106, 67, 103, 79, 87, 110, 121, 86, 120, 143, 7, 127, 132, 115, 89, 2, 18, 38, 43, 100, 95]
# Active Set Size: 22
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [94, 106, 67, 103, 79, 87, 110, 121, 86, 120, 143, 7, 127, 132, 115, 89, 2, 18, 38, 43, 100, 95]
# Final Active Set Size: 22
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 3
# Newly Activated Nodes: [16, 29, 51, 116, 131, 36, 107, 111, 112, 54, 59, 46, 64, 82, 6, 10, 37, 57, 19, 31, 63, 69, 28, 48, 119, 9, 17, 11, 114, 27, 42, 136, 128, 23]
# All Activated Nodes: [94, 106, 67, 103, 79, 87, 110, 121, 86, 120, 143, 7, 127, 132, 115, 89, 2, 18, 38, 43, 100, 95, 16, 29, 51, 116, 131, 36, 107, 111, 112, 54, 59, 46, 64, 82, 6, 10, 37, 57, 19, 31, 63, 69, 28, 48, 119, 9, 17, 11, 114, 27, 42, 136, 128, 23, 3]
# Active Set Size: 57
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [94, 106, 67, 103, 79, 87, 110, 121, 86, 120, 143, 7, 127, 132, 115, 89, 2, 18, 38, 43, 100, 95, 16, 29, 51, 116, 131, 36, 107, 111, 112, 54, 59, 46, 64, 82, 6, 10, 37, 57, 19, 31, 63, 69, 28, 48, 119, 9, 17, 11, 114, 27, 42, 136, 128, 23, 3]
# Final Active Set Size: 57
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 50
# Newly Activated Nodes: [109, 97, 137]
# All Activated Nodes: [94, 106, 67, 103, 79, 87, 110, 121, 86, 120, 143, 7, 127, 132, 115, 89, 2, 18, 38, 43, 100, 95, 16, 29, 51, 116, 131, 36, 107, 111, 112, 54, 59, 46, 64, 82, 6, 10, 37, 57, 19, 31, 63, 69, 28, 48, 119, 9, 17, 11, 114, 27, 42, 136, 128, 23, 3, 109, 97, 137, 50]
# Active Set Size: 61
# Number of deactivations: 2
# Deactivated Nodes: [132, 136]
# Final Activated Nodes: [94, 106, 67, 103, 79, 87, 110, 121, 86, 120, 143, 7, 127, 115, 89, 2, 18, 38, 43, 100, 95, 16, 29, 51, 116, 131, 36, 107, 111, 112, 54, 59, 46, 64, 82, 6, 10, 37, 57, 19, 31, 63, 69, 28, 48, 119, 9, 17, 11, 114, 27, 42, 128, 23, 3, 109, 97, 137, 50]
# Final Active Set Size: 59
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 85
# Newly Activated Nodes: []
# All Activated Nodes: [94, 106, 67, 103, 79, 87, 110, 121, 86, 120, 143, 7, 127, 115, 89, 2, 18, 38, 43, 100, 95, 16, 29, 51, 116, 131, 36, 107, 111, 112, 54, 59, 46, 64, 82, 6, 10, 37, 57, 19, 31, 63, 69, 28, 48, 119, 9, 17, 11, 114, 27, 42, 128, 23, 3, 109, 97, 137, 50, 85]
# Active Set Size: 60
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [94, 106, 67, 103, 79, 87, 110, 121, 86, 120, 143, 7, 127, 115, 89, 2, 18, 38, 43, 100, 95, 16, 29, 51, 116, 131, 36, 107, 111, 112, 54, 59, 46, 64, 82, 6, 10, 37, 57, 19, 31, 63, 69, 28, 48, 119, 9, 17, 11, 114, 27, 42, 128, 23, 3, 109, 97, 137, 50, 85]
# Final Active Set Size: 60

# %%
print(LT_ref)
print("")
print(sorted_influencers)
# Out:
# [([39, 87, 71, 147, 35], 84), ([19, 50, 79, 9, 101], 84), ([38, 102, 63, 50, 48], 77), ([107, 100, 139, 34, 146], 69), ([115, 95, 3, 50, 85], 60)]
#
# [[39, 87, 71, 147, 35], [19, 50, 79, 9, 101], [38, 102, 63, 50, 48], [107, 100, 139, 34, 146], [115, 95, 3, 50, 85]]

# %%
# Actual Influence Spread

# %%
def check_reference(sorted_influencers, all_activated_nodes, i, model, config):
    influencer = sorted_influencers[0][i]
    j = 1
    while influencer in all_activated_nodes:
        try:   
            influencer = sorted_influencers[j][i]
            j += 1
        except IndexError:
            influencer = GreedySelect(g, all_activated_nodes, model, config, greedy_i)

    # Filter sorted influencers for unmatching combinations
    print(f"Influencer: Node {influencer}")
    n = []
    for combination in sorted_influencers:
        if combination[i] == influencer:
            n.append(combination)
    print(f"New Sorted Combination List: {n}")
    sorted_influencers = n
    return influencer, sorted_influencers

def greedy_sequential(g, target_set_size, greedy_i, sorted_influencers):
    '''
    Assuming continuous process (previously activated nodes cannot reattempt)
    As compared to one-time influence spread, all influencer same start point
    Default strategy set as greedy 
    '''
    # prepare graph for respective strategies
    g = remove_isolated_nodes(g)
        
    # initialize diffusion model
    model, config = InitModel(g)
    
    all_activated_nodes = []
    influencers = []
    active_ss_list = []
    
    for i in range(target_set_size):
        print(f"Selecting Influencer {i+1}")
        print("------------------------------------")
        
        if sorted_influencers == []: # If no matching combination, simulate greedy
            influencer = GreedySelect(g, all_activated_nodes, model, config, greedy_i)
            print("Approach: Greedy Select")
        else: # Check LT Reward Reference
            influencer, sorted_influencers = check_reference(sorted_influencers, all_activated_nodes, i, model, config)
            print("Approach: LT Reward Reference")
            
        influencers.append(influencer)

        active_set_size, newly_activated_nodes = InfluenceSpread(model, config, influencer)
        print(f"Newly Activated Nodes: {newly_activated_nodes}")
        newly_activated_nodes.append(influencer)
        all_activated_nodes.extend(newly_activated_nodes)
        print(f"All Activated Nodes: {all_activated_nodes}")
        print(f"Active Set Size: {active_set_size}")
        
        active_set_size, all_activated_nodes = model.random_deactivation(all_activated_nodes)
        print(f"Final Activated Nodes: {all_activated_nodes}")
        print(f"Final Active Set Size: {active_set_size}")
        print("")

        model.is_reset()
        active_ss_list.append(active_set_size)

    return influencers, active_ss_list[-1]

# %%
target_set_size = 5
greedy_i = 10
influencers, active_set_size = greedy_sequential(g, target_set_size, greedy_i, sorted_influencers)
print(influencers)
print(active_set_size)
# Out:
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 39
# New Sorted Combination List: [[39, 87, 71, 147, 35]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [39]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [39]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 87
# New Sorted Combination List: [[39, 87, 71, 147, 35]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [71, 69, 89, 27, 38, 83, 28, 70, 104, 107, 110, 136, 10, 17, 92, 128, 145, 4, 30, 42, 55, 82, 109, 147, 23, 37, 41, 50, 112, 115, 120, 133, 18, 36, 45, 54, 56, 62, 73, 76, 84, 111, 124, 137, 141, 143, 20, 31, 75, 108, 149, 29, 44, 81, 132]
# All Activated Nodes: [71, 69, 89, 27, 38, 83, 28, 70, 104, 107, 110, 136, 10, 17, 92, 128, 145, 4, 30, 42, 55, 82, 109, 147, 23, 37, 41, 50, 112, 115, 120, 133, 18, 36, 45, 54, 56, 62, 73, 76, 84, 111, 124, 137, 141, 143, 20, 31, 75, 108, 149, 29, 44, 81, 132, 87]
# Active Set Size: 56
# Number of deactivations: 1
# Deactivated Nodes: [17]
# Final Activated Nodes: [71, 69, 89, 27, 38, 83, 28, 70, 104, 107, 110, 136, 10, 92, 128, 145, 4, 30, 42, 55, 82, 109, 147, 23, 37, 41, 50, 112, 115, 120, 133, 18, 36, 45, 54, 56, 62, 73, 76, 84, 111, 124, 137, 141, 143, 20, 31, 75, 108, 149, 29, 44, 81, 132, 87]
# Final Active Set Size: 55
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 16
# Influencer: Node 16
# New Sorted Combination List: []
# Approach: LT Reward Reference
# Newly Activated Nodes: [113, 14, 68, 105, 25, 72, 79, 138, 77, 116, 121, 3, 86, 80]
# All Activated Nodes: [71, 69, 89, 27, 38, 83, 28, 70, 104, 107, 110, 136, 10, 92, 128, 145, 4, 30, 42, 55, 82, 109, 147, 23, 37, 41, 50, 112, 115, 120, 133, 18, 36, 45, 54, 56, 62, 73, 76, 84, 111, 124, 137, 141, 143, 20, 31, 75, 108, 149, 29, 44, 81, 132, 87, 113, 14, 68, 105, 25, 72, 79, 138, 77, 116, 121, 3, 86, 80, 16]
# Active Set Size: 70
# Number of deactivations: 1
# Deactivated Nodes: [92]
# Final Activated Nodes: [71, 69, 89, 27, 38, 83, 28, 70, 104, 107, 110, 136, 10, 128, 145, 4, 30, 42, 55, 82, 109, 147, 23, 37, 41, 50, 112, 115, 120, 133, 18, 36, 45, 54, 56, 62, 73, 76, 84, 111, 124, 137, 141, 143, 20, 31, 75, 108, 149, 29, 44, 81, 132, 87, 113, 14, 68, 105, 25, 72, 79, 138, 77, 116, 121, 3, 86, 80, 16]
# Final Active Set Size: 69
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 119
# Approach: Greedy Select
# Newly Activated Nodes: [26, 52, 134, 96, 98]
# All Activated Nodes: [71, 69, 89, 27, 38, 83, 28, 70, 104, 107, 110, 136, 10, 128, 145, 4, 30, 42, 55, 82, 109, 147, 23, 37, 41, 50, 112, 115, 120, 133, 18, 36, 45, 54, 56, 62, 73, 76, 84, 111, 124, 137, 141, 143, 20, 31, 75, 108, 149, 29, 44, 81, 132, 87, 113, 14, 68, 105, 25, 72, 79, 138, 77, 116, 121, 3, 86, 80, 16, 26, 52, 134, 96, 98, 119]
# Active Set Size: 75
# Number of deactivations: 4
# Deactivated Nodes: [28, 79, 41, 89]
# Final Activated Nodes: [71, 69, 27, 38, 83, 70, 104, 107, 110, 136, 10, 128, 145, 4, 30, 42, 55, 82, 109, 147, 23, 37, 50, 112, 115, 120, 133, 18, 36, 45, 54, 56, 62, 73, 76, 84, 111, 124, 137, 141, 143, 20, 31, 75, 108, 149, 29, 44, 81, 132, 87, 113, 14, 68, 105, 25, 72, 138, 77, 116, 121, 3, 86, 80, 16, 26, 52, 134, 96, 98, 119]
# Final Active Set Size: 71
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 118
# Approach: Greedy Select
# Newly Activated Nodes: [19]
# All Activated Nodes: [71, 69, 27, 38, 83, 70, 104, 107, 110, 136, 10, 128, 145, 4, 30, 42, 55, 82, 109, 147, 23, 37, 50, 112, 115, 120, 133, 18, 36, 45, 54, 56, 62, 73, 76, 84, 111, 124, 137, 141, 143, 20, 31, 75, 108, 149, 29, 44, 81, 132, 87, 113, 14, 68, 105, 25, 72, 138, 77, 116, 121, 3, 86, 80, 16, 26, 52, 134, 96, 98, 119, 19, 118]
# Active Set Size: 73
# Number of deactivations: 4
# Deactivated Nodes: [44, 45, 107, 141]
# Final Activated Nodes: [71, 69, 27, 38, 83, 70, 104, 110, 136, 10, 128, 145, 4, 30, 42, 55, 82, 109, 147, 23, 37, 50, 112, 115, 120, 133, 18, 36, 54, 56, 62, 73, 76, 84, 111, 124, 137, 143, 20, 31, 75, 108, 149, 29, 81, 132, 87, 113, 14, 68, 105, 25, 72, 138, 77, 116, 121, 3, 86, 80, 16, 26, 52, 134, 96, 98, 119, 19, 118]
# Final Active Set Size: 69
#
# [39, 87, 16, 119, 118]
# 69

# %%
def random_sequential(g, target_set_size):
    '''
    Assuming continuous process (previously activated nodes cannot reattempt)
    As compared to one-time influence spread, all influencer same start point
    Default strategy set as greedy 
    '''
    # prepare graph for respective strategies
    g = remove_isolated_nodes(g)
        
    # initialize diffusion model
    model, config = InitModel(g)
    
    all_activated_nodes = []
    influencers = []
    active_ss_list = []
    
    for i in range(target_set_size):
        print(f"Selecting Influencer {i+1}")
        print("------------------------------------")
        
        influencer = random.randint(0, len(g)-1)
        while influencer in all_activated_nodes:
            influencer = random.randint(0, len(g)-1)
        print(f"Influencer: Node {influencer}")
            
        influencers.append(influencer)

        active_set_size, newly_activated_nodes = InfluenceSpread(model, config, influencer)
        print(f"Newly Activated Nodes: {newly_activated_nodes}")
        newly_activated_nodes.append(influencer)
        all_activated_nodes.extend(newly_activated_nodes)
        print(f"All Activated Nodes: {all_activated_nodes}")
        print(f"Active Set Size: {active_set_size}")
        
        active_set_size, all_activated_nodes = model.random_deactivation(all_activated_nodes)
        print(f"Final Activated Nodes: {all_activated_nodes}")
        print(f"Final Active Set Size: {active_set_size}")
        print("")

        model.is_reset()
        active_ss_list.append(active_set_size)

    return influencers, active_ss_list[-1]

# %%
exp_i = 20
target_set_size = 5
r_total_activated_nodes = 0

for i in range(exp_i):
    influencers, active_set_size = random_sequential(g, target_set_size)
    r_total_activated_nodes += active_set_size

r_avg_activated_nodes = r_total_activated_nodes / exp_i
# Out:
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 58
# Newly Activated Nodes: [93, 62, 94, 45, 32, 44, 144, 81, 99, 139, 71, 132, 89, 98, 116, 143, 2, 23, 29, 43, 59, 95, 49, 54, 105, 107, 125, 127, 64, 69, 91, 109, 111, 134, 145, 6, 28, 33, 48, 53, 60, 67, 83, 110, 12, 25, 77, 87, 88, 104, 122, 135, 136, 1, 50, 66, 92, 97, 123, 124, 0, 8, 15, 47, 56, 79, 115, 141, 19, 37, 41, 76, 148, 9, 27, 36, 121, 31, 128, 72, 106]
# All Activated Nodes: [93, 62, 94, 45, 32, 44, 144, 81, 99, 139, 71, 132, 89, 98, 116, 143, 2, 23, 29, 43, 59, 95, 49, 54, 105, 107, 125, 127, 64, 69, 91, 109, 111, 134, 145, 6, 28, 33, 48, 53, 60, 67, 83, 110, 12, 25, 77, 87, 88, 104, 122, 135, 136, 1, 50, 66, 92, 97, 123, 124, 0, 8, 15, 47, 56, 79, 115, 141, 19, 37, 41, 76, 148, 9, 27, 36, 121, 31, 128, 72, 106, 58]
# Active Set Size: 82
# Number of deactivations: 5
# Deactivated Nodes: [93, 77, 58, 28, 115]
# Final Activated Nodes: [62, 94, 45, 32, 44, 144, 81, 99, 139, 71, 132, 89, 98, 116, 143, 2, 23, 29, 43, 59, 95, 49, 54, 105, 107, 125, 127, 64, 69, 91, 109, 111, 134, 145, 6, 33, 48, 53, 60, 67, 83, 110, 12, 25, 87, 88, 104, 122, 135, 136, 1, 50, 66, 92, 97, 123, 124, 0, 8, 15, 47, 56, 79, 141, 19, 37, 41, 76, 148, 9, 27, 36, 121, 31, 128, 72, 106]
# Final Active Set Size: 77
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 108
# Newly Activated Nodes: []
# All Activated Nodes: [62, 94, 45, 32, 44, 144, 81, 99, 139, 71, 132, 89, 98, 116, 143, 2, 23, 29, 43, 59, 95, 49, 54, 105, 107, 125, 127, 64, 69, 91, 109, 111, 134, 145, 6, 33, 48, 53, 60, 67, 83, 110, 12, 25, 87, 88, 104, 122, 135, 136, 1, 50, 66, 92, 97, 123, 124, 0, 8, 15, 47, 56, 79, 141, 19, 37, 41, 76, 148, 9, 27, 36, 121, 31, 128, 72, 106, 108]
# Active Set Size: 78
# Number of deactivations: 4
# Deactivated Nodes: [66, 145, 105, 69]
# Final Activated Nodes: [62, 94, 45, 32, 44, 144, 81, 99, 139, 71, 132, 89, 98, 116, 143, 2, 23, 29, 43, 59, 95, 49, 54, 107, 125, 127, 64, 91, 109, 111, 134, 6, 33, 48, 53, 60, 67, 83, 110, 12, 25, 87, 88, 104, 122, 135, 136, 1, 50, 92, 97, 123, 124, 0, 8, 15, 47, 56, 79, 141, 19, 37, 41, 76, 148, 9, 27, 36, 121, 31, 128, 72, 106, 108]
# Final Active Set Size: 74
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 39
# Newly Activated Nodes: []
# All Activated Nodes: [62, 94, 45, 32, 44, 144, 81, 99, 139, 71, 132, 89, 98, 116, 143, 2, 23, 29, 43, 59, 95, 49, 54, 107, 125, 127, 64, 91, 109, 111, 134, 6, 33, 48, 53, 60, 67, 83, 110, 12, 25, 87, 88, 104, 122, 135, 136, 1, 50, 92, 97, 123, 124, 0, 8, 15, 47, 56, 79, 141, 19, 37, 41, 76, 148, 9, 27, 36, 121, 31, 128, 72, 106, 108, 39]
# Active Set Size: 75
# Number of deactivations: 1
# Deactivated Nodes: [36]
# Final Activated Nodes: [62, 94, 45, 32, 44, 144, 81, 99, 139, 71, 132, 89, 98, 116, 143, 2, 23, 29, 43, 59, 95, 49, 54, 107, 125, 127, 64, 91, 109, 111, 134, 6, 33, 48, 53, 60, 67, 83, 110, 12, 25, 87, 88, 104, 122, 135, 136, 1, 50, 92, 97, 123, 124, 0, 8, 15, 47, 56, 79, 141, 19, 37, 41, 76, 148, 9, 27, 121, 31, 128, 72, 106, 108, 39]
# Final Active Set Size: 74
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 20
# Newly Activated Nodes: []
# All Activated Nodes: [62, 94, 45, 32, 44, 144, 81, 99, 139, 71, 132, 89, 98, 116, 143, 2, 23, 29, 43, 59, 95, 49, 54, 107, 125, 127, 64, 91, 109, 111, 134, 6, 33, 48, 53, 60, 67, 83, 110, 12, 25, 87, 88, 104, 122, 135, 136, 1, 50, 92, 97, 123, 124, 0, 8, 15, 47, 56, 79, 141, 19, 37, 41, 76, 148, 9, 27, 121, 31, 128, 72, 106, 108, 39, 20]
# Active Set Size: 75
# Number of deactivations: 1
# Deactivated Nodes: [23]
# Final Activated Nodes: [62, 94, 45, 32, 44, 144, 81, 99, 139, 71, 132, 89, 98, 116, 143, 2, 29, 43, 59, 95, 49, 54, 107, 125, 127, 64, 91, 109, 111, 134, 6, 33, 48, 53, 60, 67, 83, 110, 12, 25, 87, 88, 104, 122, 135, 136, 1, 50, 92, 97, 123, 124, 0, 8, 15, 47, 56, 79, 141, 19, 37, 41, 76, 148, 9, 27, 121, 31, 128, 72, 106, 108, 39, 20]
# Final Active Set Size: 74
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 129
# Newly Activated Nodes: []
# All Activated Nodes: [62, 94, 45, 32, 44, 144, 81, 99, 139, 71, 132, 89, 98, 116, 143, 2, 29, 43, 59, 95, 49, 54, 107, 125, 127, 64, 91, 109, 111, 134, 6, 33, 48, 53, 60, 67, 83, 110, 12, 25, 87, 88, 104, 122, 135, 136, 1, 50, 92, 97, 123, 124, 0, 8, 15, 47, 56, 79, 141, 19, 37, 41, 76, 148, 9, 27, 121, 31, 128, 72, 106, 108, 39, 20, 129]
# Active Set Size: 75
# Number of deactivations: 3
# Deactivated Nodes: [99, 37, 1]
# Final Activated Nodes: [62, 94, 45, 32, 44, 144, 81, 139, 71, 132, 89, 98, 116, 143, 2, 29, 43, 59, 95, 49, 54, 107, 125, 127, 64, 91, 109, 111, 134, 6, 33, 48, 53, 60, 67, 83, 110, 12, 25, 87, 88, 104, 122, 135, 136, 50, 92, 97, 123, 124, 0, 8, 15, 47, 56, 79, 141, 19, 41, 76, 148, 9, 27, 121, 31, 128, 72, 106, 108, 39, 20, 129]
# Final Active Set Size: 72
#
# [58, 108, 39, 20, 129]
# 72
