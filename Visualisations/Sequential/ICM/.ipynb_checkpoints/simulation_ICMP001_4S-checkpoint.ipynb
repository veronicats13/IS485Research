# %%
import networkx as nx
import ModelConfig as mc
import IndependentCascadesModelP001 as icm
# import IndependentCascadesModelP010 as icm
# import WeightedCascadeModel as icm
import operator
import random 
import matplotlib.pyplot as plt
import numpy as np

# %%
def GreedySelect(g, activated_nodes, num_iterations=100):
    ''' 
    Select node with max average marginal gain
    Variable 'mg' refers to 'marginal gain'
    Number of iterations to find average marginal gain defaulted to 100
    '''
    
    mg_dict = {}
    temp_activated_nodes = []
    for candidate in g.nodes():
        if candidate in activated_nodes:
            continue
            
        temp_activated_nodes.clear()
        temp_activated_nodes.extend(activated_nodes)
        mg = 1 #count the influencer candidate node already

        for i in range(num_iterations):
            model = icm.IndependentCascadesModel(g) 
            config = mc.Configuration()
            for n in g.nodes():
                if n in temp_activated_nodes:
                    config.add_node_configuration("attempt", n, 1)
                else:
                    config.add_node_configuration("attempt", n, 0)
            temp_activated_nodes.append(candidate)
            config.add_model_initial_configuration("Infected", temp_activated_nodes)
            model.set_initial_status(config)
            iterations = model.iteration_bunch()

            for i in range(1,len(iterations)):
                for node in iterations[i]['status']:
                    mg += 1

        avg_mg = mg/num_iterations
        mg_dict[candidate] = avg_mg
    
    influencer = max(mg_dict.items(), key=operator.itemgetter(1))[0]
    
    print(mg_dict)
    print(f"Selected Influencer: Node {influencer}")
    print("")
    
    return influencer

# %%
def HighDegreeSelect(g, sorted_g, activated_nodes):
    ''' 
    Select node with highest degree/number of neighbours
    Node cannot be previously activated
    '''
    
    for pair in sorted_g:
        candidate = pair[0]
        if candidate in activated_nodes:
            continue
        influencer = candidate
        neighbors = list(g.neighbors(influencer))
        
        print(f"Activated Nodes: {activated_nodes}")
        print(f"Influencer: Node {influencer}")
        print(f"Degree: {pair[1]}")
        print(f"Neighbors: Nodes {neighbors}")
        print("")
        
        return influencer

# %%
def RandomSelect(g, activated_nodes):
    ''' 
    Select node with highest degree/number of neighbours
    Node cannot be previously activated
    '''
    
    selected = False
    while not selected:
        candidate = random.randint(0,len(g)-1)
        if candidate not in activated_nodes:
            influencer = candidate
            selected = True
    neighbors = list(g.neighbors(influencer))
    degree = len(neighbors)
        
    print(f"Activated Nodes: {activated_nodes}")
    print(f"Influencer: Node {influencer}")
    print(f"Degree: {degree}")
    print(f"Neighbors: Nodes {neighbors}")
    print("")
    
    return influencer

# %%
def CentralitySort(g):
    '''
    Returns dictionary storing the average shortest distance of each node 
    '''
    asd_dict = {} 

    for node in g.nodes():
        count_dist = 0
        node_paths = nx.shortest_path(g)[node]
        for value in node_paths.values():
            count_dist += len(value) - 1 # excluding start node
        asd_dict[node] = count_dist/len(g)
    
    sorted_g = dict(sorted(asd_dict.items(), key=lambda item: item[1]))
    return sorted_g

def CentralitySelect(sorted_g, activated_nodes):
    ''' 
    Select node with highest shortest average distance
    Node cannot be previously activated
    '''
    
    for pair in sorted_g.items():
        candidate = pair[0]
        if candidate in activated_nodes:
            continue
        influencer = candidate
        
        print(f"Activated Nodes: {activated_nodes}")
        print(f"Influencer: Node {influencer}")
        print(f"Node's ASP: {pair[1]}")
        print("")
        
        return influencer

# %%
def remove_isolated_nodes(g):
    isolated_nodes = []
    for pair in g.degree():
        node = pair[0]
        degree = pair[1]
        if degree == 0:
            isolated_nodes.append(node)

    for node in isolated_nodes:
        g.remove_node(node)
        
    return g

# %%
def InfluenceSpread(g, target_set_size, num_iterations=100, strategy='greedy'):
    '''
    Assuming continuous process (previously activated nodes cannot reattempt)
    As compared to one-time influence spread, all influencer same start point
    Default strategy set as greedy 
    '''
    g = remove_isolated_nodes(g)
    
    if strategy == 'centrality':
        sorted_g = CentralitySort(g)
    elif strategy == 'highdegree':
        sorted_g = sorted(g.degree, key=lambda x: x[1], reverse=True)
    
    activated_nodes = []
    influencers_list = []
    for i in range(target_set_size):
        print(f"Selecting Influencer {i+1}")
        print("------------------------------------")
        
        if strategy == 'greedy':
            influencer = GreedySelect(g, activated_nodes, num_iterations)
        elif strategy == 'highdegree':
            influencer = HighDegreeSelect(g, sorted_g, activated_nodes)
        elif strategy == 'random':
            influencer = RandomSelect(g, activated_nodes)
        elif strategy == 'centrality':
            influencer = CentralitySelect(sorted_g, activated_nodes)
        influencers_list.append(influencer)
        model = icm.IndependentCascadesModel(g) 
        config = mc.Configuration()
        
        for n in g.nodes():
            if n in activated_nodes:
                config.add_node_configuration("attempt", n, 1)
            else:
                config.add_node_configuration("attempt", n, 0)
                
        activated_nodes.append(influencer)
        config.add_model_initial_configuration("Infected", activated_nodes)        
        model.set_initial_status(config)
        iterations = model.iteration_bunch()
        
        for i in range(1,len(iterations)):
            for node in iterations[i]['status']:
                activated_nodes.append(node)
                
    active_set_size = len(activated_nodes)
    return influencers_list, active_set_size

# %%
g = nx.erdos_renyi_graph(150, 0.1) #number of nodes, probability to form edges

random_as_list = []
for i in range(30):
    target_set_size = i
    num_iterations = 100
    strategy = 'random'
    _, active_set_size = InfluenceSpread(g, target_set_size, num_iterations, strategy)
    random_as_list.append(active_set_size)
random_as_list = np.array(random_as_list)

centrality_as_list = []
for i in range(30):
    target_set_size = i
    num_iterations = 100
    strategy = 'centrality'
    _, active_set_size = InfluenceSpread(g, target_set_size, num_iterations, strategy)
    centrality_as_list.append(active_set_size)
centrality_as_list = np.array(centrality_as_list)

highdegree_as_list = []
for i in range(30):
    target_set_size = i
    num_iterations = 100
    strategy = 'highdegree'
    _, active_set_size = InfluenceSpread(g, target_set_size, num_iterations, strategy)
    highdegree_as_list.append(active_set_size)
highdegree_as_list = np.array(highdegree_as_list)

greedy_as_list = []
for i in range(5):
    target_set_size = i
    num_iterations = 1
    strategy = 'greedy'
    _, active_set_size = InfluenceSpread(g, target_set_size, num_iterations, strategy)
    greedy_as_list.append(active_set_size)
greedy_as_list = np.array(greedy_as_list)
# Out:
# Selecting Influencer 1
# ------------------------------------
# Activated Nodes: []
# Influencer: Node 127
# Degree: 17
# Neighbors: Nodes [1, 15, 22, 29, 39, 41, 50, 51, 63, 75, 86, 103, 118, 121, 125, 135, 145]
#
# Selecting Influencer 1
# ------------------------------------
# Activated Nodes: []
# Influencer: Node 1
# Degree: 20
# Neighbors: Nodes [5, 11, 38, 40, 41, 45, 46, 47, 52, 65, 76, 85, 88, 98, 105, 119, 124, 127, 143, 148]
#
# Selecting Influencer 2
# ------------------------------------
# Activated Nodes: [1]
# Influencer: Node 9
# Degree: 12
# Neighbors: Nodes [5, 23, 49, 76, 77, 89, 97, 98, 106, 113, 144, 145]
#
# Selecting Influencer 1
# ------------------------------------
# Activated Nodes: []
# Influencer: Node 35
# Degree: 13
# Neighbors: Nodes [2, 3, 13, 24, 43, 50, 51, 64, 68, 88, 112, 123, 135]
#
# Selecting Influencer 2
# ------------------------------------
# Activated Nodes: [35]
# Influencer: Node 10
# Degree: 16
# Neighbors: Nodes [7, 22, 24, 27, 34, 45, 56, 61, 66, 72, 75, 93, 101, 111, 124, 141]
#
# Selecting Influencer 3
# ------------------------------------
# Activated Nodes: [35, 10]
# Influencer: Node 65
# Degree: 10
# Neighbors: Nodes [1, 19, 43, 55, 64, 89, 99, 123, 139, 144]
#
# Selecting Influencer 1
# ------------------------------------
# Activated Nodes: []
# Influencer: Node 90
# Degree: 10
# Neighbors: Nodes [15, 27, 28, 53, 75, 79, 87, 96, 118, 131]
#
# Selecting Influencer 2
# ------------------------------------
# Activated Nodes: [90]
# Influencer: Node 88
# Degree: 24
# Neighbors: Nodes [1, 12, 16, 23, 31, 32, 35, 40, 41, 42, 61, 63, 85, 99, 108, 113, 117, 118, 124, 129, 134, 137, 140, 149]
#
# Selecting Influencer 3
# ------------------------------------
# Activated Nodes: [90, 88]
# Influencer: Node 125
# Degree: 15
# Neighbors: Nodes [5, 29, 42, 46, 54, 64, 93, 98, 102, 103, 117, 127, 133, 142, 145]
#
# Selecting Influencer 4
# ------------------------------------
# Activated Nodes: [90, 88, 125, 29, 105]
# Influencer: Node 76
# Degree: 17
# Neighbors: Nodes [1, 9, 14, 28, 40, 54, 59, 77, 91, 99, 111, 117, 126, 141, 145, 146, 147]
#
# Selecting Influencer 1
# ------------------------------------
# Activated Nodes: []
# Influencer: Node 141
# Degree: 12
# Neighbors: Nodes [8, 10, 12, 25, 26, 51, 57, 75, 76, 79, 96, 121]
#
# Selecting Influencer 2
# ------------------------------------
# Activated Nodes: [141]
# Influencer: Node 75
# Degree: 15
# Neighbors: Nodes [10, 13, 15, 22, 39, 57, 61, 68, 90, 92, 118, 124, 127, 134, 141]
#
# Selecting Influencer 3
# ------------------------------------
# Activated Nodes: [141, 75]
# Influencer: Node 57
# Degree: 15
# Neighbors: Nodes [11, 25, 46, 71, 73, 74, 75, 86, 97, 99, 114, 123, 126, 129, 141]
#
# Selecting Influencer 4
# ------------------------------------
# Activated Nodes: [141, 75, 57]
# Influencer: Node 31
# Degree: 9
# Neighbors: Nodes [0, 17, 27, 88, 104, 108, 109, 114, 144]
#
# Selecting Influencer 5
# ------------------------------------
# Activated Nodes: [141, 75, 57, 31]
# Influencer: Node 59
# Degree: 10
# Neighbors: Nodes [0, 20, 45, 69, 76, 97, 109, 115, 119, 129]
#
# Selecting Influencer 1
# ------------------------------------
# Activated Nodes: []
# Influencer: Node 114
# Degree: 20
# Neighbors: Nodes [6, 15, 17, 18, 28, 31, 37, 39, 43, 57, 60, 66, 74, 80, 92, 98, 107, 123, 130, 139]
#
# Selecting Influencer 2
# ------------------------------------
# Activated Nodes: [114]
# Influencer: Node 31
# Degree: 9
# Neighbors: Nodes [0, 17, 27, 88, 104, 108, 109, 114, 144]
#
# Selecting Influencer 3
# ------------------------------------
# Activated Nodes: [114, 31]
# Influencer: Node 21
# Degree: 15
# Neighbors: Nodes [6, 8, 22, 34, 42, 43, 48, 87, 89, 103, 109, 120, 126, 130, 145]
#
# Selecting Influencer 4
# ------------------------------------
# Activated Nodes: [114, 31, 21]
# Influencer: Node 74
# Degree: 16
# Neighbors: Nodes [7, 15, 20, 40, 43, 57, 63, 66, 92, 96, 104, 106, 109, 110, 114, 137]
#
# Selecting Influencer 5
# ------------------------------------
# Activated Nodes: [114, 31, 21, 74]
# Influencer: Node 132
# Degree: 14
# Neighbors: Nodes [0, 6, 28, 29, 34, 37, 46, 58, 61, 68, 87, 121, 142, 143]
#
# Selecting Influencer 6
# ------------------------------------
# Activated Nodes: [114, 31, 21, 74, 132]
# Influencer: Node 62
# Degree: 15
# Neighbors: Nodes [6, 20, 37, 38, 54, 82, 89, 91, 99, 107, 111, 119, 123, 124, 137]
#
# Selecting Influencer 1
# ------------------------------------
# Activated Nodes: []
# Influencer: Node 41
# Degree: 19
# Neighbors: Nodes [1, 11, 26, 33, 34, 37, 68, 70, 78, 82, 87, 88, 97, 103, 127, 136, 138, 139, 149]
#
# Selecting Influencer 2
# ------------------------------------
# Activated Nodes: [41]
# Influencer: Node 25
# Degree: 12
# Neighbors: Nodes [11, 14, 15, 26, 39, 57, 66, 71, 82, 123, 131, 141]
#
# Selecting Influencer 3
# ------------------------------------
# Activated Nodes: [41, 25]
# Influencer: Node 97
# Degree: 18
# Neighbors: Nodes [9, 28, 33, 41, 42, 47, 57, 59, 64, 81, 85, 89, 93, 111, 113, 117, 129, 144]
#
# Selecting Influencer 4
# ------------------------------------
# Activated Nodes: [41, 25, 97]
# Influencer: Node 85
# Degree: 15
# Neighbors: Nodes [1, 12, 39, 51, 54, 61, 63, 71, 88, 92, 97, 98, 106, 113, 119]
#
# Selecting Influencer 5
# ------------------------------------
# Activated Nodes: [41, 25, 97, 85]
# Influencer: Node 82
# Degree: 16
# Neighbors: Nodes [17, 25, 26, 39, 41, 44, 62, 67, 69, 91, 94, 101, 102, 138, 146, 149]
#
# Selecting Influencer 6
# ------------------------------------
# Activated Nodes: [41, 25, 97, 85, 82]
# Influencer: Node 73
# Degree: 18
# Neighbors: Nodes [0, 16, 19, 23, 46, 57, 72, 80, 91, 94, 96, 99, 102, 105, 118, 120, 131, 139]
#
# Selecting Influencer 7
# ------------------------------------
# Activated Nodes: [41, 25, 97, 85, 82, 73]
# Influencer: Node 112
# Degree: 13
# Neighbors: Nodes [3, 5, 35, 58, 69, 91, 110, 120, 123, 130, 138, 146, 149]
#
# Selecting Influencer 1
# ------------------------------------
# Activated Nodes: []
# Influencer: Node 146
# Degree: 17
# Neighbors: Nodes [13, 16, 17, 23, 46, 54, 66, 76, 81, 82, 95, 102, 103, 112, 118, 121, 137]
#
# Selecting Influencer 2
# ------------------------------------
# Activated Nodes: [146, 66, 60]
# Influencer: Node 114
# Degree: 20
# Neighbors: Nodes [6, 15, 17, 18, 28, 31, 37, 39, 43, 57, 60, 66, 74, 80, 92, 98, 107, 123, 130, 139]
#
# Selecting Influencer 3
# ------------------------------------
# Activated Nodes: [146, 66, 60, 114]
# Influencer: Node 123
# Degree: 13
# Neighbors: Nodes [2, 15, 25, 35, 57, 62, 63, 65, 66, 72, 95, 112, 114]
#
# Selecting Influencer 4
# ------------------------------------
# Activated Nodes: [146, 66, 60, 114, 123]
# Influencer: Node 53
# Degree: 16
# Neighbors: Nodes [4, 15, 19, 33, 46, 47, 52, 72, 83, 90, 103, 108, 111, 121, 126, 148]
#
# Selecting Influencer 5
# ------------------------------------
# Activated Nodes: [146, 66, 60, 114, 123, 53]
# Influencer: Node 19
# Degree: 11
# Neighbors: Nodes [12, 20, 53, 65, 73, 92, 108, 131, 135, 142, 144]
#
# Selecting Influencer 6
# ------------------------------------
# Activated Nodes: [146, 66, 60, 114, 123, 53, 19]
# Influencer: Node 139
# Degree: 18
# Neighbors: Nodes [6, 11, 17, 37, 38, 41, 51, 52, 65, 67, 73, 87, 93, 102, 103, 114, 122, 124]
#
# Selecting Influencer 7
# ------------------------------------
# Activated Nodes: [146, 66, 60, 114, 123, 53, 19, 139]
# Influencer: Node 112
# Degree: 13
# Neighbors: Nodes [3, 5, 35, 58, 69, 91, 110, 120, 123, 130, 138, 146, 149]
#
# Selecting Influencer 8
# ------------------------------------
# Activated Nodes: [146, 66, 60, 114, 123, 53, 19, 139, 112]
# Influencer: Node 121
# Degree: 10
# Neighbors: Nodes [18, 22, 53, 66, 120, 127, 132, 135, 141, 146]
#
# Selecting Influencer 1
# ------------------------------------
# Activated Nodes: []
# Influencer: Node 84
# Degree: 12
# Neighbors: Nodes [13, 30, 39, 47, 60, 83, 94, 101, 128, 129, 133, 137]
#
# Selecting Influencer 2
# ------------------------------------
# Activated Nodes: [84]
# Influencer: Node 90
# Degree: 10
# Neighbors: Nodes [15, 27, 28, 53, 75, 79, 87, 96, 118, 131]
#
# Selecting Influencer 3
# ------------------------------------
# Activated Nodes: [84, 90]
# Influencer: Node 12
# Degree: 21
# Neighbors: Nodes [19, 23, 27, 43, 44, 48, 61, 64, 70, 85, 87, 88, 91, 95, 101, 110, 124, 128, 131, 133, 141]
#
# Selecting Influencer 4
# ------------------------------------
# Activated Nodes: [84, 90, 12]
# Influencer: Node 148
# Degree: 12
# Neighbors: Nodes [1, 16, 46, 53, 55, 64, 107, 108, 109, 129, 131, 137]
#
# Selecting Influencer 5
# ------------------------------------
# Activated Nodes: [84, 90, 12, 148]
# Influencer: Node 9
# Degree: 12
# Neighbors: Nodes [5, 23, 49, 76, 77, 89, 97, 98, 106, 113, 144, 145]
#
# Selecting Influencer 6
# ------------------------------------
# Activated Nodes:

#
# Selecting Influencer 3
# ------------------------------------
# Activated Nodes: [75, 28, 94]
# Influencer: Node 24
# Degree: 10
# Neighbors: Nodes [10, 22, 26, 30, 35, 72, 79, 92, 109, 137]
#
# Selecting Influencer 4
# ------------------------------------
# Activated Nodes: [75, 28, 94, 24]
# Influencer: Node 133
# Degree: 17
# Neighbors: Nodes [6, 12, 14, 20, 26, 29, 33, 36, 38, 44, 64, 84, 98, 105, 125, 136, 138]
#
# Selecting Influencer 5
# ------------------------------------
# Activated Nodes: [75, 28, 94, 24, 133]
# Influencer: Node 120
# Degree: 14
# Neighbors: Nodes [14, 20, 21, 44, 67, 73, 81, 100, 112, 118, 121, 122, 140, 147]
#
# Selecting Influencer 6
# ------------------------------------
# Activated Nodes: [75, 28, 94, 24, 133, 120]
# Influencer: Node 40
# Degree: 21
# Neighbors: Nodes [1, 5, 6, 13, 15, 20, 28, 42, 68, 71, 74, 76, 88, 98, 99, 105, 119, 135, 136, 144, 149]
# Selecting Influencer 7
# ------------------------------------
# Activated Nodes: [75, 28, 94, 24, 133, 120, 40]
# Influencer: Node 35
# Degree: 13
# Neighbors: Nodes [2, 3, 13, 24, 43, 50, 51, 64, 68, 88, 112, 123, 135]
#
# Selecting Influencer 8
# ------------------------------------
# Activated Nodes: [75, 28, 94, 24, 133, 120, 40, 35]
# Influencer: Node 46
# Degree: 16
# Neighbors: Nodes [1, 20, 28, 29, 49, 53, 57, 73, 87, 95, 122, 125, 132, 145, 146, 148]
#
# Selecting Influencer 9
# ------------------------------------
# Activated Nodes: [75, 28, 94, 24, 133, 120, 40, 35, 46]
# Influencer: Node 62
# Degree: 15
# Neighbors: Nodes [6, 20, 37, 38, 54, 82, 89, 91, 99, 107, 111, 119, 123, 124, 137]
#
# Selecting Influencer 10
# ------------------------------------
# Activated Nodes: [75, 28, 94, 24, 133, 120, 40, 35, 46, 62]
# Influencer: Node 57
# Degree: 15
# Neighbors: Nodes [11, 25, 46, 71, 73, 74, 75, 86, 97, 99, 114, 123, 126, 129, 141]
#
# Selecting Influencer 11
# ------------------------------------
# Activated Nodes: [75, 28, 94, 24, 133, 120, 40, 35, 46, 62, 57]
# Influencer: Node 66
# Degree: 20
# Neighbors: Nodes [6, 10, 22, 25, 30, 45, 49, 60, 67, 74, 78, 87, 91, 94, 96, 114, 117, 121, 123, 146]
#
# Selecting Influencer 1
# ------------------------------------
# Activated Nodes: []
# Influencer: Node 48
# Degree: 9
# Neighbors: Nodes [12, 21, 52, 68, 70, 87, 89, 107, 118]
#
# Selecting Influencer 2
# ------------------------------------
# Activated Nodes: [48]
# Influencer: Node 71
# Degree: 11
# Neighbors: Nodes [0, 25, 29, 40, 57, 68, 70, 81, 83, 85, 122]
#
# Selecting Influencer 3
# ------------------------------------
# Activated Nodes: [48, 71, 122]
# Influencer: Node 76
# Degree: 17
# Neighbors: Nodes [1, 9, 14, 28, 40, 54, 59, 77, 91, 99, 111, 117, 126, 141, 145, 146, 147]
#
# Selecting Influencer 4
# ------------------------------------
# Activated Nodes: [48, 71, 122, 76]
# Influencer: Node 24
# Degree: 10
# Neighbors: Nodes [10, 22, 26, 30, 35, 72, 79, 92, 109, 137]
#
# Selecting Influencer 5
# ------------------------------------
# Activated Nodes: [48, 71, 122, 76, 24]
# Influencer: Node 26
# Degree: 12
# Neighbors: Nodes [6, 24, 25, 41, 50, 54, 82, 91, 133, 140, 141, 149]
#
# Selecting Influencer 6
# ------------------------------------
# Activated Nodes: [48, 71, 122, 76, 24, 26]
# Influencer: Node 65
# Degree: 10
# Neighbors: Nodes [1, 19, 43, 55, 64, 89, 99, 123, 139, 144]
#
# Selecting Influencer 7
# ------------------------------------
# Activated Nodes: [48, 71, 122, 76, 24, 26, 65]
# Influencer: Node 91
# Degree: 21
# Neighbors: Nodes [3, 12, 23, 26, 43, 62, 66, 70, 72, 73, 76, 77, 82, 89, 102, 109, 112, 118, 136, 137, 149]
#
# Selecting Influencer 8
# ------------------------------------
# Activated Nodes: [48, 71, 122, 76, 24, 26, 65, 91]
# Influencer: Node 29
# Degree: 16
# Neighbors: Nodes [13, 16, 46, 52, 56, 69, 71, 87, 89, 102, 105, 122, 125, 127, 132, 133]
#
# Selecting Influencer 9
# ------------------------------------
# Activated Nodes: [48, 71, 122, 76, 24, 26, 65, 91, 29]
# Influencer: Node 139
# Degree: 18
# Neighbors: Nodes [6, 11, 17, 37, 38, 41, 51, 52, 65, 67, 73, 87, 93, 102, 103, 114, 122, 124]
#
# Selecting Influencer 10
# ------------------------------------
# Activated Nodes: [48, 71, 122, 76, 24, 26, 65, 91, 29, 139]
# Influencer: Node 86
# Degree: 10
# Neighbors: Nodes [5, 7, 13, 14, 50, 51, 57, 61, 127, 131]
#
# Selecting Influencer 11
# ------------------------------------
# Activated Nodes: [48, 71, 122, 76, 24, 26, 65, 91, 29, 139, 86]
# Influencer: Node 20
# Degree: 17
# Neighbors: Nodes [4, 19, 28, 37, 40, 46, 59, 62, 63, 74, 92, 99, 105, 120, 130, 133, 138]
#
# Selecting Influencer 12
# ------------------------------------
# Activated Nodes: [48, 71, 122, 76, 24, 26, 65, 91, 29, 139, 86, 20]
# Influencer: Node 132
# Degree: 14
# Neighbors: Nodes [0, 6, 28, 29, 34, 37, 46, 58, 61, 68, 87, 121, 142, 143]
#
# Selecting Influencer 1
# ------------------------------------
# Activated Nodes: []
# Influencer: Node 148
# Degree: 12
# Neighbors: Nodes [1, 16, 46, 53, 55, 64, 107, 108, 109, 129, 131, 137]
#
# Selecting Influencer 2
# ------------------------------------
# Activated Nodes: [148]
# Influencer: Node 60
# Degree: 14
# Neighbors: Nodes [0, 4, 56, 66, 84, 89, 102, 109, 114, 117, 118, 134, 143, 147]
#
# Selecting Influencer 3
# ------------------------------------
# Activated Nodes: [148, 60]
# Influencer: Node 41
# Degree: 19
# Neighbors: Nodes [1, 11, 26, 33, 34, 37, 68, 70, 78, 82, 87, 88, 97, 103, 127, 136, 138, 139, 149]
#
# Selecting Influencer 4
# ------------------------------------
# Activated Nodes: [148, 60, 41]
# Influencer: Node 129
# Degree: 11
# Neighbors: Nodes [22, 54, 57, 59, 61, 84, 88, 89, 97, 137, 148]
#
# Selecting Influencer 5
# ------------------------------------
# Activated Nodes: [148, 60, 41, 129]
# Influencer: Node 114
# Degree: 20
# Neighbors: Nodes [6, 15, 17, 18, 28, 31, 37, 39, 43, 57, 60, 66, 74, 80, 92, 98, 107, 123, 130, 139]
#
# Selecting Influencer 6
# ------------------------------------
# Activated Nodes: [148, 60, 41, 129, 114]
# Influencer: Node 74
# Degree: 16
# Neighbors: Nodes [7, 15, 20, 40, 43, 57, 63, 66, 92, 96, 104, 106, 109, 110, 114, 137]
#
# Selecting Influencer 7
# ------------------------------------
# Activated Nodes: [148, 60, 41, 129, 114, 74]
# Influencer: Node 51
# Degree: 16
# Neighbors: Nodes [6, 13, 15, 17, 35, 42, 80, 85, 86, 89, 126, 127, 131, 135, 139, 141]
#
# Selecting Influencer 8
# ------------------------------------
# Activated Nodes: [148, 60, 41, 129, 114, 74, 51]
# Influencer: Node 91
# Degree: 21
# Neighbors: Nodes [3, 12, 23, 26, 43, 62, 66, 70, 72, 73, 76, 77, 82, 89, 102, 109, 112, 118, 136, 137, 149]
#
# Selecting Influencer 9
# ------------------------------------
# Activated Nodes: [148, 60, 41, 129, 114, 74, 51, 91]
# Influencer: Node 22
# Degree: 21
# Neighbors: Nodes [7, 10, 14, 21, 24, 27, 42, 44, 50, 63, 66, 72, 75, 80, 92, 104, 107, 115, 121, 127, 129]
#
# Selecting Influencer 10
# ------------------------------------
# Activated Nodes: [148, 60, 41, 129, 114, 74, 51, 91, 22]
# Influencer: Node 144
# Degree: 14
# Neighbors: Nodes [9, 15, 19, 31, 40, 43, 47, 65, 92, 97, 106, 109, 130, 138]
#
# Selecting Influencer 11
# ------------------------------------
# Activated Nodes: [148, 60, 41, 129, 114, 74, 51, 91, 22, 144]
# Influencer: Node 133
# Degree: 17
# Neighbors: Nodes [6, 12, 14, 20, 26, 29, 33, 36, 38, 44, 64, 84, 98, 105, 125, 136, 138]
#
# Selecting Influencer 12
# ------------------------------------
# Activated Nodes: [148, 60, 41, 129, 114, 74, 51, 91, 22, 144, 133, 36]
# Influencer: Node 81
# Degree: 17
# Neighbors: Nodes [7, 16, 18, 32, 34, 36, 45, 70, 71, 97, 107, 120, 122, 138, 145, 146, 147]
#
# Selecting Influencer 13
# ------------------------------------
# Activated Nodes: [148, 60, 41, 129, 114, 74, 51, 91, 22, 144, 133, 36, 81]
# Influencer: Node 71
# Degree: 11
# Neighbors: Nodes [0, 25, 29, 40, 57, 68, 70, 81, 83, 85, 122]
#
# Selecting Influencer 1
# ------------------------------------
# Activated Nodes: []
# Influencer: Node 15
# Degree: 24
# Neighbors: Nodes [4, 5, 14, 25, 28, 30, 32, 33, 40, 51, 53, 69, 70, 74, 75, 90, 99, 114, 123, 127, 138, 144, 145, 147]
#
# Selecting Influencer 2
# ------------------------------------
# Activated Nodes: [15]
# Influencer: Node 10
# Degree: 16
# Neighbors: Nodes [7, 22, 24, 27, 34, 45, 56, 61, 66, 72, 75, 93, 101, 111, 124, 141]
#
# Selecting Influencer 3
# ------------------------------------
# Activated Nodes: [15, 10]
# Influencer: Node 35
# Degree: 13
# Neighbors: Nodes [2, 3, 13, 24, 43, 50, 51, 64, 68, 88, 112, 123, 135]
#
# Selecting Influencer 4
# ------------------------------------
# Activated Nodes: [15, 10, 35]
# Influencer: Node 6
# Degree: 19
# Neighbors: Nodes [21, 26, 40, 42, 51, 54, 56, 62, 66, 92, 94, 101, 107, 111, 114, 131, 132, 133, 139]
#
# Selecting Influencer 5
# ------------------------------------
# Activated Nodes: [15, 10, 35, 6]
# Influencer: Node 96
# Degree: 11
# Neighbors: Nodes [16, 38, 45, 55, 66, 68, 73, 74, 90, 126, 141]
#
# Selecting Influencer 6
# ------------------------------------
# Activated Nodes: [15, 10, 35, 6, 96]
# Influencer: Node 86
# Degree: 10
# Neighbors: Nodes [5, 7, 13, 14, 50, 51, 57, 61, 127, 131]
#
# Selecting Influencer 7
# ------------------------------------
# Activated Nodes: [15, 10, 35, 6, 96, 86]
# Influencer: Node 104
# Degree: 14
# Neighbors: Nodes [2, 4, 22, 31, 44, 47, 52, 63, 74, 103, 108, 110, 134, 142]
#
# Selecting Influencer 8
# ------------------------------------
# Activated Nodes: [15, 10, 35, 6, 96, 86, 104]
# Influencer: Node 93
# Degree: 9
# Neighbors: Nodes [10, 37, 72, 97, 101, 111, 125, 138, 139]
#
# Selecting Influencer 9
# ------------------------------------
# Activated Nodes: [15, 10, 35, 6, 96, 86, 104, 93]
# Influencer: Node 143
# Degree: 13
# Neighbors: Nodes [1, 2, 8, 11, 33, 44, 56, 60, 83, 89, 100, 115, 132]
#
# Selecting Influencer 10
# ------------------------------------
# Activated Nodes: [15, 10, 35, 6, 96, 86, 104, 93, 143]
# Influencer: Node 133
# Degree: 17
# Neighbors: Nodes [6, 12, 14, 20, 26, 29, 33, 36, 38, 44, 64, 84, 98, 105, 125, 136, 138]
#
# Selecting Influencer 11
# ------------------------------------
# Activated Nodes: [15, 10, 35, 6, 96, 86, 104, 93, 143, 133]
# Influencer: Node 16
# Degree: 17
# Neighbors: Nodes [4, 8, 17, 29, 39, 47, 68, 73, 81, 88, 96, 113, 119, 135, 136, 146, 148]
#
# Selecting Influencer 12
# ------------------------------------
# Activated Nodes: [15, 10, 35, 6, 96, 86, 104, 93, 143, 133, 16]
# Influencer: Node 67
# Degree: 15
# Neighbors: Nodes [0, 7, 28, 42, 66, 82, 83, 89, 105, 111, 113, 120, 128, 136, 139]
#
# Selecting Influencer 13
# ------------------------------------
# Activated Nodes: [15, 10, 35, 6, 96, 86, 104, 93, 143, 133, 16, 67]
# Influencer: Node 135
# Degree: 11
# Neighbors: Nodes [16, 19, 23, 35, 40, 51, 77, 95, 106, 121, 127]
#
# Selecting Influencer 14
# ------------------------------------
# Activated Nodes: [15, 10, 35, 6, 96, 86, 104, 93, 143, 133, 16, 67, 135]
# Influencer: Node 81
# Degree: 17
# Neighbors: Nodes [7, 16, 18, 32, 34, 36, 45, 70, 71, 97, 107, 120, 122, 138, 145, 146, 147]
#
# Selecting Influencer 1
# ------------------------------------
# Activated Nodes: []
# Influencer: Node 142
# Degree: 9
# Neighbors: Nodes [5, 19, 42, 102, 104, 109, 125, 132, 145]
#
# Selecting Influencer 2
# ------------------------------------
# Activated Nodes: [142]
# Influencer: Node 109
# Degree: 24
# Neighbors: Nodes [2, 13, 17, 18, 21, 24, 31, 45, 47, 59, 60, 63, 68, 70, 74, 79, 83, 91, 110, 117, 124, 142, 144, 148]
#
# Selecting Influencer 3
# ------------------------------------
# Activated Nodes: [142, 109]
# Influencer: Node 103
# Degree: 15
# Neighbors: Nodes [17, 21, 28, 41, 53, 58, 102, 104, 113, 122, 125, 127, 139, 146, 149]
#
# Selecting Influencer 4
# ------------------------------------
# Activated Nodes: [142, 109, 103]
# Influencer: Node 7
# Degree: 8
# Neighbors: Nodes [3, 10, 22, 67, 74, 81, 86, 95]
#
# Selecting Influencer 5
# ------------------------------------
# Activated Nodes: [142, 109, 103, 7]
# Influencer: Node 94
# Degree: 13
# Neighbors: Nodes [6, 28, 34, 38, 66, 72, 73, 82, 84, 116, 118, 122, 136]
#
# Selecting Influencer 6
# ------------------------------------
# Activated Nodes: [142, 109, 103, 7, 94]
# Influencer: Node 4
# Degree: 16
# Neighbors: Nodes [0, 14, 15, 16, 20, 32, 37, 39, 43, 53, 60, 61, 78, 80, 104, 128]
#
# Selecting Influencer 7
# ------------------------------------
# Activated Nodes: [142, 109, 103, 7, 94, 4]
# Influencer: Node 141
# Degree: 12
# Neighbors: Nodes [8, 10, 12, 25, 26, 51, 57, 75, 76, 79, 96, 121]
#
# Selecting Influencer 8
# ------------------------------------
# Activated Nodes: [142, 109, 103, 7, 94, 4, 141]
# Influencer: Node 99
# Degree: 16
# Neighbors: Nodes [15, 20, 33, 40, 45, 49, 57, 62, 65, 73, 76, 88, 89, 98, 106, 124]
#
# Selecting Influencer 9
# ------------------------------------
# Activated Nodes: [142, 109, 103, 7, 94, 4, 141, 99]
# Influencer: Node 98
# Degree: 16
# Neighbors: Nodes [0, 1, 9, 32, 33, 36, 40, 50, 58, 85, 89, 99, 114, 125, 133, 147]
#
# Selecting Influencer 10
# ------------------------------------
# Activated Nodes: [142, 109, 103, 7, 94, 4, 141, 99, 98]
# Influencer: Node 83
# Degree: 11
# Neighbors: Nodes [36, 53, 67, 71, 84, 89, 95, 109, 117, 131, 143]
#
# Selecting Influencer 11
# ------------------------------------
# Activated Nodes: [142, 109, 103, 7, 94, 4, 141, 99, 98, 83]
# Influencer: Node 118
# Degree: 17
# Neighbors: Nodes [3, 38, 39, 44, 48, 60, 73, 75, 88, 90, 91, 94, 116, 120, 122, 127, 146]
# Selecting Influencer 12
# ------------------------------------
# Activated Nodes: [142, 109, 103, 7, 94, 4, 141, 99, 98, 83, 118]
# Influencer: Node 87
# Degree: 16
# Neighbors: Nodes [2, 12, 21, 28, 29, 41, 43, 46, 48, 66, 90, 108, 116, 132, 138, 139]
#
# Selecting Influencer 13
# ------------------------------------
# Activated Nodes: [142, 109, 103, 7, 94, 4, 141, 99, 98, 83, 118, 87]
# Influencer: Node 21
# Degree: 15
# Neighbors: Nodes [6, 8, 22, 34, 42, 43, 48, 87, 89, 103, 109, 120, 126, 130, 145]
#
# Selecting Influencer 14
# ------------------------------------
# Activated Nodes: [142, 109, 103, 7, 94, 4, 141, 99, 98, 83, 118, 87, 21]
# Influencer: Node 16
# Degree: 17
# Neighbors: Nodes [4, 8, 17, 29, 39, 47, 68, 73, 81, 88, 96, 113, 119, 135, 136, 146, 148]
#
# Selecting Influencer 15
# ------------------------------------
# Activated Nodes: [142, 109, 103, 7, 94, 4, 141, 99, 98, 83, 118, 87, 21, 16]
# Influencer: Node 70
# Degree: 16
# Neighbors: Nodes [12, 15, 41, 45, 47, 48, 52, 71, 81, 89, 91, 95, 107, 109, 110, 126]
#
# Selecting Influencer 1
# ------------------------------------
# Activated Nodes: []
# Influencer: Node 9
# Degree: 12
# Neighbors: Nodes [5, 23, 49, 76, 77, 89, 97, 98, 106, 113, 144, 145]
#
# Selecting Influencer 2
# ------------------------------------
# Activated Nodes: [9]
# Influencer: Node 47
# Degree: 17
# Neighbors: Nodes [1, 16, 17, 18, 28, 53, 68, 70, 78, 84, 92, 97, 104, 109, 113, 131, 144]
#
# Selecting Influencer 3
# ------------------------------------
# Activated Nodes: [9, 47, 16, 4]
# Influencer: Node 109
# Degree: 24
# Neighbors: Nodes [2, 13, 17, 18, 21, 24, 31, 45, 47, 59, 60, 63, 68, 70, 74, 79, 83, 91, 110, 117, 124, 142, 144, 148]
#
# Selecting Influencer 4
# ------------------------------------
# Activated Nodes: [9, 47, 16, 4, 109]
# Influencer: Node 122
# Degree: 21
# Neighbors: Nodes [3, 5, 11, 14, 29, 33, 37, 38, 42, 46, 68, 71, 72, 81, 94, 102, 103, 106, 118, 120, 139]
#
# Selecting Influencer 5
# ------------------------------------
# Activated Nodes: [9, 47, 16, 4, 109, 122]
# Influencer: Node 44
# Degree: 15
# Neighbors: Nodes [12, 22, 33, 52, 55, 79, 82, 104, 118, 119, 120, 126, 128, 133, 143]
#
# Selecting Influencer 6
# ------------------------------------
# Activated Nodes: [9, 47, 16, 4, 109, 122, 44]
# Influencer: Node 22
# Degree: 21
# Neighbors: Nodes [7, 10, 14, 21, 24, 27, 42, 44, 50, 63, 66, 72, 75, 80, 92, 104, 107, 115, 121, 127, 129]
#
# Selecting Influencer 7
# ------------------------------------
# Activated Nodes: [9, 47, 16, 4, 109, 122, 44, 22]
# Influencer: Node 6
# Degree: 19
# Neighbors: Nodes [21, 26, 40, 42, 51, 54, 56, 62, 66, 92, 94, 101, 107, 111, 114, 131, 132, 133, 139]
#
# Selecting Influencer 8
# ------------------------------------
# Activated Nodes: [9, 47, 16, 4, 109, 122, 44, 22, 6]
# Influencer: Node 62
# Degree: 15
# Neighbors: Nodes [6, 20, 37, 38, 54, 82, 89, 91, 99, 107, 111, 119, 123, 124, 137]
#
# Selecting Influencer 9
# ------------------------------------
# Activated Nodes: [9, 47, 16, 4, 109, 122, 44, 22, 6, 62, 82]
# Influencer: Node 5
# Degree: 15
# Neighbors: Nodes [1, 9, 15, 38, 40, 86, 92, 100, 112, 116, 122, 125, 136, 142, 145]
#
# Selecting Influencer 10
# ------------------------------------
# Activated Nodes: [9, 47, 16, 4, 109, 122, 44, 22, 6, 62, 82, 5]
# Influencer: Node 36
# Degree: 11
# Neighbors: Nodes [14, 34, 58, 79, 81, 83, 89, 98, 124, 133, 134]
#
# Selecting Influencer 11
# ------------------------------------
# Activated Nodes: [9, 47, 16, 4, 109, 122, 44, 22, 6, 62, 82, 5, 36]
# Influencer: Node 133
# Degree: 17
# Neighbors: Nodes [6, 12, 14, 20, 26, 29, 33, 36, 38, 44, 64, 84, 98, 105, 125, 136, 138]
#
# Selecting Influencer 12
# ------------------------------------
# Activated Nodes: [9, 47, 16, 4, 109, 122, 44, 22, 6, 62, 82, 5, 36, 133]
# Influencer: Node 129
# Degree: 11
# Neighbors: Nodes [22, 54, 57, 59, 61, 84, 88, 89, 97, 137, 148]
#
# Selecting Influencer 13
# ------------------------------------
# Activated Nodes: [9, 47, 16, 4, 109, 122, 44, 22, 6, 62, 82, 5, 36, 133, 129]
# Influencer: Node 34
# Degree: 12
# Neighbors: Nodes [2, 10, 21, 36, 41, 50, 58, 81, 94, 124, 132, 140]
#
# Selecting Influencer 14
# ------------------------------------
# Activated Nodes: [9, 47, 16, 4, 109, 122, 44, 22, 6, 62, 82, 5, 36, 133, 129, 34]
# Influencer: Node 114
# Degree: 20
# Neighbors: Nodes [6, 15, 17, 18, 28, 31, 37, 39, 43, 57, 60, 66, 74, 80, 92, 98, 107, 123, 130, 139]
#
# Selecting Influencer 15
# ------------------------------------
# Activated Nodes: [9, 47, 16, 4, 109, 122, 44, 22, 6, 62, 82, 5, 36, 133, 129, 34, 114, 31]
# Influencer: Node 143
# Degree: 13
# Neighbors: Nodes [1, 2, 8, 11, 33, 44, 56, 60, 83, 89, 100, 115, 132]
#
# Selecting Influencer 16
# ------------------------------------
# Activated Nodes: [9, 47, 16, 4, 109, 122, 44, 22, 6, 62, 82, 5, 36, 133, 129, 34, 114, 31, 143]
# Influencer: Node 145
# Degree: 17
# Neighbors: Nodes [5, 9, 13, 14, 15, 21, 46, 54, 68, 76, 78, 81, 92, 101, 125, 127, 142]
#
# Selecting Influencer 1
# ------------------------------------
# Activated Nodes: []
# Influencer: Node 28
# Degree: 22
# Neighbors: Nodes [15, 20, 40, 46, 47, 55, 67, 68, 76, 87, 90, 94, 97, 102, 103, 106, 107, 114, 115, 116, 132, 136]
#
# Selecting Influencer 2
# ------------------------------------
# Activated Nodes: [28, 97]
# Influencer: Node 116
# Degree: 8
# Neighbors: Nodes [5, 27, 28, 39, 87, 94, 102, 118]
#
# Selecting Influencer 3
# ------------------------------------
# Activated Nodes: [28, 97, 116]
# Influencer: Node 88
# Degree: 24
# Neighbors: Nodes [1, 12, 16, 23, 31, 32, 35, 40, 41, 42, 61, 63, 85, 99, 108, 113, 117, 118, 124, 129, 134, 137, 140, 149]
#
# Selecting Influencer 4
# ------------------------------------
# Activated Nodes: [28, 97, 116, 88]
# Influencer: Node 125
# Degree: 15
# Neighbors: Nodes [5, 29, 42, 46, 54, 64, 93, 98, 102, 103, 117, 127, 133, 142, 145]
#
# Selecting Influencer 5
# ------------------------------------
# Activated Nodes: [28, 97, 116, 88, 125]
# Influencer: Node 18
# Degree: 15
# Neighbors: Nodes [8, 14, 27, 37, 47, 55, 63, 68, 81, 89, 109, 114, 115, 121, 136]
#
# Selecting Influencer 6
# ------------------------------------
# Activated Nodes: [28, 97, 116, 88, 125, 18]
# Influencer: Node 23
# Degree: 16
# Neighbors: Nodes [9, 12, 49, 52, 54, 63, 73, 88, 89, 91, 115, 128, 130, 134, 135, 146]
#
# Selecting Influencer 7
# ------------------------------------
# Activated Nodes: [28, 97, 116, 88, 125, 18, 23]
# Influencer: Node 112
# Degree: 13
# Neighbors: Nodes [3, 5, 35, 58, 69, 91, 110, 120, 123, 130, 138, 146, 149]
#
# Selecting Influencer 8
# ------------------------------------
# Activated Nodes: [28, 97, 116, 88, 125, 18, 23, 112, 69]
# Influencer: Node 24
# Degree: 10
# Neighbors: Nodes [10, 22, 26, 30, 35, 72, 79, 92, 109, 137]
#
# Selecting Influencer 9
# ------------------------------------
# Activated Nodes: [28, 97, 116, 88, 125, 18, 23, 112, 69, 24]
# Influencer: Node 29
# Degree: 16
# Neighbors: Nodes [13, 16, 46, 52, 56, 69, 71, 87, 89, 102, 105, 122, 125, 127, 132, 133]
#
# Selecting Influencer 10
# ------------------------------------
# Activated Nodes: [28, 97, 116, 88, 125, 18, 23, 112, 69, 24, 29]
# Influencer: Node 89
# Degree: 23
# Neighbors: Nodes [9, 18, 21, 23, 29, 36, 43, 48, 51, 60, 62, 65, 67, 70, 83, 91, 95, 97, 98, 99, 124, 129, 143]
#
# Selecting Influencer 11
# ------------------------------------
# Activated Nodes: [28, 97, 116, 88, 125, 18, 23, 112, 69, 24, 29, 89, 62]
# Influencer: Node 105
# Degree: 16
# Neighbors: Nodes [1, 11, 17, 20, 29, 39, 40, 63, 67, 73, 107, 111, 113, 126, 133, 134]
#
# Selecting Influencer 12
# ------------------------------------
# Activated Nodes: [28, 97, 116, 88, 125, 18, 23, 112, 69, 24, 29, 89, 62, 105]
# Influencer: Node 85
# Degree: 15
# Neighbors: Nodes [1, 12, 39, 51, 54, 61, 63, 71, 88, 92, 97, 98, 106, 113, 119]
#
# Selecting Influencer 13
# ------------------------------------
# Activated Nodes: [28, 97, 116, 88, 125, 18, 23, 112, 69, 24, 29, 89, 62, 105, 85]
# Influencer: Node 96
# Degree: 11
# Neighbors: Nodes [16, 38, 45, 55, 66, 68, 73, 74, 90, 126, 141]
#
# Selecting Influencer 14
# ------------------------------------
# Activated Nodes: [28, 97, 116, 88, 125, 18, 23, 112, 69, 24, 29, 89, 62, 105, 85, 96]
# Influencer: Node 108
# Degree: 13
# Neighbors: Nodes [3, 14, 17, 19, 31, 53, 78, 87, 88, 104, 124, 134, 148]
#
# Selecting Influencer 15
# ------------------------------------
# Activated Nodes: [28, 97, 116, 88, 125, 18, 23, 112, 69, 24, 29, 89, 62, 105, 85, 96, 108]
# Influencer: Node 2
# Degree: 13
# Neighbors: Nodes [14, 34, 35, 50, 61, 87, 104, 107, 109, 123, 134, 138, 143]
#
# Selecting Influencer 16
# ------------------------------------
# Activated Nodes: [28, 97, 116, 88, 125, 18, 23, 112, 69, 24, 29, 89, 62, 105, 85, 96, 108, 2, 109]
# Influencer: Node 32
# Degree: 11
# Neighbors: Nodes [4, 15, 43, 63, 79, 81, 88, 98, 102, 130, 138]
#
# Selecting Influencer 17
# ------------------------------------
# Activated Nodes: [28, 97, 116, 88, 125, 18, 23, 112, 69, 24, 29, 89, 62, 105, 85, 96, 108, 2, 109, 32]
# Influencer: Node 127
# Degree: 17
# Neighbors: Nodes [1, 15, 22, 29, 39, 41, 50, 51, 63, 75, 86, 103, 118, 121, 125, 135, 145]
#
# Selecting Influencer 1
# ------------------------------------
# Activated Nodes: []
# Influencer: Node 114
# Degree: 20
# Neighbors: Nodes [6, 15, 17, 18, 28, 31, 37, 39, 43, 57, 60, 66, 74, 80, 92, 98, 107, 123, 130, 139]
#
# Selecting Influencer 2
# ------------------------------------
# Activated Nodes: [114]
# Influencer: Node 37
# Degree: 19
# Neighbors: Nodes [4, 17, 18, 20, 38, 41, 62, 68, 69, 72, 77, 79, 93, 95, 114, 122, 132, 139, 147]
#
# Selecting Influencer 3
# ------------------------------------
# Activated Nodes: [114, 37]
# Influencer: Node 70
# Degree: 16
# Neighbors: Nodes [12, 15, 41, 45, 47, 48, 52, 71, 81, 89, 91, 95, 107, 109, 110, 126]
#
# Selecting Influencer 4
# ------------------------------------
# Activated Nodes: [114, 37, 70]
# Influencer: Node 64
# Degree: 12
# Neighbors: Nodes [12, 35, 39, 61, 65, 97, 113, 117, 125, 133, 137, 148]
#
# Selecting Influencer 5
# ------------------------------------
# Activated Nodes: [114, 37, 70, 64]
# Influencer: Node 117
# Degree: 14
# Neighbors: Nodes [11, 30, 38, 60, 64, 66, 76, 83, 88, 97, 109, 110, 115, 125]
#
# Selecting Influencer 6
# ------------------------------------
# Activated Nodes: [114, 37, 70, 64, 117]
# Influencer: Node 131
# Degree: 20
# Neighbors: Nodes [6, 11, 12, 19, 25, 45, 47, 51, 61, 63, 73, 83, 86, 90, 92, 100, 106, 140, 148, 149]
#
# Selecting Influencer 7
# ------------------------------------
# Activated Nodes: [114, 37, 70, 64, 117, 131]
# Influencer: Node 33
# Degree: 17
# Neighbors: Nodes [3, 8, 15, 41, 44, 53, 97, 98, 99, 101, 107, 122, 126, 133, 136, 143, 149]
#
# Selecting Influencer 8
# ------------------------------------
# Activated Nodes: [114, 37, 70, 64, 117, 131, 33]
# Influencer: Node 12
# Degree: 21
# Neighbors: Nodes [19, 23, 27, 43, 44, 48, 61, 64, 70, 85, 87, 88, 91, 95, 101, 110, 124, 128, 131, 133, 141]
#
# Selecting Influencer 9
# ------------------------------------
# Activated Nodes: [114, 37, 70, 64, 117, 131, 33, 12, 44, 85]
# Influencer: Node 55
# Degree: 8
# Neighbors: Nodes [18, 28, 44, 65, 79, 96, 136, 148]
#
# Selecting Influencer 10
# ------------------------------------
# Activated Nodes: [114, 37, 70, 64, 117, 131, 33, 12, 44, 85, 55]
# Influencer: Node 72
# Degree: 18
# Neighbors: Nodes [3, 10, 13, 22, 24, 37, 42, 43, 53, 73, 91, 93, 94, 122, 123, 128, 136, 138]
#
# Selecting Influencer 11
# ------------------------------------
# Activated Nodes: [114, 37, 70, 64, 117, 131, 33, 12, 44, 85, 55, 72]
# Influencer: Node 109
# Degree: 24
# Neighbors: Nodes [2, 13, 17, 18, 21, 24, 31, 45, 47, 59, 60, 63, 68, 70, 74, 79, 83, 91, 110, 117, 124, 142, 144, 148]
#
# Selecting Influencer 12
# ------------------------------------
# Activated Nodes: [114, 37, 70, 64, 117, 131, 33, 12, 44, 85, 55, 72, 109]
# Influencer: Node 146
# Degree: 17
# Neighbors: Nodes [13, 16, 17, 23, 46, 54, 66, 76, 81, 82, 95, 102, 103, 112, 118, 121, 137]
#
# Selecting Influencer 13
# ------------------------------------
# Activated Nodes: [114, 37, 70, 64, 117, 131, 33, 12, 44, 85, 55, 72, 109, 146]
# Influencer: Node 113
# Degree: 15
# Neighbors: Nodes [9, 16, 17, 38, 47, 64, 67, 85, 88, 97, 103, 105, 110, 128, 149]
#
# Selecting Influencer 14
# ------------------------------------
# Activated Nodes: [114, 37, 70, 64, 117, 131, 33, 12, 44, 85, 55, 72, 109, 146, 113, 38]
# Influencer: Node 6
# Degree: 19
# Neighbors: Nodes [21, 26, 40, 42, 51, 54, 56, 62, 66, 92, 94, 101, 107, 111, 114, 131, 132, 133, 139]
#
# Selecting Influencer 15
# ------------------------------------
# Activated Nodes: [114, 37, 70, 64, 117, 131, 33, 12, 44, 85, 55, 72, 109, 146, 113, 38, 6]
# Influencer: Node 16
# Degree: 17
# Neighbors: Nodes [4, 8, 17, 29, 39, 47, 68, 73, 81, 88, 96, 113, 119, 135, 136, 146, 148]
#
# Selecting Influencer 16
# ------------------------------------
# Activated Nodes: [114, 37, 70, 64, 117, 131, 33, 12, 44, 85, 55, 72, 109, 146, 113, 38, 6, 16, 136]
# Influencer: Node 29
# Degree: 16
# Neighbors: Nodes [13, 16, 46, 52, 56, 69, 71, 87, 89, 102, 105, 122, 125, 127, 132, 133]
#
# Selecting Influencer 17
# ------------------------------------
# Activated Nodes: [114, 37, 70, 64, 117, 131, 33, 12, 44, 85, 55, 72, 109, 146, 113, 38, 6, 16, 136, 29]
# Influencer: Node 97
# Degree: 18
# Neighbors: Nodes [9, 28, 33, 41, 42, 47, 57, 59, 64, 81, 85, 89, 93, 111, 113, 117, 129, 144]
#
# Selecting Influencer 18
# ------------------------------------
# Activated Nodes: [114, 37, 70, 64, 117, 131, 33, 12, 44, 85, 55, 72, 109, 146, 113, 38, 6, 16, 136, 29, 97]
# Influencer: Node 62
# Degree: 15
# Neighbors: Nodes [6, 20, 37, 38, 54, 82, 89, 91, 99, 107, 111, 119, 123, 124, 137]
# Selecting Influencer 1
# ------------------------------------
# Activated Nodes: []
# Influencer: Node 75
# Degree: 15
# Neighbors: Nodes [10, 13, 15, 22, 39, 57, 61, 68, 90, 92, 118, 124, 127, 134, 141]
#
# Selecting Influencer 2
# ------------------------------------
# Activated Nodes: [75]
# Influencer: Node 55
# Degree: 8
# Neighbors: Nodes [18, 28, 44, 65, 79, 96, 136, 148]
#
# Selecting Influencer 3
# ------------------------------------
# Activated Nodes: [75, 55]
# Influencer: Node 33
# Degree: 17
# Neighbors: Nodes [3, 8, 15, 41, 44, 53, 97, 98, 99, 101, 107, 122, 126, 133, 136, 143, 149]
#
# Selecting Influencer 4
# ------------------------------------
# Activated Nodes: [75, 55, 33]
# Influencer: Node 146
# Degree: 17
# Neighbors: Nodes [13, 16, 17, 23, 46, 54, 66, 76, 81, 82, 95, 102, 103, 112, 118, 121, 137]
#
# Selecting Influencer 5
# ------------------------------------
# Activated Nodes: [75, 55, 33, 146]
# Influencer: Node 57
# Degree: 15
# Neighbors: Nodes [11, 25, 46, 71, 73, 74, 75, 86, 97, 99, 114, 123, 126, 129, 141]
#
# Selecting Influencer 6
# ------------------------------------
# Activated Nodes: [75, 55, 33, 146, 57]
# Influencer: Node 20
# Degree: 17
# Neighbors: Nodes [4, 19, 28, 37, 40, 46, 59, 62, 63, 74, 92, 99, 105, 120, 130, 133, 138]
#
# Selecting Influencer 7
# ------------------------------------
# Activated Nodes: [75, 55, 33, 146, 57, 20, 59]
# Influencer: Node 133
# Degree: 17
# Neighbors: Nodes [6, 12, 14, 20, 26, 29, 33, 36, 38, 44, 64, 84, 98, 105, 125, 136, 138]
#
# Selecting Influencer 8
# ------------------------------------
# Activated Nodes: [75, 55, 33, 146, 57, 20, 59, 133]
# Influencer: Node 1
# Degree: 20
# Neighbors: Nodes [5, 11, 38, 40, 41, 45, 46, 47, 52, 65, 76, 85, 88, 98, 105, 119, 124, 127, 143, 148]
#
# Selecting Influencer 9
# ------------------------------------
# Activated Nodes: [75, 55, 33, 146, 57, 20, 59, 133, 1]
# Influencer: Node 130
# Degree: 10
# Neighbors: Nodes [17, 20, 21, 23, 32, 56, 112, 114, 144, 149]
#
# Selecting Influencer 10
# ------------------------------------
# Activated Nodes: [75, 55, 33, 146, 57, 20, 59, 133, 1, 130, 32, 98]
# Influencer: Node 56
# Degree: 11
# Neighbors: Nodes [3, 6, 10, 14, 29, 60, 63, 111, 115, 130, 143]
#
# Selecting Influencer 11
# ------------------------------------
# Activated Nodes: [75, 55, 33, 146, 57, 20, 59, 133, 1, 130, 32, 98, 56]
# Influencer: Node 31
# Degree: 9
# Neighbors: Nodes [0, 17, 27, 88, 104, 108, 109, 114, 144]
#
# Selecting Influencer 12
# ------------------------------------
# Activated Nodes: [75, 55, 33, 146, 57, 20, 59, 133, 1, 130, 32, 98, 56, 31]
# Influencer: Node 43
# Degree: 24
# Neighbors: Nodes [0, 4, 8, 12, 21, 32, 35, 39, 52, 54, 65, 72, 74, 79, 80, 87, 89, 91, 101, 111, 114, 126, 134, 144]
#
# Selecting Influencer 13
# ------------------------------------
# Activated Nodes: [75, 55, 33, 146, 57, 20, 59, 133, 1, 130, 32, 98, 56, 31, 43]
# Influencer: Node 116
# Degree: 8
# Neighbors: Nodes [5, 27, 28, 39, 87, 94, 102, 118]
#
# Selecting Influencer 14
# ------------------------------------
# Activated Nodes: [75, 55, 33, 146, 57, 20, 59, 133, 1, 130, 32, 98, 56, 31, 43, 116]
# Influencer: Node 125
# Degree: 15
# Neighbors: Nodes [5, 29, 42, 46, 54, 64, 93, 98, 102, 103, 117, 127, 133, 142, 145]
#
# Selecting Influencer 15
# ------------------------------------
# Activated Nodes: [75, 55, 33, 146, 57, 20, 59, 133, 1, 130, 32, 98, 56, 31, 43, 116, 125]
# Influencer: Node 87
# Degree: 16
# Neighbors: Nodes [2, 12, 21, 28, 29, 41, 43, 46, 48, 66, 90, 108, 116, 132, 138, 139]
#
# Selecting Influencer 16
# ------------------------------------
# Activated Nodes: [75, 55, 33, 146, 57, 20, 59, 133, 1, 130, 32, 98, 56, 31, 43, 116, 125, 87]
# Influencer: Node 3
# Degree: 14
# Neighbors: Nodes [7, 8, 33, 35, 56, 68, 72, 79, 91, 95, 108, 112, 118, 122]
#
# Selecting Influencer 17
# ------------------------------------
# Activated Nodes: [75, 55, 33, 146, 57, 20, 59, 133, 1, 130, 32, 98, 56, 31, 43, 116, 125, 87, 3]
# Influencer: Node 95
# Degree: 14
# Neighbors: Nodes [3, 7, 12, 27, 37, 46, 52, 61, 70, 83, 89, 123, 135, 146]
#
# Selecting Influencer 18
# ------------------------------------
# Activated Nodes: [75, 55, 33, 146, 57, 20, 59, 133, 1, 130, 32, 98, 56, 31, 43, 116, 125, 87, 3, 95]
# Influencer: Node 118
# Degree: 17
# Neighbors: Nodes [3, 38, 39, 44, 48, 60, 73, 75, 88, 90, 91, 94, 116, 120, 122, 127, 146]
#
# Selecting Influencer 19
# ------------------------------------
# Activated Nodes: [75, 55, 33, 146, 57, 20, 59, 133, 1, 130, 32, 98, 56, 31, 43, 116, 125, 87, 3, 95, 118]
# Influencer: Node 51
# Degree: 16
# Neighbors: Nodes [6, 13, 15, 17, 35, 42, 80, 85, 86, 89, 126, 127, 131, 135, 139, 141]
#
# Selecting Influencer 1
# ------------------------------------
# Activated Nodes: []
# Influencer: Node 98
# Degree: 16
# Neighbors: Nodes [0, 1, 9, 32, 33, 36, 40, 50, 58, 85, 89, 99, 114, 125, 133, 147]
#
# Selecting Influencer 2
# ------------------------------------
# Activated Nodes: [98, 89, 62]
# Influencer: Node 93
# Degree: 9
# Neighbors: Nodes [10, 37, 72, 97, 101, 111, 125, 138, 139]
#
# Selecting Influencer 3
# ------------------------------------
# Activated Nodes: [98, 89, 62, 93]
# Influencer: Node 64
# Degree: 12
# Neighbors: Nodes [12, 35, 39, 61, 65, 97, 113, 117, 125, 133, 137, 148]
#
# Selecting Influencer 4
# ------------------------------------
# Activated Nodes: [98, 89, 62, 93, 64]
# Influencer: Node 126
# Degree: 15
# Neighbors: Nodes [11, 21, 33, 43, 44, 51, 53, 57, 70, 76, 96, 101, 105, 119, 128]
#
# Selecting Influencer 5
# ------------------------------------
# Activated Nodes: [98, 89, 62, 93, 64, 126]
# Influencer: Node 19
# Degree: 11
# Neighbors: Nodes [12, 20, 53, 65, 73, 92, 108, 131, 135, 142, 144]
#
# Selecting Influencer 6
# ------------------------------------
# Activated Nodes: [98, 89, 62, 93, 64, 126, 19]
# Influencer: Node 9
# Degree: 12
# Neighbors: Nodes [5, 23, 49, 76, 77, 89, 97, 98, 106, 113, 144, 145]
#
# Selecting Influencer 7
# ------------------------------------
# Activated Nodes: [98, 89, 62, 93, 64, 126, 19, 9]
# Influencer: Node 43
# Degree: 24
# Neighbors: Nodes [0, 4, 8, 12, 21, 32, 35, 39, 52, 54, 65, 72, 74, 79, 80, 87, 89, 91, 101, 111, 114, 126, 134, 144]
#
# Selecting Influencer 8
# ------------------------------------
# Activated Nodes: [98, 89, 62, 93, 64, 126, 19, 9, 43]
# Influencer: Node 109
# Degree: 24
# Neighbors: Nodes [2, 13, 17, 18, 21, 24, 31, 45, 47, 59, 60, 63, 68, 70, 74, 79, 83, 91, 110, 117, 124, 142, 144, 148]
#
# Selecting Influencer 9
# ------------------------------------
# Activated Nodes: [98, 89, 62, 93, 64, 126, 19, 9, 43, 109]
# Influencer: Node 0
# Degree: 17
# Neighbors: Nodes [4, 14, 31, 42, 43, 52, 59, 60, 67, 68, 71, 73, 77, 98, 111, 132, 149]
#
# Selecting Influencer 10
# ------------------------------------
# Activated Nodes: [98, 89, 62, 93, 64, 126, 19, 9, 43, 109, 0]
# Influencer: Node 84
# Degree: 12
# Neighbors: Nodes [13, 30, 39, 47, 60, 83, 94, 101, 128, 129, 133, 137]
#
# Selecting Influencer 11
# ------------------------------------
# Activated Nodes: [98, 89, 62, 93, 64, 126, 19, 9, 43, 109, 0, 84]
# Influencer: Node 25
# Degree: 12
# Neighbors: Nodes [11, 14, 15, 26, 39, 57, 66, 71, 82, 123, 131, 141]
#
# Selecting Influencer 12
# ------------------------------------
# Activated Nodes: [98, 89, 62, 93, 64, 126, 19, 9, 43, 109, 0, 84, 25]
# Influencer: Node 100
# Degree: 6
# Neighbors: Nodes [5, 50, 101, 120, 131, 143]
#
# Selecting Influencer 13
# ------------------------------------
# Activated Nodes: [98, 89, 62, 93, 64, 126, 19, 9, 43, 109, 0, 84, 25, 100]
# Influencer: Node 77
# Degree: 12
# Neighbors: Nodes [0, 8, 9, 37, 45, 58, 76, 91, 124, 135, 136, 140]
#
# Selecting Influencer 14
# ------------------------------------
# Activated Nodes: [98, 89, 62, 93, 64, 126, 19, 9, 43, 109, 0, 84, 25, 100, 77, 45]
# Influencer: Node 5
# Degree: 15
# Neighbors: Nodes [1, 9, 15, 38, 40, 86, 92, 100, 112, 116, 122, 125, 136, 142, 145]
#
# Selecting Influencer 15
# ------------------------------------
# Activated Nodes: [98, 89, 62, 93, 64, 126, 19, 9, 43, 109, 0, 84, 25, 100, 77, 45, 5, 122, 3]
# Influencer: Node 27
# Degree: 11
# Neighbors: Nodes [10, 12, 18, 22, 31, 63, 79, 80, 90, 95, 116]
#
# Selecting Influencer 16
# ------------------------------------
# Activated Nodes: [98, 89, 62, 93, 64, 126, 19, 9, 43, 109, 0, 84, 25, 100, 77, 45, 5, 122, 3, 27]
# Influencer: Node 7
# Degree: 8
# Neighbors: Nodes [3, 10, 22, 67, 74, 81, 86, 95]
#
# Selecting Influencer 17
# ------------------------------------
# Activated Nodes: [98, 89, 62, 93, 64, 126, 19, 9, 43, 109, 0, 84, 25, 100, 77, 45, 5, 122, 3, 27, 7]
# Influencer: Node 96
# Degree: 11
# Neighbors: Nodes [16, 38, 45, 55, 66, 68, 73, 74, 90, 126, 141]
#
# Selecting Influencer 18
# ------------------------------------
# Activated Nodes: [98, 89, 62, 93, 64, 126, 19, 9, 43, 109, 0, 84, 25, 100, 77, 45, 5, 122, 3, 27, 7, 96]
# Influencer: Node 59
# Degree: 10
# Neighbors: Nodes [0, 20, 45, 69, 76, 97, 109, 115, 119, 129]
#
# Selecting Influencer 19
# ------------------------------------
# Activated Nodes: [98, 89, 62, 93, 64, 126, 19, 9, 43, 109, 0, 84, 25, 100, 77, 45, 5, 122, 3, 27, 7, 96, 59]
# Influencer: Node 17
# Degree: 19
# Neighbors: Nodes [16, 31, 37, 47, 49, 51, 52, 82, 103, 105, 108, 109, 111, 113, 114, 130, 139, 146, 147]
#
# Selecting Influencer 20
# ------------------------------------
# Activated Nodes: [98, 89, 62, 93, 64, 126, 19, 9, 43, 109, 0, 84, 25, 100, 77, 45, 5, 122, 3, 27, 7, 96, 59, 17]
# Influencer: Node 90
# Degree: 10
# Neighbors: Nodes [15, 27, 28, 53, 75, 79, 87, 96, 118, 131]
#
# Selecting Influencer 1
# ------------------------------------
# Activated Nodes: []
# Influencer: Node 74
# Degree: 16
# Neighbors: Nodes [7, 15, 20, 40, 43, 57, 63, 66, 92, 96, 104, 106, 109, 110, 114, 137]
#
# Selecting Influencer 2
# ------------------------------------
# Activated Nodes: [74]
# Influencer: Node 49
# Degree: 12
# Neighbors: Nodes [9, 11, 17, 23, 30, 39, 42, 46, 50, 52, 66, 99]
#
# Selecting Influencer 3
# ------------------------------------
# Activated Nodes: [74, 49]
# Influencer: Node 124
# Degree: 17
# Neighbors: Nodes [1, 10, 12, 13, 34, 36, 62, 75, 77, 80, 88, 89, 99, 108, 109, 119, 139]
#
# Selecting Influencer 4
# ------------------------------------
# Activated Nodes: [74, 49, 124]
# Influencer: Node 30
# Degree: 9
# Neighbors: Nodes [15, 24, 45, 49, 58, 66, 84, 117, 137]
#
# Selecting Influencer 5
# ------------------------------------
# Activated Nodes: [74, 49, 124, 30]
# Influencer: Node 101
# Degree: 15
# ...
# Influencer: Node 73
# Degree: 18
# Neighbors: Nodes [0, 16, 19, 23, 46, 57, 72, 80, 91, 94, 96, 99, 102, 105, 118, 120, 131, 139]
#
# Selecting Influencer 27
# ------------------------------------
# Activated Nodes: [15, 90, 43, 88, 109, 68, 132, 89, 28, 97, 12, 64, 14, 22, 40, 91, 122, 1, 66, 114, 131, 136, 6, 17, 37, 41, 78, 42, 0, 4, 63, 102, 72, 73, 120]
# Influencer: Node 92
# Degree: 18
# Neighbors: Nodes [5, 6, 19, 20, 22, 24, 47, 50, 54, 68, 74, 75, 85, 102, 114, 131, 144, 145]
#
# Selecting Influencer 28
# ------------------------------------
# Activated Nodes: [15, 90, 43, 88, 109, 68, 132, 89, 28, 97, 12, 64, 14, 22, 40, 91, 122, 1, 66, 114, 131, 136, 6, 17, 37, 41, 78, 42, 0, 4, 63, 102, 72, 73, 120, 92]
# Influencer: Node 139
# Degree: 18
# Neighbors: Nodes [6, 11, 17, 37, 38, 41, 51, 52, 65, 67, 73, 87, 93, 102, 103, 114, 122, 124]
#
# Selecting Influencer 29
# ------------------------------------
# Activated Nodes: [15, 90, 43, 88, 109, 68, 132, 89, 28, 97, 12, 64, 14, 22, 40, 91, 122, 1, 66, 114, 131, 136, 6, 17, 37, 41, 78, 42, 0, 4, 63, 102, 72, 73, 120, 92, 139]
# Influencer: Node 16
# Degree: 17
# Neighbors: Nodes [4, 8, 17, 29, 39, 47, 68, 73, 81, 88, 96, 113, 119, 135, 136, 146, 148]
# Selecting Influencer 1
# ------------------------------------
# {0: 1.0, 1: 1.0, 2: 1.0, 3: 1.0, 4: 1.0, 5: 1.0, 6: 1.0, 7: 1.0, 8: 1.0, 9: 1.0, 10: 1.0, 11: 1.0, 12: 2.0, 13: 1.0, 14: 1.0, 15: 1.0, 16: 1.0, 17: 1.0, 18: 1.0, 19: 1.0, 20: 1.0, 21: 1.0, 22: 2.0, 23: 1.0, 24: 2.0, 25: 1.0, 26: 1.0, 27: 1.0, 28: 1.0, 29: 1.0, 30: 1.0, 31: 1.0, 32: 1.0, 33: 1.0, 34: 1.0, 35: 4.0, 36: 1.0, 37: 1.0, 38: 1.0, 39: 2.0, 40: 2.0, 41: 1.0, 42: 1.0, 43: 1.0, 44: 2.0, 45: 1.0, 46: 2.0, 47: 1.0, 48: 1.0, 49: 2.0, 50: 1.0, 51: 1.0, 52: 1.0, 53: 3.0, 54: 2.0, 55: 1.0, 56: 1.0, 57: 3.0, 58: 1.0, 59: 1.0, 60: 1.0, 61: 1.0, 62: 1.0, 63: 1.0, 64: 1.0, 65: 1.0, 66: 1.0, 67: 1.0, 68: 1.0, 69: 1.0, 