# %%
import networkx as nx
import ModelConfig as mc
import IndependentCascadesModelP001 as icm
# import IndependentCascadesModelP010 as icm
# import WeightedCascadeModel as icm
import operator
import random 
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
def GreedySelect(g, activated_nodes, model, config, greedy_i):
    ''' 
    Select node with max average marginal gain
    Variable 'mg' refers to 'marginal gain'
    Number of iterations to find average marginal gain defaulted to 100
    '''
    mg_dict = {}
    for candidate in g.nodes():
        if candidate in activated_nodes:
            continue
        mg = 0
        for i in range(greedy_i):
            newly_activated_nodes = GreedySim(model, config, candidate)
            mg += len(newly_activated_nodes)
        avg_mg = mg/greedy_i
        mg_dict[candidate] = avg_mg
    influencer = max(mg_dict.items(), key=operator.itemgetter(1))[0]
    print(f"Selected Influencer: Node {influencer}")
    
    return influencer

def GreedySim(model, config, candidate):
    config.add_model_initial_configuration("Infected", [candidate])
    model.set_initial_status(config)
    active_set_size, newly_activated_nodes = model.iteration_bunch()
    newly_activated_nodes.append(candidate)
    model.mg_reset(newly_activated_nodes)
    
    return newly_activated_nodes

# %%
def InitModel(g):
    model = icm.IndependentCascadesModel(g)
    config = mc.Configuration()
    return model, config

def InfluenceSpread(model, config, influencer):
    config.add_model_initial_configuration("Infected", [influencer])
    model.set_initial_status(config)
    active_set_size, newly_activated_nodes = model.iteration_bunch()
    return active_set_size, newly_activated_nodes

def get_combination(g, target_set_size, greedy_i=100):
    '''
    Assuming continuous process (previously activated nodes cannot reattempt)
    As compared to one-time influence spread, all influencer same start point
    Default strategy set as greedy 
    '''
    # prepare graph for respective strategies
    g = remove_isolated_nodes(g)
        
    # initialize diffusion model
    model, config = InitModel(g)
    
    all_activated_nodes = []
    influencers = []
    active_ss_list = []
    for i in range(1, target_set_size+1):
        print(f"Selecting Influencer {i}")
        print("------------------------------------")
        
        influencer = GreedySelect(g, all_activated_nodes, model, config, greedy_i)
        influencers.append(influencer)

        active_set_size, newly_activated_nodes = InfluenceSpread(model, config, influencer)
        print(f"Newly Activated Nodes: {newly_activated_nodes}")
        newly_activated_nodes.append(influencer)
        all_activated_nodes.extend(newly_activated_nodes)
        print(f"All Activated Nodes: {all_activated_nodes}")
        print(f"Active Set Size: {active_set_size}")
        
        active_set_size, all_activated_nodes = model.random_deactivation(all_activated_nodes)
        print(f"Final Activated Nodes: {all_activated_nodes}")
        print(f"Final Active Set Size: {active_set_size}")
        print("")

        model.is_reset()
        active_ss_list.append(active_set_size)

    return influencers, active_ss_list[-1]

# %%
def remove_isolated_nodes(g):
    isolated_nodes = []
    for pair in g.degree:
        node = pair[0]
        degree = pair[1]
        if degree == 0:
            isolated_nodes.append(node)

    for node in isolated_nodes:
        g.remove_node(node)
        
    return g

# %%
# Simulation: Build Long Term Reward Reference

# %%
g = nx.erdos_renyi_graph(150, 0.1) #number of nodes, probability to form edges
g = remove_isolated_nodes(g)
target_set_size = 5
greedy_i = 50
LT_ref = []
num_i = 100
for i in range(1, num_i+1):
    print(f"Combination {i}")
    print("------------------------------------")
        
    combination = get_combination(g, target_set_size, greedy_i)
    LT_ref.append(combination)

LT_ref.sort(key=lambda x:x[1], reverse=True)
sorted_influencers = []
for influencers, LT_reward in LT_ref:
    if influencers in sorted_influencers: #better if can compare LT_reward and use the one with higher value
        continue  
    sorted_influencers.append(influencers)
# Out:
# Combination 1
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: []
# All Activated Nodes: [33]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [33]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: []
# All Activated Nodes: [33]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [33]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 38
# Newly Activated Nodes: [100]
# All Activated Nodes: [100, 38]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [100, 38]
# Final Active Set Size: 2
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 135
# Newly Activated Nodes: []
# All Activated Nodes: [100, 38, 135]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [100, 38, 135]
# Final Active Set Size: 3
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 47
# Newly Activated Nodes: []
# All Activated Nodes: [100, 38, 135, 47]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [100, 38, 135, 47]
# Final Active Set Size: 4
#
# Combination 2
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 43
# Newly Activated Nodes: []
# All Activated Nodes: [43]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [43]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 44
# Newly Activated Nodes: [47]
# All Activated Nodes: [47, 44]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [47, 44]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 31
# Newly Activated Nodes: []
# All Activated Nodes: [47, 44, 31]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [47, 44, 31]
# Final Active Set Size: 3
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 136
# Newly Activated Nodes: []
# All Activated Nodes: [47, 44, 31, 136]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [47, 44, 31, 136]
# Final Active Set Size: 4
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 121
# Newly Activated Nodes: []
# All Activated Nodes: [47, 44, 31, 136, 121]
# Active Set Size: 5
# Number of deactivations: 1
# Deactivated Nodes: [136]
# Final Activated Nodes: [47, 44, 31, 121]
# Final Active Set Size: 4
#
# Combination 3
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 8
# Newly Activated Nodes: [140]
# All Activated Nodes: [140, 8]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [140, 8]
# Final Active Set Size: 2
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 90
# Newly Activated Nodes: []
# All Activated Nodes: [140, 8, 90]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [90]
# Final Activated Nodes: [140, 8]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 68
# Newly Activated Nodes: []
# All Activated Nodes: [140, 8, 68]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [140, 8, 68]
# Final Active Set Size: 3
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 123
# Newly Activated Nodes: []
# All Activated Nodes: [140, 8, 68, 123]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [140, 8, 68, 123]
# Final Active Set Size: 4
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: [120, 146]
# All Activated Nodes: [140, 8, 68, 123, 120, 146, 33]
# Active Set Size: 7
# Number of deactivations: 1
# Deactivated Nodes: [33]
# Final Activated Nodes: [140, 8, 68, 123, 120, 146]
# Final Active Set Size: 6
#
# Combination 4
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 103
# Newly Activated Nodes: []
# All Activated Nodes: [103]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [103]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: [58]
# All Activated Nodes: [58, 33]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [58, 33]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 57
# Newly Activated Nodes: []
# All Activated Nodes: [58, 33, 57]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [58]
# Final Activated Nodes: [33, 57]
# Final Active Set Size: 2
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 47
# Newly Activated Nodes: []
# All Activated Nodes: [33, 57, 47]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [33, 57, 47]
# Final Active Set Size: 3
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 7
# Newly Activated Nodes: []
# All Activated Nodes: [33, 57, 47, 7]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [33, 57, 47, 7]
# Final Active Set Size: 4
#
# Combination 5
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 2
# Newly Activated Nodes: []
# All Activated Nodes: [2]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [2]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 30
# Newly Activated Nodes: []
# All Activated Nodes: [30]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [30]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 4
# Newly Activated Nodes: []
# All Activated Nodes: [4]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [4]
# Final Active Set Size: 1
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 38
# Newly Activated Nodes: []
# All Activated Nodes: [4, 38]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [38]
# Final Activated Nodes: [4]
# Final Active Set Size: 1
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 38
# Newly Activated Nodes: []
# All Activated Nodes: [4, 38]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [4]
# Final Activated Nodes: [38]
# Final Active Set Size: 1
#
# Combination 6
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 25
# Newly Activated Nodes: [117, 119, 132]
# All Activated Nodes: [117, 119, 132, 25]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [117, 119, 132, 25]
# Final Active Set Size: 4
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: []
# All Activated Nodes: [117, 119, 132, 25, 33]
# Active Set Size: 5
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [117, 119, 132, 25, 33]
# Final Active Set Size: 5
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 120
# Newly Activated Nodes: []
# All Activated Nodes: [117, 119, 132, 25, 33, 120]
# Active Set Size: 6
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [117, 119, 132, 25, 33, 120]
# Final Active Set Size: 6
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 2
# Newly Activated Nodes: []
# All Activated Nodes: [117, 119, 132, 25, 33, 120, 2]
# Active Set Size: 7
# Number of deactivations: 1
# Deactivated Nodes: [33]
# Final Activated Nodes: [117, 119, 132, 25, 120, 2]
# Final Active Set Size: 6
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 35
# Newly Activated Nodes: []
# All Activated Nodes: [117, 119, 132, 25, 120, 2, 35]
# Active Set Size: 7
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [117, 119, 132, 25, 120, 2, 35]
# Final Active Set Size: 7
#
# Combination 7
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 116
# Newly Activated Nodes: [79]
# All Activated Nodes: [79, 116]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [116]
# Final Activated Nodes: [79]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 35
# Newly Activated Nodes: []
# All Activated Nodes: [79, 35]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [79, 35]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: []
# All Activated Nodes: [79, 35, 33]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [79, 35, 33]
# Final Active Set Size: 3
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 123
# Newly Activated Nodes: [135]
# All Activated Nodes: [79, 35, 33, 135, 123]
# Active Set Size: 5
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [79, 35, 33, 135, 123]
# Final Active Set Size: 5
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 32
# Newly Activated Nodes: []
# All Activated Nodes: [79, 35, 33, 135, 123, 32]
# Active Set Size: 6
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [79, 35, 33, 135, 123, 32]
# Final Active Set Size: 6
#
# Combination 8
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: []
# All Activated Nodes: [33]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [33]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 38
# Newly Activated Nodes: [113]
# All Activated Nodes: [33, 113, 38]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [33]
# Final Activated Nodes: [113, 38]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 52
# Newly Activated Nodes: []
# All Activated Nodes: [113, 38, 52]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [113]
# Final Activated Nodes: [38, 52]
# Final Active Set Size: 2
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 1
# Newly Activated Nodes: []
# All Activated Nodes: [38, 52, 1]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [52]
# Final Activated Nodes: [38, 1]
# Final Active Set Size: 2
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 68
# Newly Activated Nodes: []
# All Activated Nodes: [38, 1, 68]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [68]
# Final Activated Nodes: [38, 1]
# Final Active Set Size: 2
#
# Combination 9
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 25
# Newly Activated Nodes: []
# All Activated Nodes: [25]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [25]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 125
# Newly Activated Nodes: []
# All Activated Nodes: [125]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [125]
# Final Active Set Size: 1
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 38
# Newly Activated Nodes: []
# All Activated Nodes: [125, 38]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [125, 38]
# Final Active Set Size: 2
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 128
# Newly Activated Nodes: []
# All Activated Nodes: [125, 38, 128]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [125, 38, 128]
# Final Active Set Size: 3
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 82
# Newly Activated Nodes: [4]
# All Activated Nodes: [125, 38, 128, 4, 82]
# Active Set Size: 5
# Number of deactivations: 1
# Deactivated Nodes: [125]
# Final Activated Nodes: [38, 128, 4, 82]
# Final Active Set Size: 4
#
# Combination 10
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: []
# All Activated Nodes: [33]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [33]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 2
# Newly Activated Nodes: []
# All Activated Nodes: [2]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [2]
# Final Active Set Size: 1
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 57
# Newly Activated Nodes: [77, 121]
# All Activated Nodes: [2, 77, 121, 57]
# Active Set Size: 4
# Number of deactivations: 1
# Deactivated Nodes: [77]
# Final Activated Nodes: [2, 121, 57]
# Final Active Set Size: 3
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 25
# Newly Activated Nodes: []
# All Activated Nodes: [2, 121, 57, 25]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [2, 121, 57, 25]
# Final Active Set Size: 4
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 43
# Newly Activated Nodes: []
# All Activated Nodes: [2, 121, 57, 25, 43]
# Active Set Size: 5
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [2, 121, 57, 25, 43]
# Final Active Set Size: 5
#
# Combination 11
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 58
# Newly Activated Nodes: []
# All Activated Nodes: [58]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [58]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 58
# Newly Activated Nodes: []
# All Activated Nodes: [58]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [58]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 103
# Newly Activated Nodes: []
# All Activated Nodes: [103]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [103]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 58
# Newly Activated Nodes: []
# All Activated Nodes: [58]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [58]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 120
# Newly Activated Nodes: []
# All Activated Nodes: [120]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [120]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Combination 12
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 56
# Newly Activated Nodes: []
# All Activated Nodes: [56]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [56]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 31
# Newly Activated Nodes: []
# All Activated Nodes: [31]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [31]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 38
# Newly Activated Nodes: []
# All Activated Nodes: [38]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [38]
# Final Active Set Size: 1
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 44
# Newly Activated Nodes: []
# All Activated Nodes: [38, 44]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [44]
# Final Activated Nodes: [38]
# Final Active Set Size: 1
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 4
# Newly Activated Nodes: [33]
# All Activated Nodes: [38, 33, 4]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [38, 33, 4]
# Final Active Set Size: 3
#
# Combination 13
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 38
# Newly Activated Nodes: [78, 63, 1]
# All Activated Nodes: [78, 63, 1, 38]
# Active Set Size: 4
# Number of deactivations: 1
# Deactivated Nodes: [63]
# Final Activated Nodes: [78, 1, 38]
# Final Active Set Size: 3
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 4
# Newly Activated Nodes: []
# All Activated Nodes: [78, 1, 38, 4]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [78, 1, 38, 4]
# Final Active Set Size: 4
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 48
# Newly Activated Nodes: []
# All Activated Nodes: [78, 1, 38, 4, 48]
# Active Set Size: 5
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [78, 1, 38, 4, 48]
# Final Active Set Size: 5
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 132
# Newly Activated Nodes: []
# All Activated Nodes: [78, 1, 38, 4, 48, 132]
# Active Set Size: 6
# Number of deactivations: 1
# Deactivated Nodes: [48]
# Final Activated Nodes: [78, 1, 38, 4, 132]
# Final Active Set Size: 5
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 128
# Newly Activated Nodes: []
# All Activated Nodes: [78, 1, 38, 4, 132, 128]
# Active Set Size: 6
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [78, 1, 38, 4, 132, 128]
# Final Active Set Size: 6
#
# Combination 14
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 44
# Newly Activated Nodes: []
# All Activated Nodes: [44]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [44]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 117
# Newly Activated Nodes: []
# All Activated Nodes: [44, 117]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [117]
# Final Activated Nodes: [44]
# Final Active Set Size: 1
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 25
# Newly Activated Nodes: []
# All Activated Nodes: [44, 25]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [44]
# Final Activated Nodes: [25]
# Final Active Set Size: 1
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 35
# Newly Activated Nodes: []
# All Activated Nodes: [25, 35]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [25, 35]
# Final Active Set Size: 2
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 38
# Newly Activated Nodes: []
# All Activated Nodes: [25, 35, 38]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [25, 35, 38]
# Final Active Set Size: 3
#
# Combination 15
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 120
# Newly Activated Nodes: []
# All Activated Nodes: [120]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [120]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 25
# Newly Activated Nodes: []
# All Activated Nodes: [120, 25]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [120, 25]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: []
# All Activated Nodes: [120, 25, 33]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [25]
# Final Activated Nodes: [120, 33]
# Final Active Set Size: 2
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 136
# Newly Activated Nodes: [69]
# All Activated Nodes: [120, 33, 69, 136]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [120, 33, 69, 136]
# Final Active Set Size: 4
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 57
# Newly Activated Nodes: []
# All Activated Nodes: [120, 33, 69, 136, 57]
# Active Set Size: 5
# Number of deactivations: 1
# Deactivated Nodes: [69]
# Final Activated Nodes: [120, 33, 136, 57]
# Final Active Set Size: 4
#
# Combination 16
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 123
# Newly Activated Nodes: [121, 39]
# All Activated Nodes: [121, 39, 123]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [121, 39, 123]
# Final Active Set Size: 3
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 2
# Newly Activated Nodes: []
# All Activated Nodes: [121, 39, 123, 2]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [121, 39, 123, 2]
# Final Active Set Size: 4
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 129
# Newly Activated Nodes: []
# All Activated Nodes: [121, 39, 123, 2, 129]
# Active Set Size: 5
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [121, 39, 123, 2, 129]
# Final Active Set Size: 5
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: [3]
# All Activated Nodes: [121, 39, 123, 2, 129, 3, 33]
# Active Set Size: 7
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [121, 39, 123, 2, 129, 3, 33]
# Final Active Set Size: 7
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 38
# Newly Activated Nodes: []
# All Activated Nodes: [121, 39, 123, 2, 129, 3, 33, 38]
# Active Set Size: 8
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [121, 39, 123, 2, 129, 3, 33, 38]
# Final Active Set Size: 8
#
# Combination 17
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 37
# Newly Activated Nodes: []
# All Activated Nodes: [37]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [37]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 93
# Newly Activated Nodes: []
# All Activated Nodes: [37, 93]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [93]
# Final Activated Nodes: [37]
# Final Active Set Size: 1
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 52
# Newly Activated Nodes: [19]
# All Activated Nodes: [37, 19, 52]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [37]
# Final Activated Nodes: [19, 52]
# Final Active Set Size: 2
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 0
# Newly Activated Nodes: []
# All Activated Nodes: [19, 52, 0]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [19, 52, 0]
# Final Active Set Size: 3
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 148
# Newly Activated Nodes: []
# All Activated Nodes: [19, 52, 0, 148]
# Active Set Size: 4
# Number of deactivations: 1
# Deactivated Nodes: [0]
# Final Activated Nodes: [19, 52, 148]
# Final Active Set Size: 3
#
# Combination 18
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 120
# Newly Activated Nodes: []
# All Activated Nodes: [120]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [120]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 145
# Newly Activated Nodes: []
# All Activated Nodes: [120, 145]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [145]
# Final Activated Nodes: [120]
# Final Active Set Size: 1
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 44
# Newly Activated Nodes: []
# All Activated Nodes: [120, 44]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [44]
# Final Activated Nodes: [120]
# Final Active Set Size: 1
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: []
# All Activated Nodes: [120, 33]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [120]
# Final Activated Nodes: [33]
# Final Active Set Size: 1
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 44
# Newly Activated Nodes: []
# All Activated Nodes: [33, 44]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [33]
# Final Activated Nodes: [44]
# Final Active Set Size: 1
#
# Combination 19
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 132
# Newly Activated Nodes: []
# All Activated Nodes: [132]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [132]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 103
# Newly Activated Nodes: []
# All Activated Nodes: [132, 103]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [132]
# Final Activated Nodes: [103]
# Final Active Set Size: 1
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: [38, 109, 146]
# All Activated Nodes: [103, 38, 109, 146, 33]
# Active Set Size: 5
# Number of deactivations: 1
# Deactivated Nodes: [33]
# Final Activated Nodes: [103, 38, 109, 146]
# Final Active Set Size: 4
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 7
# Newly Activated Nodes: []
# All Activated Nodes: [103, 38, 109, 146, 7]
# Active Set Size: 5
# Number of deactivations: 1
# Deactivated Nodes: [109]
# Final Activated Nodes: [103, 38, 146, 7]
# Final Active Set Size: 4
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 99
# Newly Activated Nodes: []
# All Activated Nodes: [103, 38, 146, 7, 99]
# Active Set Size: 5
# Number of deactivations: 1
# Deactivated Nodes: [7]
# Final Activated Nodes: [103, 38, 146, 99]
# Final Active Set Size: 4
#
# Combination 20
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 62
# Newly Activated Nodes: []
# All Activated Nodes: [62]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [62]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 105
# Newly Activated Nodes: []
# All Activated Nodes: [105]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [105]
# Final Active Set Size: 1
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 141
# Newly Activated Nodes: [72, 43]
# All Activated Nodes: [105, 72, 43, 141]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [105, 72, 43, 141]
# Final Active Set Size: 4
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 30
# Newly Activated Nodes: []
# All Activated Nodes: [105, 72, 43, 141, 30]
# Active Set Size: 5
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [105, 72, 43, 141, 30]
# Final Active Set Size: 5
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: []
# All Activated Nodes: [105, 72, 43, 141, 30, 33]
# Active Set Size: 6
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [105, 72, 43, 141, 30, 33]
# Final Active Set Size: 6
#
# Combination 21
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 135
# Newly Activated Nodes: []
# All Activated Nodes: [135]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [135]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: []
# All Activated Nodes: [33]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [33]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 88
# Newly Activated Nodes: []
# All Activated Nodes: [88]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [88]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 58
# Newly Activated Nodes: []
# All Activated Nodes: [58]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [58]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 38
# Newly Activated Nodes: []
# All Activated Nodes: [38]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [38]
# Final Active Set Size: 1
#
# Combination 22
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: [55]
# All Activated Nodes: [55, 33]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [55, 33]
# Final Active Set Size: 2
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 44
# Newly Activated Nodes: []
# All Activated Nodes: [55, 33, 44]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [55, 33, 44]
# Final Active Set Size: 3
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 58
# Newly Activated Nodes: []
# All Activated Nodes: [55, 33, 44, 58]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [55, 33, 44, 58]
# Final Active Set Size: 4
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 73
# Newly Activated Nodes: []
# All Activated Nodes: [55, 33, 44, 58, 73]
# Active Set Size: 5
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [55, 33, 44, 58, 73]
# Final Active Set Size: 5
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 90
# Newly Activated Nodes: []
# All Activated Nodes: [55, 33, 44, 58, 73, 90]
# Active Set Size: 6
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [55, 33, 44, 58, 73, 90]
# Final Active Set Size: 6
#
# Combination 23
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 4
# Newly Activated Nodes: []
# All Activated Nodes: [4]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [4]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 9
# Newly Activated Nodes: []
# All Activated Nodes: [9]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [9]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 38
# Newly Activated Nodes: [68]
# All Activated Nodes: [68, 38]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [38]
# Final Activated Nodes: [68]
# Final Active Set Size: 1
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 38
# Newly Activated Nodes: [78, 18, 73]
# All Activated Nodes: [68, 78, 18, 73, 38]
# Active Set Size: 5
# Number of deactivations: 1
# Deactivated Nodes: [73]
# Final Activated Nodes: [68, 78, 18, 38]
# Final Active Set Size: 4
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 57
# Newly Activated Nodes: []
# All Activated Nodes: [68, 78, 18, 38, 57]
# Active Set Size: 5
# Number of deactivations: 1
# Deactivated Nodes: [38]
# Final Activated Nodes: [68, 78, 18, 57]
# Final Active Set Size: 4
#
# Combination 24
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 57
# Newly Activated Nodes: []
# All Activated Nodes: [57]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [57]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 12
# Newly Activated Nodes: []
# All Activated Nodes: [57, 12]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [57, 12]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 104
# Newly Activated Nodes: []
# All Activated Nodes: [57, 12, 104]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [12]
# Final Activated Nodes: [57, 104]
# Final Active Set Size: 2
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 18
# Newly Activated Nodes: []
# All Activated Nodes: [57, 104, 18]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [57, 104, 18]
# Final Active Set Size: 3
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 88
# Newly Activated Nodes: []
# All Activated Nodes: [57, 104, 18, 88]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [57, 104, 18, 88]
# Final Active Set Size: 4
#
# Combination 25
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 113
# Newly Activated Nodes: []
# All Activated Nodes: [113]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [113]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: [146]
# All Activated Nodes: [146, 33]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [33]
# Final Activated Nodes: [146]
# Final Active Set Size: 1
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 57
# Newly Activated Nodes: [62]
# All Activated Nodes: [146, 62, 57]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [146, 62, 57]
# Final Active Set Size: 3
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: []
# All Activated Nodes: [146, 62, 57, 33]
# Active Set Size: 4
# Number of deactivations: 1
# Deactivated Nodes: [33]
# Final Activated Nodes: [146, 62, 57]
# Final Active Set Size: 3
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 30
# Newly Activated Nodes: []
# All Activated Nodes: [146, 62, 57, 30]
# Active Set Size: 4
# Number of deactivations: 1
# Deactivated Nodes: [57]
# Final Activated Nodes: [146, 62, 30]
# Final Active Set Size: 3
#
# Combination 26
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 44
# Newly Activated Nodes: []
# All Activated Nodes: [44]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [44]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 12
# Newly Activated Nodes: []
# All Activated Nodes: [44, 12]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [44, 12]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 25
# Newly Activated Nodes: []
# All Activated Nodes: [44, 12, 25]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [44, 12, 25]
# Final Active Set Size: 3
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 31
# Newly Activated Nodes: []
# All Activated Nodes: [44, 12, 25, 31]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [44, 12, 25, 31]
# Final Active Set Size: 4
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 9
# Newly Activated Nodes: []
# All Activated Nodes: [44, 12, 25, 31, 9]
# Active Set Size: 5
# Number of deactivations: 1
# Deactivated Nodes: [12]
# Final Activated Nodes: [44, 25, 31, 9]
# Final Active Set Size: 4
#
# Combination 27
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 72
# Newly Activated Nodes: []
# All Activated Nodes: [72]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [72]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 44
# Newly Activated Nodes: []
# All Activated Nodes: [72, 44]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [72, 44]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 48
# Newly Activated Nodes: []
# All Activated Nodes: [72, 44, 48]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [72, 44, 48]
# Final Active Set Size: 3
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: []
# All Activated Nodes: [72, 44, 48, 33]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [72, 44, 48, 33]
# Final Active Set Size: 4
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 73
# Newly Activated Nodes: []
# All Activated Nodes: [72, 44, 48, 33, 73]
# Active Set Size: 5
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [72, 44, 48, 33, 73]
# Final Active Set Size: 5
#
# Combination 28
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 30
# Newly Activated Nodes: []
# All Activated Nodes: [30]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [30]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 43
# Newly Activated Nodes: []
# All Activated Nodes: [43]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [43]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 30
# Newly Activated Nodes: []
# All Activated Nodes: [30]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [30]
# Final Active Set Size: 1
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 58
# Newly Activated Nodes: []
# All Activated Nodes: [30, 58]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [30]
# Final Activated Nodes: [58]
# Final Active Set Size: 1
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 4
# Newly Activated Nodes: []
# All Activated Nodes: [58, 4]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [4]
# Final Activated Nodes: [58]
# Final Active Set Size: 1
#
# Combination 29
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 10
# Newly Activated Nodes: []
# All Activated Nodes: [10]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [10]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 38
# Newly Activated Nodes: []
# All Activated Nodes: [10, 38]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [10, 38]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: []
# All Activated Nodes: [10, 38, 33]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [38]
# Final Activated Nodes: [10, 33]
# Final Active Set Size: 2
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 31
# Newly Activated Nodes: []
# All Activated Nodes: [10, 33, 31]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [10, 33, 31]
# Final Active Set Size: 3
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 1
# Newly Activated Nodes: []
# All Activated Nodes: [10, 33, 31, 1]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [10, 33, 31, 1]
# Final Active Set Size: 4
#
# Combination 30
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 126
# Newly Activated Nodes: []
# All Activated Nodes: [126]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [126]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 38
# Newly Activated Nodes: []
# All Activated Nodes: [38]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [38]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 37
# Newly Activated Nodes: [5]
# All Activated Nodes: [5, 37]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [37]
# Final Activated Nodes: [5]
# Final Active Set Size: 1
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 58
# Newly Activated Nodes: []
# All Activated Nodes: [5, 58]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [5, 58]
# Final Active Set Size: 2
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 121
# Newly Activated Nodes: []
# All Activated Nodes: [5, 58, 121]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [5]
# Final Activated Nodes: [58, 121]
# Final Active Set Size: 2
#
# Combination 31
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: []
# All Activated Nodes: [33]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [33]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 7
# Newly Activated Nodes: []
# All Activated Nodes: [7]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [7]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: []
# All Activated Nodes: [33]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [33]
# Final Active Set Size: 1
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 47
# Newly Activated Nodes: []
# All Activated Nodes: [33, 47]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [47]
# Final Activated Nodes: [33]
# Final Active Set Size: 1
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 57
# Newly Activated Nodes: []
# All Activated Nodes: [33, 57]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [57]
# Final Activated Nodes: [33]
# Final Active Set Size: 1
#
# Combination 32
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 4
# Newly Activated Nodes: []
# All Activated Nodes: [4]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [4]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 0
# Newly Activated Nodes: []
# All Activated Nodes: [0]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [0]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: []
# All Activated Nodes: [33]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [33]
# Final Active Set Size: 1
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 57
# Newly Activated Nodes: []
# All Activated Nodes: [33, 57]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [33]
# Final Activated Nodes: [57]
# Final Active Set Size: 1
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 44
# Newly Activated Nodes: [60]
# All Activated Nodes: [57, 60, 44]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [57, 60, 44]
# Final Active Set Size: 3
#
# Combination 33
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 77
# Newly Activated Nodes: []
# All Activated Nodes: [77]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [77]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 57
# Newly Activated Nodes: []
# All Activated Nodes: [57]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [57]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 2
# Newly Activated Nodes: []
# All Activated Nodes: [2]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [2]
# Final Active Set Size: 1
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: []
# All Activated Nodes: [2, 33]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [2, 33]
# Final Active Set Size: 2
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 145
# Newly Activated Nodes: []
# All Activated Nodes: [2, 33, 145]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [2]
# Final Activated Nodes: [33, 145]
# Final Active Set Size: 2
#
# Combination 34
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 4
# Newly Activated Nodes: []
# All Activated Nodes: [4]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [4]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 44
# Newly Activated Nodes: []
# All Activated Nodes: [44]
# Active Set Size: 1
# ...
# Final Active Set Size: 5
#
# Combination 90
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: []
# All Activated Nodes: [33]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [33]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 18
# Newly Activated Nodes: [34, 81]
# All Activated Nodes: [34, 81, 18]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [34, 81, 18]
# Final Active Set Size: 3
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 58
# Newly Activated Nodes: []
# All Activated Nodes: [34, 81, 18, 58]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [34, 81, 18, 58]
# Final Active Set Size: 4
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 123
# Newly Activated Nodes: []
# All Activated Nodes: [34, 81, 18, 58, 123]
# Active Set Size: 5
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [34, 81, 18, 58, 123]
# Final Active Set Size: 5
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 141
# Newly Activated Nodes: [117]
# All Activated Nodes: [34, 81, 18, 58, 123, 117, 141]
# Active Set Size: 7
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [34, 81, 18, 58, 123, 117, 141]
# Final Active Set Size: 7
#
# Combination 91
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 57
# Newly Activated Nodes: []
# All Activated Nodes: [57]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [57]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: []
# All Activated Nodes: [57, 33]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [57]
# Final Activated Nodes: [33]
# Final Active Set Size: 1
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 1
# Newly Activated Nodes: []
# All Activated Nodes: [33, 1]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [33, 1]
# Final Active Set Size: 2
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 38
# Newly Activated Nodes: []
# All Activated Nodes: [33, 1, 38]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [1]
# Final Activated Nodes: [33, 38]
# Final Active Set Size: 2
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 120
# Newly Activated Nodes: []
# All Activated Nodes: [33, 38, 120]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [33, 38, 120]
# Final Active Set Size: 3
#
# Combination 92
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 57
# Newly Activated Nodes: []
# All Activated Nodes: [57]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [57]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: []
# All Activated Nodes: [57, 33]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [57]
# Final Activated Nodes: [33]
# Final Active Set Size: 1
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 57
# Newly Activated Nodes: []
# All Activated Nodes: [33, 57]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [33, 57]
# Final Active Set Size: 2
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 12
# Newly Activated Nodes: []
# All Activated Nodes: [33, 57, 12]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [33, 57, 12]
# Final Active Set Size: 3
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 38
# Newly Activated Nodes: []
# All Activated Nodes: [33, 57, 12, 38]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [33, 57, 12, 38]
# Final Active Set Size: 4
#
# Combination 93
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 25
# Newly Activated Nodes: [77, 129]
# All Activated Nodes: [77, 129, 25]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [129]
# Final Activated Nodes: [77, 25]
# Final Active Set Size: 2
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 58
# Newly Activated Nodes: []
# All Activated Nodes: [77, 25, 58]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [77, 25, 58]
# Final Active Set Size: 3
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 31
# Newly Activated Nodes: [91]
# All Activated Nodes: [77, 25, 58, 91, 31]
# Active Set Size: 5
# Number of deactivations: 1
# Deactivated Nodes: [31]
# Final Activated Nodes: [77, 25, 58, 91]
# Final Active Set Size: 4
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 72
# Newly Activated Nodes: []
# All Activated Nodes: [77, 25, 58, 91, 72]
# Active Set Size: 5
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [77, 25, 58, 91, 72]
# Final Active Set Size: 5
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 57
# Newly Activated Nodes: []
# All Activated Nodes: [77, 25, 58, 91, 72, 57]
# Active Set Size: 6
# Number of deactivations: 1
# Deactivated Nodes: [58]
# Final Activated Nodes: [77, 25, 91, 72, 57]
# Final Active Set Size: 5
#
# Combination 94
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 25
# Newly Activated Nodes: []
# All Activated Nodes: [25]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [25]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 7
# Newly Activated Nodes: []
# All Activated Nodes: [25, 7]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [25, 7]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: []
# All Activated Nodes: [25, 7, 33]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [25]
# Final Activated Nodes: [7, 33]
# Final Active Set Size: 2
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 132
# Newly Activated Nodes: []
# All Activated Nodes: [7, 33, 132]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [7, 33, 132]
# Final Active Set Size: 3
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 75
# Newly Activated Nodes: []
# All Activated Nodes: [7, 33, 132, 75]
# Active Set Size: 4
# Number of deactivations: 1
# Deactivated Nodes: [7]
# Final Activated Nodes: [33, 132, 75]
# Final Active Set Size: 3
#
# Combination 95
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 2
# Newly Activated Nodes: []
# All Activated Nodes: [2]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [2]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 132
# Newly Activated Nodes: []
# All Activated Nodes: [132]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [132]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 58
# Newly Activated Nodes: []
# All Activated Nodes: [58]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [58]
# Final Active Set Size: 1
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 60
# Newly Activated Nodes: []
# All Activated Nodes: [58, 60]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [58, 60]
# Final Active Set Size: 2
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 88
# Newly Activated Nodes: []
# All Activated Nodes: [58, 60, 88]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [58, 60, 88]
# Final Active Set Size: 3
#
# Combination 96
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 106
# Newly Activated Nodes: []
# All Activated Nodes: [106]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [106]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 145
# Newly Activated Nodes: []
# All Activated Nodes: [145]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [145]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 113
# Newly Activated Nodes: [145]
# All Activated Nodes: [145, 113]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [145]
# Final Activated Nodes: [113]
# Final Active Set Size: 1
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 57
# Newly Activated Nodes: []
# All Activated Nodes: [113, 57]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [57]
# Final Activated Nodes: [113]
# Final Active Set Size: 1
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 141
# Newly Activated Nodes: []
# All Activated Nodes: [113, 141]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [141]
# Final Activated Nodes: [113]
# Final Active Set Size: 1
#
# Combination 97
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 146
# Newly Activated Nodes: []
# All Activated Nodes: [146]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [146]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 57
# Newly Activated Nodes: [101]
# All Activated Nodes: [146, 101, 57]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [146, 101, 57]
# Final Active Set Size: 3
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: []
# All Activated Nodes: [146, 101, 57, 33]
# Active Set Size: 4
# Number of deactivations: 1
# Deactivated Nodes: [33]
# Final Activated Nodes: [146, 101, 57]
# Final Active Set Size: 3
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 88
# Newly Activated Nodes: []
# All Activated Nodes: [146, 101, 57, 88]
# Active Set Size: 4
# Number of deactivations: 1
# Deactivated Nodes: [57]
# Final Activated Nodes: [146, 101, 88]
# Final Active Set Size: 3
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: []
# All Activated Nodes: [146, 101, 88, 33]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [146, 101, 88, 33]
# Final Active Set Size: 4
#
# Combination 98
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: []
# All Activated Nodes: [33]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [33]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 111
# Newly Activated Nodes: []
# All Activated Nodes: [33, 111]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [33, 111]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 104
# Newly Activated Nodes: []
# All Activated Nodes: [33, 111, 104]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [33]
# Final Activated Nodes: [111, 104]
# Final Active Set Size: 2
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 57
# Newly Activated Nodes: [130]
# All Activated Nodes: [111, 104, 130, 57]
# Active Set Size: 4
# Number of deactivations: 1
# Deactivated Nodes: [130]
# Final Activated Nodes: [111, 104, 57]
# Final Active Set Size: 3
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 1
# Newly Activated Nodes: []
# All Activated Nodes: [111, 104, 57, 1]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [111, 104, 57, 1]
# Final Active Set Size: 4
#
# Combination 99
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 132
# Newly Activated Nodes: []
# All Activated Nodes: [132]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [132]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 21
# Newly Activated Nodes: [112]
# All Activated Nodes: [112, 21]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [112, 21]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 121
# Newly Activated Nodes: []
# All Activated Nodes: [112, 21, 121]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [112, 21, 121]
# Final Active Set Size: 3
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 55
# Newly Activated Nodes: []
# All Activated Nodes: [112, 21, 121, 55]
# Active Set Size: 4
# Number of deactivations: 1
# Deactivated Nodes: [21]
# Final Activated Nodes: [112, 121, 55]
# Final Active Set Size: 3
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 33
# Newly Activated Nodes: []
# All Activated Nodes: [112, 121, 55, 33]
# Active Set Size: 4
# Number of deactivations: 1
# Deactivated Nodes: [33]
# Final Activated Nodes: [112, 121, 55]
# Final Active Set Size: 3
#
# Combination 100
# ------------------------------------
# Selecting Influencer 1
# ------------------------------------
# Selected Influencer: Node 58
# Newly Activated Nodes: []
# All Activated Nodes: [58]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [58]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Selected Influencer: Node 44
# Newly Activated Nodes: [32]
# All Activated Nodes: [58, 32, 44]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [58, 32, 44]
# Final Active Set Size: 3
#
# Selecting Influencer 3
# ------------------------------------
# Selected Influencer: Node 106
# Newly Activated Nodes: []
# All Activated Nodes: [58, 32, 44, 106]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [58, 32, 44, 106]
# Final Active Set Size: 4
#
# Selecting Influencer 4
# ------------------------------------
# Selected Influencer: Node 57
# Newly Activated Nodes: []
# All Activated Nodes: [58, 32, 44, 106, 57]
# Active Set Size: 5
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [58, 32, 44, 106, 57]
# Final Active Set Size: 5
#
# Selecting Influencer 5
# ------------------------------------
# Selected Influencer: Node 88
# Newly Activated Nodes: []
# All Activated Nodes: [58, 32, 44, 106, 57, 88]
# Active Set Size: 6
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [58, 32, 44, 106, 57, 88]
# Final Active Set Size: 6

# %%
print(LT_ref)
print("")
print(sorted_influencers)
# Out:
# [([123, 2, 129, 33, 38], 8), ([25, 33, 120, 2, 35], 7), ([33, 57, 52, 141, 38], 7), ([58, 33, 38, 18, 57], 7), ([94, 141, 24, 25, 57], 7), ([12, 57, 44, 123, 38], 7), ([33, 18, 58, 123, 141], 7), ([8, 90, 68, 123, 33], 6), ([116, 35, 33, 123, 32], 6), ([38, 4, 48, 132, 128], 6), ([62, 105, 141, 30, 33], 6), ([33, 44, 58, 73, 90], 6), ([7, 33, 4, 57, 2], 6), ([58, 44, 106, 57, 88], 6), ([33, 2, 57, 25, 43], 5), ([72, 44, 48, 33, 73], 5), ([69, 57, 52, 10, 38], 5), ([58, 6, 55, 38, 123], 5), ([120, 90, 50, 58, 57], 5), ([30, 141, 12, 25, 113], 5), ([66, 38, 25, 106, 132], 5), ([137, 116, 73, 141, 52], 5), ([25, 33, 38, 33, 135], 5), ([33, 103, 31, 56, 106], 5), ([25, 58, 31, 72, 57], 5), ([33, 33, 38, 135, 47], 4), ([43, 44, 31, 136, 121], 4), ([103, 33, 57, 47, 7], 4), ([25, 125, 38, 128, 82], 4), ([120, 25, 33, 136, 57], 4), ([132, 103, 33, 7, 99], 4), ([4, 9, 38, 38, 57], 4), ([57, 12, 104, 18, 88], 4), ([44, 12, 25, 31, 9], 4), ([10, 38, 33, 31, 1], 4), ([52, 66, 38, 120, 64], 4), ([4, 38, 111, 58, 88], 4), ([44, 33, 120, 130, 43], 4), ([4, 117, 58, 33, 103], 4), ([113, 73, 2, 33, 44], 4), ([38, 7, 36, 57, 103], 4), ([44, 106, 8, 120, 57], 4), ([120, 66, 88, 25, 123], 4), ([147, 58, 120, 54, 36], 4), ([38, 117, 33, 47, 44], 4), ([84, 44, 55, 110, 38], 4), ([33, 33, 31, 30, 58], 4), ([2, 38, 33, 44, 104], 4), ([103, 2, 123, 33, 57], 4), ([2, 31, 38, 52, 44], 4), ([33, 57, 4, 64, 1], 4), ([57, 33, 57, 12, 38], 4), ([146, 57, 33, 88, 33], 4), ([33, 111, 104, 57, 1], 4), ([56, 31, 38, 44, 4], 3), ([44, 117, 25, 35, 38], 3), ([37, 93, 52, 0, 148], 3), ([113, 33, 57, 33, 30], 3), ([4, 0, 33, 57, 44], 3), ([4, 44, 25, 43, 58], 3), ([141, 117, 135, 33, 33], 3), ([33, 38, 8, 35, 4], 3), ([38, 44, 25, 38, 68], 3), ([123, 33, 47, 44, 10], 3), ([58, 58, 2, 135, 55], 3), ([33, 135, 43, 57, 106], 3), ([8, 33, 93, 44, 33], 3), ([44, 30, 120, 113, 44], 3), ([38, 55, 30, 43, 103], 3), ([57, 8, 15, 38, 47], 3), ([10, 58, 33, 62, 44], 3), ([33, 57, 22, 123, 4], 3), ([57, 38, 28, 52, 134], 3), ([57, 33, 1, 38, 120], 3), ([25, 7, 33, 132, 75], 3), ([2, 132, 58, 60, 88], 3), ([132, 21, 121, 55, 33], 3), ([33, 38, 52, 1, 68], 2), ([126, 38, 37, 58, 121], 2), ([77, 57, 2, 33, 145], 2), ([35, 57, 47, 122, 38], 2), ([7, 33, 72, 120, 33], 2), ([0, 66, 1, 33, 43], 2), ([38, 145, 73, 33, 38], 2), ([38, 124, 38, 55, 57], 2), ([145, 25, 52, 94, 38], 2), ([35, 123, 33, 21, 93], 2), ([33, 120, 88, 103, 44], 2), ([57, 132, 57, 2, 31], 2), ([2, 30, 4, 38, 38], 1), ([120, 145, 44, 33, 44], 1), ([135, 33, 88, 58, 38], 1), ([30, 43, 30, 58, 4], 1), ([33, 7, 33, 47, 57], 1), ([44, 136, 94, 33, 57], 1), ([60, 73, 30, 120, 132], 1), ([132, 135, 113, 68, 33], 1), ([103, 33, 132, 35, 73], 1), ([106, 145, 113, 57, 141], 1), ([58, 58, 103, 58, 120], 0)]
#
# [[123, 2, 129, 33, 38], [25, 33, 120, 2, 35], [33, 57, 52, 141, 38], [58, 33, 38, 18, 57], [94, 141, 24, 25, 57], [12, 57, 44, 123, 38], [33, 18, 58, 123, 141], [8, 90, 68, 123, 33], [116, 35, 33, 123, 32], [38, 4, 48, 132, 128], [62, 105, 141, 30, 33], [33, 44, 58, 73, 90], [7, 33, 4, 57, 2], [58, 44, 106, 57, 88], [33, 2, 57, 25, 43], [72, 44, 48, 33, 73], [69, 57, 52, 10, 38], [58, 6, 55, 38, 123], [120, 90, 50, 58, 57], [30, 141, 12, 25, 113], [66, 38, 25, 106, 132], [137, 116, 73, 141, 52], [25, 33, 38, 33, 135], [33, 103, 31, 56, 106], [25, 58, 31, 72, 57], [33, 33, 38, 135, 47], [43, 44, 31, 136, 121], [103, 33, 57, 47, 7], [25, 125, 38, 128, 82], [120, 25, 33, 136, 57], [132, 103, 33, 7, 99], [4, 9, 38, 38, 57], [57, 12, 104, 18, 88], [44, 12, 25, 31, 9], [10, 38, 33, 31, 1], [52, 66, 38, 120, 64], [4, 38, 111, 58, 88], [44, 33, 120, 130, 43], [4, 117, 58, 33, 103], [113, 73, 2, 33, 44], [38, 7, 36, 57, 103], [44, 106, 8, 120, 57], [120, 66, 88, 25, 123], [147, 58, 120, 54, 36], [38, 117, 33, 47, 44], [84, 44, 55, 110, 38], [33, 33, 31, 30, 58], [2, 38, 33, 44, 104], [103, 2, 123, 33, 57], [2, 31, 38, 52, 44], [33, 57, 4, 64, 1], [57, 33, 57, 12, 38], [146, 57, 33, 88, 33], [33, 111, 104, 57, 1], [56, 31, 38, 44, 4], [44, 117, 25, 35, 38], [37, 93, 52, 0, 148], [113, 33, 57, 33, 30], [4, 0, 33, 57, 44], [4, 44, 25, 43, 58], [141, 117, 135, 33, 33], [33, 38, 8, 35, 4], [38, 44, 25, 38, 68], [123, 33, 47, 44, 10], [58, 58, 2, 135, 55], [33, 135, 43, 57, 106], [8, 33, 93, 44, 33], [44, 30, 120, 113, 44], [38, 55, 30, 43, 103], [57, 8, 15, 38, 47], [10, 58, 33, 62, 44], [33, 57, 22, 123, 4], [57, 38, 28, 52, 134], [57, 33, 1, 38, 120], [25, 7, 33, 132, 75], [2, 132, 58, 60, 88], [132, 21, 121, 55, 33], [33, 38, 52, 1, 68], [126, 38, 37, 58, 121], [77, 57, 2, 33, 145], [35, 57, 47, 122, 38], [7, 33, 72, 120, 33], [0, 66, 1, 33, 43], [38, 145, 73, 33, 38], [38, 124, 38, 55, 57], [145, 25, 52, 94, 38], [35, 123, 33, 21, 93], [33, 120, 88, 103, 44], [57, 132, 57, 2, 31], [2, 30, 4, 38, 38], [120, 145, 44, 33, 44], [135, 33, 88, 58, 38], [30, 43, 30, 58, 4], [33, 7, 33, 47, 57], [44, 136, 94, 33, 57], [60, 73, 30, 120, 132], [132, 135, 113, 68, 33], [103, 33, 132, 35, 73], [106, 145, 113, 57, 141], [58, 58, 103, 58, 120]]

# %%
# Actual Influence Spread

# %%
def check_reference(sorted_influencers, all_activated_nodes, i, model, config):
    influencer = sorted_influencers[0][i]
    j = 1
    while influencer in all_activated_nodes:
        try:   
            influencer = sorted_influencers[j][i]
            j += 1
        except IndexError:
            influencer = GreedySelect(g, all_activated_nodes, model, config, greedy_i)

    # Filter sorted influencers for unmatching combinations
    print(f"Influencer: Node {influencer}")
    n = []
    for combination in sorted_influencers:
        if combination[i] == influencer:
            n.append(combination)
    print(f"New Sorted Combination List: {n}")
    sorted_influencers = n
    return influencer, sorted_influencers

def greedy_sequential(g, target_set_size, greedy_i, sorted_influencers):
    '''
    Assuming continuous process (previously activated nodes cannot reattempt)
    As compared to one-time influence spread, all influencer same start point
    Default strategy set as greedy 
    '''
    # prepare graph for respective strategies
    g = remove_isolated_nodes(g)
        
    # initialize diffusion model
    model, config = InitModel(g)
    
    all_activated_nodes = []
    influencers = []
    active_ss_list = []
    
    for i in range(target_set_size):
        print(f"Selecting Influencer {i+1}")
        print("------------------------------------")
        
        if sorted_influencers == []: # If no matching combination, simulate greedy
            influencer = GreedySelect(g, all_activated_nodes, model, config, greedy_i)
            print("Approach: Greedy Select")
        else: # Check LT Reward Reference
            influencer, sorted_influencers = check_reference(sorted_influencers, all_activated_nodes, i, model, config)
            print("Approach: LT Reward Reference")
            
        influencers.append(influencer)

        active_set_size, newly_activated_nodes = InfluenceSpread(model, config, influencer)
        print(f"Newly Activated Nodes: {newly_activated_nodes}")
        newly_activated_nodes.append(influencer)
        all_activated_nodes.extend(newly_activated_nodes)
        print(f"All Activated Nodes: {all_activated_nodes}")
        print(f"Active Set Size: {active_set_size}")
        
        active_set_size, all_activated_nodes = model.random_deactivation(all_activated_nodes)
        print(f"Final Activated Nodes: {all_activated_nodes}")
        print(f"Final Active Set Size: {active_set_size}")
        print("")

        model.is_reset()
        active_ss_list.append(active_set_size)

    return influencers, active_ss_list[-1]

# %%
exp_i = 20
greedy_i = 50
target_set_size = 5
g_total_activated_nodes = 0

for i in range(exp_i):
    influencers, active_set_size = greedy_sequential(g, target_set_size, greedy_i, sorted_influencers)
    g_total_activated_nodes += active_set_size

g_avg_activated_nodes = g_total_activated_nodes / exp_i
# Out:
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 123
# New Sorted Combination List: [[123, 2, 129, 33, 38], [123, 33, 47, 44, 10]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [123]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 2
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [2]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [2]
# Final Active Set Size: 1
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 129
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [2, 129]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [2]
# Final Activated Nodes: [129]
# Final Active Set Size: 1
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 33
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [3, 141, 5, 117, 127, 25]
# All Activated Nodes: [129, 3, 141, 5, 117, 127, 25, 33]
# Active Set Size: 8
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [129, 3, 141, 5, 117, 127, 25, 33]
# Final Active Set Size: 8
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 38
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [129, 3, 141, 5, 117, 127, 25, 33, 38]
# Active Set Size: 9
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [129, 3, 141, 5, 117, 127, 25, 33, 38]
# Final Active Set Size: 9
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 123
# New Sorted Combination List: [[123, 2, 129, 33, 38], [123, 33, 47, 44, 10]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [123]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 2
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [10]
# All Activated Nodes: [10, 2]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [10, 2]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 129
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [6, 49, 21]
# All Activated Nodes: [10, 2, 6, 49, 21, 129]
# Active Set Size: 6
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [10, 2, 6, 49, 21, 129]
# Final Active Set Size: 6
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 33
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [109]
# All Activated Nodes: [10, 2, 6, 49, 21, 129, 109, 33]
# Active Set Size: 8
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [10, 2, 6, 49, 21, 129, 109, 33]
# Final Active Set Size: 8
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 38
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [46]
# All Activated Nodes: [10, 2, 6, 49, 21, 129, 109, 33, 46, 38]
# Active Set Size: 10
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [10, 2, 6, 49, 21, 129, 109, 33, 46, 38]
# Final Active Set Size: 10
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 123
# New Sorted Combination List: [[123, 2, 129, 33, 38], [123, 33, 47, 44, 10]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [135]
# All Activated Nodes: [135, 123]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [135, 123]
# Final Active Set Size: 2
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 2
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [135, 123, 2]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [123]
# Final Activated Nodes: [135, 2]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 129
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [135, 2, 129]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [135, 2, 129]
# Final Active Set Size: 3
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 33
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [135, 2, 129, 33]
# Active Set Size: 4
# Number of deactivations: 1
# Deactivated Nodes: [33]
# Final Activated Nodes: [135, 2, 129]
# Final Active Set Size: 3
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 38
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [135, 2, 129, 38]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [135, 2, 129, 38]
# Final Active Set Size: 4
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 123
# New Sorted Combination List: [[123, 2, 129, 33, 38], [123, 33, 47, 44, 10]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [123]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 2
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [2]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [2]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 129
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [129]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [129]
# Final Active Set Size: 1
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 33
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [129, 33]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [129, 33]
# Final Active Set Size: 2
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 38
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [129, 33, 38]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [129, 33, 38]
# Final Active Set Size: 3
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 123
# New Sorted Combination List: [[123, 2, 129, 33, 38], [123, 33, 47, 44, 10]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [123]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 2
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123, 2]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [123, 2]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 129
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123, 2, 129]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [123, 2, 129]
# Final Active Set Size: 3
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 33
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123, 2, 129, 33]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [123, 2, 129, 33]
# Final Active Set Size: 4
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 38
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123, 2, 129, 33, 38]
# Active Set Size: 5
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [123, 2, 129, 33, 38]
# Final Active Set Size: 5
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 123
# New Sorted Combination List: [[123, 2, 129, 33, 38], [123, 33, 47, 44, 10]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [123]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 2
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [2]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [2]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 129
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [129]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [129]
# Final Active Set Size: 1
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 33
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [129, 33]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [129]
# Final Activated Nodes: [33]
# Final Active Set Size: 1
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 38
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [108, 113, 92]
# All Activated Nodes: [33, 108, 113, 92, 38]
# Active Set Size: 5
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [33, 108, 113, 92, 38]
# Final Active Set Size: 5
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 123
# New Sorted Combination List: [[123, 2, 129, 33, 38], [123, 33, 47, 44, 10]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [123]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 2
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123, 2]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [123, 2]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 129
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123, 2, 129]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [129]
# Final Activated Nodes: [123, 2]
# Final Active Set Size: 2
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 33
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123, 2, 33]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [123, 2, 33]
# Final Active Set Size: 3
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 38
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123, 2, 33, 38]
# Active Set Size: 4
# Number of deactivations: 1
# Deactivated Nodes: [123]
# Final Activated Nodes: [2, 33, 38]
# Final Active Set Size: 3
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 123
# New Sorted Combination List: [[123, 2, 129, 33, 38], [123, 33, 47, 44, 10]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [123]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 2
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123, 2]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [123]
# Final Activated Nodes: [2]
# Final Active Set Size: 1
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 129
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [2, 129]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [2]
# Final Activated Nodes: [129]
# Final Active Set Size: 1
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 33
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [129, 33]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [129, 33]
# Final Active Set Size: 2
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 38
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [78]
# All Activated Nodes: [129, 33, 78, 38]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [129, 33, 78, 38]
# Final Active Set Size: 4
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 123
# New Sorted Combination List: [[123, 2, 129, 33, 38], [123, 33, 47, 44, 10]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [127]
# All Activated Nodes: [127, 123]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [127]
# Final Activated Nodes: [123]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 2
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [116]
# All Activated Nodes: [123, 116, 2]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [123, 116, 2]
# Final Active Set Size: 3
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 129
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123, 116, 2, 129]
# Active Set Size: 4
# Number of deactivations: 1
# Deactivated Nodes: [123]
# Final Activated Nodes: [116, 2, 129]
# Final Active Set Size: 3
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 33
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [116, 2, 129, 33]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [116, 2, 129, 33]
# Final Active Set Size: 4
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 38
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [116, 2, 129, 33, 38]
# Active Set Size: 5
# Number of deactivations: 1
# Deactivated Nodes: [38]
# Final Activated Nodes: [116, 2, 129, 33]
# Final Active Set Size: 4
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 123
# New Sorted Combination List: [[123, 2, 129, 33, 38], [123, 33, 47, 44, 10]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [123]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 2
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123, 2]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [123, 2]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 129
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [41]
# All Activated Nodes: [123, 2, 41, 129]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [123, 2, 41, 129]
# Final Active Set Size: 4
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 33
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123, 2, 41, 129, 33]
# Active Set Size: 5
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [123, 2, 41, 129, 33]
# Final Active Set Size: 5
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 38
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [5]
# All Activated Nodes: [123, 2, 41, 129, 33, 5, 38]
# Active Set Size: 7
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [123, 2, 41, 129, 33, 5, 38]
# Final Active Set Size: 7
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 123
# New Sorted Combination List: [[123, 2, 129, 33, 38], [123, 33, 47, 44, 10]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [123]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 2
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [2]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [2]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 129
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [129]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [129]
# Final Active Set Size: 1
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 33
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [146]
# All Activated Nodes: [129, 146, 33]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [129, 146, 33]
# Final Active Set Size: 3
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 38
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [88]
# All Activated Nodes: [129, 146, 33, 88, 38]
# Active Set Size: 5
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [129, 146, 33, 88, 38]
# Final Active Set Size: 5
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 123
# New Sorted Combination List: [[123, 2, 129, 33, 38], [123, 33, 47, 44, 10]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [123]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 2
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [2]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [2]
# Final Active Set Size: 1
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 129
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [2, 129]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [2, 129]
# Final Active Set Size: 2
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 33
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [2, 129, 33]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [129]
# Final Activated Nodes: [2, 33]
# Final Active Set Size: 2
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 38
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [2, 33, 38]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [2, 33, 38]
# Final Active Set Size: 3
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 123
# New Sorted Combination List: [[123, 2, 129, 33, 38], [123, 33, 47, 44, 10]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [123]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 2
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123, 2]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [123]
# Final Activated Nodes: [2]
# Final Active Set Size: 1
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 129
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [2, 129]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [2, 129]
# Final Active Set Size: 2
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 33
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [2, 129, 33]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [2, 129, 33]
# Final Active Set Size: 3
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 38
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [7]
# All Activated Nodes: [2, 129, 33, 7, 38]
# Active Set Size: 5
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [2, 129, 33, 7, 38]
# Final Active Set Size: 5
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 123
# New Sorted Combination List: [[123, 2, 129, 33, 38], [123, 33, 47, 44, 10]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [123]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 2
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123, 2]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [123, 2]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 129
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123, 2, 129]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [123, 2, 129]
# Final Active Set Size: 3
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 33
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [95, 120, 74]
# All Activated Nodes: [123, 2, 129, 95, 120, 74, 33]
# Active Set Size: 7
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [123, 2, 129, 95, 120, 74, 33]
# Final Active Set Size: 7
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 38
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [83]
# All Activated Nodes: [123, 2, 129, 95, 120, 74, 33, 83, 38]
# Active Set Size: 9
# Number of deactivations: 1
# Deactivated Nodes: [120]
# Final Activated Nodes: [123, 2, 129, 95, 74, 33, 83, 38]
# Final Active Set Size: 8
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 123
# New Sorted Combination List: [[123, 2, 129, 33, 38], [123, 33, 47, 44, 10]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [123]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 2
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [2]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [2]
# Final Active Set Size: 1
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 129
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [2, 129]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [2]
# Final Activated Nodes: [129]
# Final Active Set Size: 1
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 33
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [129, 33]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [129]
# Final Activated Nodes: [33]
# Final Active Set Size: 1
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 38
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [33, 38]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [38]
# Final Activated Nodes: [33]
# Final Active Set Size: 1
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 123
# New Sorted Combination List: [[123, 2, 129, 33, 38], [123, 33, 47, 44, 10]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [123]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 2
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [2]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [2]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 129
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [55, 81, 106]
# All Activated Nodes: [55, 81, 106, 129]
# Active Set Size: 4
# Number of deactivations: 1
# Deactivated Nodes: [81]
# Final Activated Nodes: [55, 106, 129]
# Final Active Set Size: 3
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 33
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [55, 106, 129, 33]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [55, 106, 129, 33]
# Final Active Set Size: 4
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 38
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [55, 106, 129, 33, 38]
# Active Set Size: 5
# Number of deactivations: 1
# Deactivated Nodes: [106]
# Final Activated Nodes: [55, 129, 33, 38]
# Final Active Set Size: 4
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 123
# New Sorted Combination List: [[123, 2, 129, 33, 38], [123, 33, 47, 44, 10]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [123]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 2
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [2]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [2]
# Final Active Set Size: 1
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 129
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [2, 129]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [2]
# Final Activated Nodes: [129]
# Final Active Set Size: 1
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 33
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [52]
# All Activated Nodes: [129, 52, 33]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [33]
# Final Activated Nodes: [129, 52]
# Final Active Set Size: 2
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 38
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [129, 52, 38]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [38]
# Final Activated Nodes: [129, 52]
# Final Active Set Size: 2
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 123
# New Sorted Combination List: [[123, 2, 129, 33, 38], [123, 33, 47, 44, 10]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [123]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 2
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [125, 133]
# All Activated Nodes: [125, 133, 2]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [125, 133, 2]
# Final Active Set Size: 3
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 129
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [125, 133, 2, 129]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [125, 133, 2, 129]
# Final Active Set Size: 4
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 33
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [125, 133, 2, 129, 33]
# Active Set Size: 5
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [125, 133, 2, 129, 33]
# Final Active Set Size: 5
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 38
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [125, 133, 2, 129, 33, 38]
# Active Set Size: 6
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [125, 133, 2, 129, 33, 38]
# Final Active Set Size: 6
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 123
# New Sorted Combination List: [[123, 2, 129, 33, 38], [123, 33, 47, 44, 10]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [123]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 2
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [2]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [2]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 129
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [116]
# All Activated Nodes: [116, 129]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [116]
# Final Activated Nodes: [129]
# Final Active Set Size: 1
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 33
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [129, 33]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [129, 33]
# Final Active Set Size: 2
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 38
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [129, 33, 38]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [129]
# Final Activated Nodes: [33, 38]
# Final Active Set Size: 2
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 123
# New Sorted Combination List: [[123, 2, 129, 33, 38], [123, 33, 47, 44, 10]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [123]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [123]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 2
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: [122]
# All Activated Nodes: [122, 2]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [122, 2]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 129
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [122, 2, 129]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [129]
# Final Activated Nodes: [122, 2]
# Final Active Set Size: 2
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 33
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [122, 2, 33]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [122]
# Final Activated Nodes: [2, 33]
# Final Active Set Size: 2
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 38
# New Sorted Combination List: [[123, 2, 129, 33, 38]]
# Approach: LT Reward Reference
# Newly Activated Nodes: []
# All Activated Nodes: [2, 33, 38]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [2, 33, 38]
# Final Active Set Size: 3

# %%
def random_sequential(g, target_set_size):
    '''
    Assuming continuous process (previously activated nodes cannot reattempt)
    As compared to one-time influence spread, all influencer same start point
    Default strategy set as greedy 
    '''
    # prepare graph for respective strategies
    g = remove_isolated_nodes(g)
        
    # initialize diffusion model
    model, config = InitModel(g)
    
    all_activated_nodes = []
    influencers = []
    active_ss_list = []
    
    for i in range(target_set_size):
        print(f"Selecting Influencer {i+1}")
        print("------------------------------------")
        
        influencer = random.randint(0, len(g)-1)
        while influencer in all_activated_nodes:
            influencer = random.randint(0, len(g)-1)
        print(f"Influencer: Node {influencer}")
            
        influencers.append(influencer)

        active_set_size, newly_activated_nodes = InfluenceSpread(model, config, influencer)
        print(f"Newly Activated Nodes: {newly_activated_nodes}")
        newly_activated_nodes.append(influencer)
        all_activated_nodes.extend(newly_activated_nodes)
        print(f"All Activated Nodes: {all_activated_nodes}")
        print(f"Active Set Size: {active_set_size}")
        
        active_set_size, all_activated_nodes = model.random_deactivation(all_activated_nodes)
        print(f"Final Activated Nodes: {all_activated_nodes}")
        print(f"Final Active Set Size: {active_set_size}")
        print("")

        model.is_reset()
        active_ss_list.append(active_set_size)

    return influencers, active_ss_list[-1]

# %%
exp_i = 20
target_set_size = 5
r_total_activated_nodes = 0

for i in range(exp_i):
    influencers, active_set_size = random_sequential(g, target_set_size)
    r_total_activated_nodes += active_set_size

r_avg_activated_nodes = r_total_activated_nodes / exp_i
# Out:
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 45
# Newly Activated Nodes: []
# All Activated Nodes: [45]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [45]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 100
# Newly Activated Nodes: []
# All Activated Nodes: [45, 100]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [45, 100]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 35
# Newly Activated Nodes: [58]
# All Activated Nodes: [45, 100, 58, 35]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [45, 100, 58, 35]
# Final Active Set Size: 4
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 111
# Newly Activated Nodes: []
# All Activated Nodes: [45, 100, 58, 35, 111]
# Active Set Size: 5
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [45, 100, 58, 35, 111]
# Final Active Set Size: 5
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 46
# Newly Activated Nodes: []
# All Activated Nodes: [45, 100, 58, 35, 111, 46]
# Active Set Size: 6
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [45, 100, 58, 35, 111, 46]
# Final Active Set Size: 6
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 29
# Newly Activated Nodes: [103]
# All Activated Nodes: [103, 29]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [29]
# Final Activated Nodes: [103]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 24
# Newly Activated Nodes: []
# All Activated Nodes: [103, 24]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [103, 24]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 82
# Newly Activated Nodes: []
# All Activated Nodes: [103, 24, 82]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [24]
# Final Activated Nodes: [103, 82]
# Final Active Set Size: 2
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 94
# Newly Activated Nodes: []
# All Activated Nodes: [103, 82, 94]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [94]
# Final Activated Nodes: [103, 82]
# Final Active Set Size: 2
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 51
# Newly Activated Nodes: []
# All Activated Nodes: [103, 82, 51]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [82]
# Final Activated Nodes: [103, 51]
# Final Active Set Size: 2
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 91
# Newly Activated Nodes: []
# All Activated Nodes: [91]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [91]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 48
# Newly Activated Nodes: [38]
# All Activated Nodes: [38, 48]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [38, 48]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 66
# Newly Activated Nodes: []
# All Activated Nodes: [38, 48, 66]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [38, 48, 66]
# Final Active Set Size: 3
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 146
# Newly Activated Nodes: []
# All Activated Nodes: [38, 48, 66, 146]
# Active Set Size: 4
# Number of deactivations: 1
# Deactivated Nodes: [48]
# Final Activated Nodes: [38, 66, 146]
# Final Active Set Size: 3
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 127
# Newly Activated Nodes: []
# All Activated Nodes: [38, 66, 146, 127]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [38, 66, 146, 127]
# Final Active Set Size: 4
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 90
# Newly Activated Nodes: []
# All Activated Nodes: [90]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [90]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 100
# Newly Activated Nodes: []
# All Activated Nodes: [100]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [100]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 15
# Newly Activated Nodes: []
# All Activated Nodes: [15]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [15]
# Final Active Set Size: 1
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 145
# Newly Activated Nodes: []
# All Activated Nodes: [15, 145]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [15, 145]
# Final Active Set Size: 2
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 11
# Newly Activated Nodes: []
# All Activated Nodes: [15, 145, 11]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [15, 145, 11]
# Final Active Set Size: 3
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 76
# Newly Activated Nodes: []
# All Activated Nodes: [76]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [76]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 89
# Newly Activated Nodes: []
# All Activated Nodes: [76, 89]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [76]
# Final Activated Nodes: [89]
# Final Active Set Size: 1
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 125
# Newly Activated Nodes: []
# All Activated Nodes: [89, 125]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [89, 125]
# Final Active Set Size: 2
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 65
# Newly Activated Nodes: []
# All Activated Nodes: [89, 125, 65]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [89, 125, 65]
# Final Active Set Size: 3
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 132
# Newly Activated Nodes: []
# All Activated Nodes: [89, 125, 65, 132]
# Active Set Size: 4
# Number of deactivations: 1
# Deactivated Nodes: [125]
# Final Activated Nodes: [89, 65, 132]
# Final Active Set Size: 3
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 68
# Newly Activated Nodes: []
# All Activated Nodes: [68]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [68]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 13
# Newly Activated Nodes: []
# All Activated Nodes: [13]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [13]
# Final Active Set Size: 1
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 50
# Newly Activated Nodes: []
# All Activated Nodes: [13, 50]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [13]
# Final Activated Nodes: [50]
# Final Active Set Size: 1
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 74
# Newly Activated Nodes: []
# All Activated Nodes: [50, 74]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [50]
# Final Activated Nodes: [74]
# Final Active Set Size: 1
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 107
# Newly Activated Nodes: []
# All Activated Nodes: [74, 107]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [107]
# Final Activated Nodes: [74]
# Final Active Set Size: 1
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 58
# Newly Activated Nodes: []
# All Activated Nodes: [58]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [58]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 32
# Newly Activated Nodes: []
# All Activated Nodes: [32]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [32]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 34
# Newly Activated Nodes: [120]
# All Activated Nodes: [120, 34]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [120, 34]
# Final Active Set Size: 2
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 106
# Newly Activated Nodes: []
# All Activated Nodes: [120, 34, 106]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [120, 34, 106]
# Final Active Set Size: 3
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 7
# Newly Activated Nodes: []
# All Activated Nodes: [120, 34, 106, 7]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [120, 34, 106, 7]
# Final Active Set Size: 4
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 130
# Newly Activated Nodes: []
# All Activated Nodes: [130]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [130]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 31
# Newly Activated Nodes: [106]
# All Activated Nodes: [106, 31]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [106]
# Final Activated Nodes: [31]
# Final Active Set Size: 1
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 78
# Newly Activated Nodes: []
# All Activated Nodes: [31, 78]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [78]
# Final Activated Nodes: [31]
# Final Active Set Size: 1
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 21
# Newly Activated Nodes: [72]
# All Activated Nodes: [31, 72, 21]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [31, 72, 21]
# Final Active Set Size: 3
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 126
# Newly Activated Nodes: []
# All Activated Nodes: [31, 72, 21, 126]
# Active Set Size: 4
# Number of deactivations: 1
# Deactivated Nodes: [31]
# Final Activated Nodes: [72, 21, 126]
# Final Active Set Size: 3
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 101
# Newly Activated Nodes: [35, 24, 44, 59]
# All Activated Nodes: [35, 24, 44, 59, 101]
# Active Set Size: 5
# Number of deactivations: 1
# Deactivated Nodes: [35]
# Final Activated Nodes: [24, 44, 59, 101]
# Final Active Set Size: 4
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 61
# Newly Activated Nodes: []
# All Activated Nodes: [24, 44, 59, 101, 61]
# Active Set Size: 5
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [24, 44, 59, 101, 61]
# Final Active Set Size: 5
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 147
# Newly Activated Nodes: []
# All Activated Nodes: [24, 44, 59, 101, 61, 147]
# Active Set Size: 6
# Number of deactivations: 1
# Deactivated Nodes: [44]
# Final Activated Nodes: [24, 59, 101, 61, 147]
# Final Active Set Size: 5
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 144
# Newly Activated Nodes: [51]
# All Activated Nodes: [24, 59, 101, 61, 147, 51, 144]
# Active Set Size: 7
# Number of deactivations: 1
# Deactivated Nodes: [51]
# Final Activated Nodes: [24, 59, 101, 61, 147, 144]
# Final Active Set Size: 6
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 99
# Newly Activated Nodes: []
# All Activated Nodes: [24, 59, 101, 61, 147, 144, 99]
# Active Set Size: 7
# Number of deactivations: 1
# Deactivated Nodes: [61]
# Final Activated Nodes: [24, 59, 101, 147, 144, 99]
# Final Active Set Size: 6
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 110
# Newly Activated Nodes: []
# All Activated Nodes: [110]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [110]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 130
# Newly Activated Nodes: []
# All Activated Nodes: [110, 130]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [110, 130]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 28
# Newly Activated Nodes: []
# All Activated Nodes: [110, 130, 28]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [110, 130, 28]
# Final Active Set Size: 3
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 17
# Newly Activated Nodes: []
# All Activated Nodes: [110, 130, 28, 17]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [110, 130, 28, 17]
# Final Active Set Size: 4
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 35
# Newly Activated Nodes: []
# All Activated Nodes: [110, 130, 28, 17, 35]
# Active Set Size: 5
# Number of deactivations: 1
# Deactivated Nodes: [35]
# Final Activated Nodes: [110, 130, 28, 17]
# Final Active Set Size: 4
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 99
# Newly Activated Nodes: []
# All Activated Nodes: [99]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [99]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 97
# Newly Activated Nodes: []
# All Activated Nodes: [99, 97]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [99, 97]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 104
# Newly Activated Nodes: []
# All Activated Nodes: [99, 97, 104]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [104]
# Final Activated Nodes: [99, 97]
# Final Active Set Size: 2
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 59
# Newly Activated Nodes: [61, 26]
# All Activated Nodes: [99, 97, 61, 26, 59]
# Active Set Size: 5
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [99, 97, 61, 26, 59]
# Final Active Set Size: 5
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 0
# Newly Activated Nodes: []
# All Activated Nodes: [99, 97, 61, 26, 59, 0]
# Active Set Size: 6
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [99, 97, 61, 26, 59, 0]
# Final Active Set Size: 6
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 123
# Newly Activated Nodes: []
# All Activated Nodes: [123]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [123]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 121
# Newly Activated Nodes: []
# All Activated Nodes: [123, 121]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [123, 121]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 44
# Newly Activated Nodes: []
# All Activated Nodes: [123, 121, 44]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [123]
# Final Activated Nodes: [121, 44]
# Final Active Set Size: 2
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 51
# Newly Activated Nodes: []
# All Activated Nodes: [121, 44, 51]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [44]
# Final Activated Nodes: [121, 51]
# Final Active Set Size: 2
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 132
# Newly Activated Nodes: []
# All Activated Nodes: [121, 51, 132]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [121, 51, 132]
# Final Active Set Size: 3
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 20
# Newly Activated Nodes: []
# All Activated Nodes: [20]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [20]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 63
# Newly Activated Nodes: [69, 132]
# All Activated Nodes: [20, 69, 132, 63]
# Active Set Size: 4
# Number of deactivations: 1
# Deactivated Nodes: [20]
# Final Activated Nodes: [69, 132, 63]
# Final Active Set Size: 3
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 34
# Newly Activated Nodes: []
# All Activated Nodes: [69, 132, 63, 34]
# Active Set Size: 4
# Number of deactivations: 1
# Deactivated Nodes: [132]
# Final Activated Nodes: [69, 63, 34]
# Final Active Set Size: 3
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 55
# Newly Activated Nodes: [77]
# All Activated Nodes: [69, 63, 34, 77, 55]
# Active Set Size: 5
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [69, 63, 34, 77, 55]
# Final Active Set Size: 5
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 79
# Newly Activated Nodes: []
# All Activated Nodes: [69, 63, 34, 77, 55, 79]
# Active Set Size: 6
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [69, 63, 34, 77, 55, 79]
# Final Active Set Size: 6
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 53
# Newly Activated Nodes: []
# All Activated Nodes: [53]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [53]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 10
# Newly Activated Nodes: [126]
# All Activated Nodes: [53, 126, 10]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [126]
# Final Activated Nodes: [53, 10]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 133
# Newly Activated Nodes: []
# All Activated Nodes: [53, 10, 133]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [133]
# Final Activated Nodes: [53, 10]
# Final Active Set Size: 2
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 14
# Newly Activated Nodes: [67]
# All Activated Nodes: [53, 10, 67, 14]
# Active Set Size: 4
# Number of deactivations: 1
# Deactivated Nodes: [67]
# Final Activated Nodes: [53, 10, 14]
# Final Active Set Size: 3
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 109
# Newly Activated Nodes: []
# All Activated Nodes: [53, 10, 14, 109]
# Active Set Size: 4
# Number of deactivations: 1
# Deactivated Nodes: [109]
# Final Activated Nodes: [53, 10, 14]
# Final Active Set Size: 3
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 69
# Newly Activated Nodes: []
# All Activated Nodes: [69]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [69]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 89
# Newly Activated Nodes: []
# All Activated Nodes: [69, 89]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [69, 89]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 98
# Newly Activated Nodes: []
# All Activated Nodes: [69, 89, 98]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [98]
# Final Activated Nodes: [69, 89]
# Final Active Set Size: 2
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 0
# Newly Activated Nodes: []
# All Activated Nodes: [69, 89, 0]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [69, 89, 0]
# Final Active Set Size: 3
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 148
# Newly Activated Nodes: []
# All Activated Nodes: [69, 89, 0, 148]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [69, 89, 0, 148]
# Final Active Set Size: 4
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 106
# Newly Activated Nodes: [15]
# All Activated Nodes: [15, 106]
# Active Set Size: 2
# Number of deactivations: 1
# Deactivated Nodes: [15]
# Final Activated Nodes: [106]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 43
# Newly Activated Nodes: [19]
# All Activated Nodes: [106, 19, 43]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [106, 19, 43]
# Final Active Set Size: 3
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 35
# Newly Activated Nodes: []
# All Activated Nodes: [106, 19, 43, 35]
# Active Set Size: 4
# Number of deactivations: 1
# Deactivated Nodes: [35]
# Final Activated Nodes: [106, 19, 43]
# Final Active Set Size: 3
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 127
# Newly Activated Nodes: []
# All Activated Nodes: [106, 19, 43, 127]
# Active Set Size: 4
# Number of deactivations: 1
# Deactivated Nodes: [127]
# Final Activated Nodes: [106, 19, 43]
# Final Active Set Size: 3
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 27
# Newly Activated Nodes: []
# All Activated Nodes: [106, 19, 43, 27]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [106, 19, 43, 27]
# Final Active Set Size: 4
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 36
# Newly Activated Nodes: []
# All Activated Nodes: [36]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [36]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 91
# Newly Activated Nodes: []
# All Activated Nodes: [91]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [91]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 62
# Newly Activated Nodes: []
# All Activated Nodes: [62]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [62]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 85
# Newly Activated Nodes: []
# All Activated Nodes: [85]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [85]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 34
# Newly Activated Nodes: []
# All Activated Nodes: [34]
# Active Set Size: 1
# Number of deactivations: 1
# Deactivated Nodes: [34]
# Final Activated Nodes: []
# Final Active Set Size: 0
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 4
# Newly Activated Nodes: []
# All Activated Nodes: [4]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [4]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 130
# Newly Activated Nodes: []
# All Activated Nodes: [4, 130]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [4, 130]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 25
# Newly Activated Nodes: []
# All Activated Nodes: [4, 130, 25]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [4, 130, 25]
# Final Active Set Size: 3
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 78
# Newly Activated Nodes: []
# All Activated Nodes: [4, 130, 25, 78]
# Active Set Size: 4
# Number of deactivations: 1
# Deactivated Nodes: [4]
# Final Activated Nodes: [130, 25, 78]
# Final Active Set Size: 3
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 32
# Newly Activated Nodes: [63, 69]
# All Activated Nodes: [130, 25, 78, 63, 69, 32]
# Active Set Size: 6
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [130, 25, 78, 63, 69, 32]
# Final Active Set Size: 6
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 53
# Newly Activated Nodes: []
# All Activated Nodes: [53]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [53]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 26
# Newly Activated Nodes: []
# All Activated Nodes: [53, 26]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [53, 26]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 76
# Newly Activated Nodes: []
# All Activated Nodes: [53, 26, 76]
# Active Set Size: 3
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [53, 26, 76]
# Final Active Set Size: 3
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 114
# Newly Activated Nodes: []
# All Activated Nodes: [53, 26, 76, 114]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [53, 26, 76, 114]
# Final Active Set Size: 4
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 68
# Newly Activated Nodes: []
# All Activated Nodes: [53, 26, 76, 114, 68]
# Active Set Size: 5
# Number of deactivations: 1
# Deactivated Nodes: [68]
# Final Activated Nodes: [53, 26, 76, 114]
# Final Active Set Size: 4
#
# Selecting Influencer 1
# ------------------------------------
# Influencer: Node 32
# Newly Activated Nodes: []
# All Activated Nodes: [32]
# Active Set Size: 1
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [32]
# Final Active Set Size: 1
#
# Selecting Influencer 2
# ------------------------------------
# Influencer: Node 49
# Newly Activated Nodes: []
# All Activated Nodes: [32, 49]
# Active Set Size: 2
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [32, 49]
# Final Active Set Size: 2
#
# Selecting Influencer 3
# ------------------------------------
# Influencer: Node 131
# Newly Activated Nodes: []
# All Activated Nodes: [32, 49, 131]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [131]
# Final Activated Nodes: [32, 49]
# Final Active Set Size: 2
#
# Selecting Influencer 4
# ------------------------------------
# Influencer: Node 15
# Newly Activated Nodes: []
# All Activated Nodes: [32, 49, 15]
# Active Set Size: 3
# Number of deactivations: 1
# Deactivated Nodes: [15]
# Final Activated Nodes: [32, 49]
# Final Active Set Size: 2
#
# Selecting Influencer 5
# ------------------------------------
# Influencer: Node 38
# Newly Activated Nodes: [100]
# All Activated Nodes: [32, 49, 100, 38]
# Active Set Size: 4
# Number of deactivations: 0
# Deactivated Nodes: []
# Final Activated Nodes: [32, 49, 100, 38]
# Final Active Set Size: 4

# %%
print(g_avg_activated_nodes)
print(r_avg_activated_nodes)
# Out:
# 4.65
# 3.8
